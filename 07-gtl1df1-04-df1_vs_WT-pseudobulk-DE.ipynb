# %% [markdown]
# # Pseudobulk differential expression to compare df1 vs WT

# %%
library(tidyverse)
library(Seurat)
library(cowplot)
library(ComplexHeatmap)
library(circlize)
library(GeneOverlap)
library(gprofiler2)
library(ggrepel)
library(muscat)
library(purrr)
library(limma)
library(scran)
library(future)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Registered S3 method overwritten by 'spatstat.geom':
#   method     from
#   print.boxx cli
#
# Attaching SeuratObject
#
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.11.1
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite:
# Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#   genomic data. Bioinformatics 2016.
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
# ========================================
# circlize version 0.4.14
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: https://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(circlize))
# ========================================
#
#
# Warning message in checkMatrixPackageVersion():
# “Package version inconsistency detected.
# TMB was built with Matrix version 1.2.18
# Current Matrix version is 1.3.4
# Please re-install 'TMB' from source using install.packages('TMB', type = 'source') or ask CRAN for a binary version of 'TMB' matching CRAN's 'Matrix' package”
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SummarizedExperiment’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     Assays
#
#
# The following object is masked from ‘package:Seurat’:
#
#     Assays
#
#
#
# Attaching package: ‘future’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     values
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     values
#
#
# The following object is masked from ‘package:IRanges’:
#
#     values
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     values

# %%
#for 200gb ram 
options(future.globals.maxSize = 200000 * 1024^2)

# %%
rc.integrated <- readRDS("../data/integrations/rc.integrated_11S_gtl1_df1_Li_seu3_clean.rds")

# %%
rc.integrated
# Out:
# An object of class Seurat
# 70780 features across 74810 samples within 3 assays
# Active assay: integrated (17681 features, 17681 variable features)
#  2 other assays present: RNA, SCT
#  4 dimensional reductions calculated: pca, umap, umap_3D, umap_2D

# %% [markdown]
# ## Cell type and developmental stage metadata
#
# - Developmental stage: `time_zone`
# - Cell type:`cell_type`
# - Combination of cell type and developmental stage: `time_zone_cell_type`
# - Combination of cell type and developmental stage with cell subtypes (not used): `time_zone_cell_subtypes`

# %%
feature_names <- read_tsv("./data/features.tsv.gz", col_names = c("AGI", "Name", "Type")) %>%
  select(-Type) %>%
  distinct()
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   AGI = col_character(),
#   Name = col_character(),
#   Type = col_character()
# )

# %%
table(rc.integrated$genotype)
# Out:
#      df1     gtl1 gtl1_df1       WT
#    15678    22594    17634    18904

# %%
rc.integrated <- subset(rc.integrated, 
                        subset = sample %in% c("sc_122",
                                              "sc_123",
                                              "sc_124",
                                              "sc_125",
                                              "sc_126",
                                              "sc_127",
                                              "sc_128",
                                              "sc_129"))

# %%
rc.integrated$genotype <- factor(rc.integrated$genotype, 
                                 levels=c("WT", 
                                          "gtl1", 
                                          "df1", 
                                          "gtl1_df1"))

# %%
table(rc.integrated$genotype)
# Out:
#       WT     gtl1      df1 gtl1_df1
#    18904    22594    15678    17634

# %% [markdown]
# # Differential State Analysis with Muscat

# %%
# subset samples you want to compare

integrated.de <- subset(rc.integrated, subset = sample %in% c("sc_122", "sc_126","sc_124","sc_128"))
integrated.de$genotype <- factor(integrated.de$genotype, levels=c("WT", "df1"))

# %%
integrated.de
# Out:
# An object of class Seurat
# 70780 features across 34582 samples within 3 assays
# Active assay: integrated (17681 features, 17681 variable features)
#  2 other assays present: RNA, SCT
#  4 dimensional reductions calculated: pca, umap, umap_3D, umap_2D

# %% [markdown]
# ## Convert to sce

# %%
#  construct sce manually
my_metadata <- data.frame(sample_id = integrated.de$sample,
                              group_id = integrated.de$genotype,
                              cluster_id = integrated.de$time_zone_cell_type, 
                             rep=integrated.de$rep) # include experimental rep as co-variate

sce <- SingleCellExperiment(assays = list(counts = integrated.de@assays$RNA@counts),
	                            colData = my_metadata)

# %%
    (sce <- prepSCE(sce, 
        kid = "cluster_id", # subpopulation assignments
        gid = "group_id",   # group IDs (ctrl/stim)
        sid = "sample_id",    # sample IDs (ctrl/stim.1234)
        drop = FALSE))        # drop all other colData columns
# Out:
# class: SingleCellExperiment
# dim: 28688 34582
# metadata(1): experiment_info
# assays(1): counts
# rownames(28688): AT1G01010 AT1G01020 ... AT5G37474 AT5G07835
# rowData names(0):
# colnames(34582): AAACCCAAGAGCCGTA_4 AAACCCAAGCATTGTC_4 ...
#   TTTGTTGGTACGCTTA_10 TTTGTTGTCAGTGTTG_10
# colData names(4): cluster_id sample_id group_id rep
# reducedDimNames(0):
# altExpNames(0):

# %% [markdown]
# ## pre-filtering

# %%
# remove undetected genes
sce <- sce[rowSums(counts(sce) > 0) > 0, ]
dim(sce)
# Out:
# [1] 26296 34582

# %%
# remove lowly expressed genes
sce <- sce[rowSums(counts(sce) > 1) >= 1, ]
dim(sce)
# Out:
# [1] 21998 34582

# %%
# create pseudobulk profiles
pb <- aggregateData(sce,
    assay = "counts", fun = "sum",
    by = c("cluster_id", "sample_id"))
# one sheet per subpopulation
assayNames(pb)
# Out:
#  [1] "Distal Columella"
#  [2] "Distal Lateral Root Cap"
#  [3] "Elongation_Atrichoblast"
#  [4] "Elongation_Cortex"
#  [5] "Elongation_Endodermis"
#  [6] "Elongation_Pericycle"
#  [7] "Elongation_Phloem"
#  [8] "Elongation_Procambium"
#  [9] "Elongation_Trichoblast"
# [10] "Elongation_Xylem"
# [11] "Maturation_Atrichoblast"
# [12] "Maturation_Cortex"
# [13] "Maturation_Endodermis"
# [14] "Maturation_Pericycle"
# [15] "Maturation_Phloem"
# [16] "Maturation_Procambium"
# [17] "Maturation_Trichoblast"
# [18] "Maturation_Xylem"
# [19] "Proliferation Domain_Atrichoblast"
# [20] "Proliferation Domain_Cortex"
# [21] "Proliferation Domain_Endodermis"
# [22] "Proliferation Domain_Pericycle"
# [23] "Proliferation Domain_Quiescent Center"
# [24] "Proliferation Domain_Trichoblast"
# [25] "Proliferation Domain_Xylem"
# [26] "Proximal Columella"
# [27] "Proximal Lateral Root Cap"
# [28] "Transition Domain_Atrichoblast"
# [29] "Transition Domain_Cortex"
# [30] "Transition Domain_Pericycle"
# [31] "Transition Domain_Phloem"
# [32] "Transition Domain_Trichoblast"
# [33] "Transition Domain_Xylem"

# %%
# pseudobulks for 1st subpopulation
t(head(assay(pb)))
# Out:
#        AT1G01010 AT1G01020 AT1G01030 AT1G01040 AT1G01050 AT1G01060
# sc_122 37        32        12         9         862      6
# sc_124  8        20         5         5         478      1
# sc_126 26        41        17        12        1287      9
# sc_128 17        31        22         8         932      7

# %%
# metadata to manually add to DE contrast
bscs <- read.csv("./data/GEO_upload_BR_time_scRNA_samples_metadata_with_stats.csv", na.strings=c("","NA"), stringsAsFactors = F)
bscs$date <- gsub('^([0-9]{4})([0-9]{2})([0-9]+)$', '\\1-\\2-\\3', bscs$date)

# %%
# experiment info for contrasts, add rep from csv

ei <- metadata(sce)$experiment_info
ei

sample_date <- select(bscs, sample_id=sample, rep=rep)

ei <- left_join(ei, sample_date)

ei
# Out:
#   sample_id group_id n_cells
# 1 sc_122    WT       11614
# 2 sc_124    df1       9058
# 3 sc_126    WT        7290
# 4 sc_128    df1       6620
# Joining, by = "sample_id"
#   sample_id group_id n_cells rep
# 1 sc_122    WT       11614   1
# 2 sc_124    df1       9058   1
# 3 sc_126    WT        7290   2
# 4 sc_128    df1       6620   2

# %%
mm <- model.matrix(~ 0 + ei$group_id + ei$rep)
dimnames(mm) <- list(ei$sample_id, c(levels(ei$group_id), "rep"))

mm
# Out:
#        WT df1 rep
# sc_122 1  0   1
# sc_124 0  1   1
# sc_126 1  0   2
# sc_128 0  1   2

# %%
contrast <- makeContrasts("df1-WT", levels = mm)

contrast
# Out:
#       Contrasts
# Levels df1-WT
#    WT  -1
#    df1  1
#    rep  0

# %%
res <- pbDS(pb, design = mm, 
            contrast = contrast, 
            method="edgeR", 
            min_cells=5, 
            filter = c("none"))
# Out:
# Distal Columella..Distal Lateral Root Cap..Elongation_Atrichoblast..Elongation_Cortex..Elongation_Endodermis..Elongation_Pericycle..Elongation_Phloem..Elongation_Procambium..Elongation_Trichoblast..Elongation_Xylem..Maturation_Atrichoblast..Maturation_Cortex..Maturation_Endodermis..Maturation_Pericycle..Maturation_Phloem..Maturation_Procambium..Maturation_Trichoblast..Maturation_Xylem..Proliferation Domain_Atrichoblast..Proliferation Domain_Cortex..Proliferation Domain_Endodermis..Proliferation Domain_Pericycle..Proliferation Domain_Quiescent Center..Proliferation Domain_Trichoblast..Proliferation Domain_Xylem..Proximal Columella..Proximal Lateral Root Cap..Transition Domain_Atrichoblast..Transition Domain_Cortex..Transition Domain_Pericycle..Transition Domain_Phloem..Transition Domain_Trichoblast..Transition Domain_Xylem..

# %% [markdown]
# ### DEG results

# %%
# DEG results with gene freqs
(res_to_write_frq <- resDS(sce, res, bind = "row", cpm=TRUE, frq=T))
# Out:
#        gene      cluster_id                    sc_122.cpm sc_126.cpm sc_124.cpm
# 1      AT1G01010 Distal Columella               10.700      6.290      4.900
# 2      AT1G01020 Distal Columella                9.210      9.920     12.200
# 3      AT1G01030 Distal Columella                3.450      4.110      3.060
# 4      AT1G01040 Distal Columella                2.590      2.900      3.060
# 5      AT1G01050 Distal Columella              248.000    311.000    293.000
# 6      AT1G01060 Distal Columella                1.730      2.180      0.612
# 7      AT1G01070 Distal Columella                0.576      0.242      0.612
# 8      AT1G01080 Distal Columella                0.288      0.242      0.000
# 9      AT1G01090 Distal Columella               37.700     40.400     31.200
# 10     AT1G01100 Distal Columella              268.000    239.000    298.000
# 11     AT1G01110 Distal Columella                1.150      1.210      0.000
# 12     AT1G01120 Distal Columella                2.020      1.450      1.220
# 13     AT1G01130 Distal Columella                0.288      1.210      0.612
# 14     AT1G01140 Distal Columella               13.000     12.800      7.350
# 15     AT1G01160 Distal Columella               19.600     13.500     19.000
# 16     AT1G01170 Distal Columella                1.730      1.210      0.612
# 17     AT1G01180 Distal Columella               22.700     28.100     24.500
# 18     AT1G01200 Distal Columella                2.880      0.726      2.450
# 19     AT1G01210 Distal Columella                1.150      2.660      3.670
# 20     AT1G01220 Distal Columella                4.320      3.150      1.840
# 21     AT1G01225 Distal Columella                1.440      0.726      1.220
# 22     AT1G01230 Distal Columella               40.000     41.100     31.800
# 23     AT1G01240 Distal Columella               25.600     35.600     26.900
# 24     AT1G01260 Distal Columella               12.100     14.300     18.400
# 25     AT1G01290 Distal Columella                5.180      5.810      6.740
# 26     AT1G01300 Distal Columella                8.060      7.980     10.400
# 27     AT1G01310 Distal Columella                0.000      0.242      0.000
# 28     AT1G01320 Distal Columella                2.020      3.390      0.612
# 29     AT1G01340 Distal Columella                0.576      0.000      0.000
# 30     AT1G01350 Distal Columella               36.000     30.700     29.400
# ⋮      ⋮         ⋮                             ⋮          ⋮          ⋮
# 524115 ATCG01020 Transition Domain_Trichoblast 20.600      55.200     37.70
# 524116 ATCG01040 Transition Domain_Trichoblast  5.750      14.800     15.60
# 524117 ATCG01050 Transition Domain_Trichoblast  2.030       7.030     14.80
# 524118 ATCG01070 Transition Domain_Trichoblast  1.520       5.980      6.56
# 524119 ATCG01080 Transition Domain_Trichoblast  1.180       3.170      1.64
# 524120 ATCG01090 Transition Domain_Trichoblast  4.060       9.140      7.38
# 524121 ATCG01100 Transition Domain_Trichoblast  2.880      10.200     15.60
# 524122 ATCG01110 Transition Domain_Trichoblast  1.020       2.110      1.64
# 524123 ATCG01120 Transition Domain_Trichoblast  2.710       6.330      9.02
# 524124 ATCG01130 Transition Domain_Trichoblast 95.100     252.000    259.00
# 524125 AT1G04053 Transition Domain_Trichoblast  0.846       0.000      1.64
# 524126 AT1G12665 Transition Domain_Trichoblast  0.169       0.000      0.00
# 524127 AT1G49100 Transition Domain_Trichoblast  0.169       0.000      0.00
# 524128 AT1G52940 Transition Domain_Trichoblast  0.338       0.352      0.00
# 524129 AT5G03668 Transition Domain_Trichoblast  0.169       0.000      0.00
# 524130 AT5G26070 Transition Domain_Trichoblast  0.000       0.000      0.82
# 524131 AT3G03830 Transition Domain_Trichoblast  0.000       0.352      0.00
# 524132 AT2G08590 Transition Domain_Trichoblast  0.000       0.000      0.82
# 524133 AT4G36170 Transition Domain_Trichoblast  0.000       0.000      0.00
# 524134 AT5G63340 Transition Domain_Trichoblast  0.000       0.703      0.00
# 524135 AT4G05535 Transition Domain_Trichoblast  0.000       0.000      1.64
# 524136 AT2G25055 Transition Domain_Trichoblast  0.169       0.703      1.64
# 524137 AT3G22570 Transition Domain_Trichoblast  3.720       2.460      4.92
# 524138 AT3G32400 Transition Domain_Trichoblast  0.169       0.000      0.82
# 524139 AT3G43990 Transition Domain_Trichoblast 15.200       0.000      0.00
# 524140 AT4G04615 Transition Domain_Trichoblast  7.780       6.680      3.28
# 524141 AT5G25756 Transition Domain_Trichoblast  0.000       0.703      0.00
# 524142 ATCG00030 Transition Domain_Trichoblast 72.400     197.000    239.00
# 524143 AT4G20520 Transition Domain_Trichoblast  0.000       0.703      0.00
# 524144 AT4G36370 Transition Domain_Trichoblast  0.000       0.000      0.00
#        sc_128.cpm sc_122.frq sc_126.frq sc_124.frq sc_128.frq WT.frq   df1.frq
# 1        4.860    0.06100    0.05040    0.03470    0.04140    0.055900 0.03900
# 2        8.860    0.05570    0.07170    0.09410    0.07730    0.063400 0.08330
# 3        6.280    0.01970    0.03290    0.01980    0.05250    0.026100 0.04080
# 4        2.290    0.01620    0.01940    0.02480    0.02210    0.017700 0.02300
# 5      266.000    0.69300    0.77900    0.83700    0.75700    0.734000 0.78500
# 6        2.000    0.01080    0.01740    0.00495    0.01930    0.014000 0.01420
# 7        0.000    0.00359    0.00194    0.00495    0.00000    0.002800 0.00177
# 8        0.857    0.00180    0.00194    0.00000    0.00829    0.001860 0.00532
# 9       35.400    0.19600    0.26400    0.18800    0.26000    0.228000 0.23400
# 10     325.000    0.68000    0.67600    0.76200    0.70400    0.678000 0.72500
# 11       2.570    0.00718    0.00969    0.00000    0.02210    0.008390 0.01420
# 12       0.286    0.01080    0.01160    0.00495    0.00276    0.011200 0.00355
# 13       0.286    0.00180    0.00775    0.00495    0.00276    0.004660 0.00355
# 14       3.430    0.07900    0.10100    0.05940    0.03310    0.089500 0.04260
# 15      18.600    0.11100    0.09880    0.11900    0.16300    0.105000 0.14700
# 16       2.290    0.01080    0.00969    0.00495    0.01930    0.010300 0.01420
# 17      22.000    0.11700    0.19000    0.17300    0.18000    0.152000 0.17700
# 18       0.286    0.01800    0.00581    0.01980    0.00276    0.012100 0.00887
# 19       0.857    0.00718    0.01740    0.02480    0.00552    0.012100 0.01240
# 20       2.860    0.02690    0.02520    0.01490    0.02760    0.026100 0.02300
# 21       1.140    0.00898    0.00581    0.00990    0.01100    0.007460 0.01060
# 22      38.600    0.22100    0.27300    0.21300    0.30400    0.246000 0.27100
# 23      31.700    0.14400    0.24400    0.17800    0.25400    0.192000 0.22700
# 24      16.900    0.06460    0.10500    0.13400    0.15200    0.083900 0.14500
# 25       4.000    0.03230    0.04460    0.04950    0.03590    0.038200 0.04080
# 26       9.140    0.04670    0.06200    0.08420    0.08290    0.054100 0.08330
# 27       0.286    0.00000    0.00194    0.00000    0.00276    0.000932 0.00177
# 28       2.860    0.01260    0.02710    0.00495    0.02760    0.019600 0.01950
# 29       0.286    0.00359    0.00000    0.00000    0.00276    0.001860 0.00177
# 30      31.100    0.19900    0.21300    0.21800    0.25400    0.206000 0.24100
# ⋮      ⋮          ⋮          ⋮          ⋮          ⋮          ⋮        ⋮
# 524115  64.100    0.25200    0.37300    0.13800    0.37100    0.29900  0.22800
# 524116  22.500    0.09610    0.17000    0.09050    0.26500    0.12500  0.15800
# 524117   8.800    0.03600    0.09430    0.08100    0.10600    0.05870  0.09060
# 524118   8.310    0.02700    0.08020    0.03810    0.11400    0.04770  0.06730
# 524119   5.380    0.02100    0.04250    0.00952    0.06060    0.02940  0.02920
# 524120  21.500    0.06310    0.10400    0.04290    0.22000    0.07890  0.11100
# 524121  11.200    0.04800    0.12300    0.08100    0.12100    0.07710  0.09650
# 524122   0.489    0.01800    0.02360    0.00952    0.00758    0.02020  0.00877
# 524123   8.310    0.04200    0.08020    0.03810    0.12100    0.05690  0.07020
# 524124 344.000    0.58000    0.59400    0.46200    0.65200    0.58500  0.53500
# 524125   0.489    0.01500    0.00000    0.00952    0.00758    0.00917  0.00877
# 524126   0.000    0.00300    0.00000    0.00000    0.00000    0.00183  0.00000
# 524127   0.000    0.00300    0.00000    0.00000    0.00000    0.00183  0.00000
# 524128   0.000    0.00601    0.00472    0.00000    0.00000    0.00550  0.00000
# 524129   0.000    0.00300    0.00000    0.00000    0.00000    0.00183  0.00000
# 524130   0.000    0.00000    0.00000    0.00476    0.00000    0.00000  0.00292
# 524131   0.000    0.00000    0.00472    0.00000    0.00000    0.00183  0.00000
# 524132   0.000    0.00000    0.00000    0.00476    0.00000    0.00000  0.00292
# 524133   0.489    0.00000    0.00000    0.00000    0.00758    0.00000  0.00292
# 524134   0.000    0.00000    0.00943    0.00000    0.00000    0.00367  0.00000
# 524135   0.000    0.00000    0.00000    0.00476    0.00000    0.00000  0.00292
# 524136   0.978    0.00300    0.00943    0.00952    0.01520    0.00550  0.01170
# 524137   3.910    0.06310    0.03300    0.02380    0.04550    0.05140  0.03220
# 524138   0.000    0.00300    0.00000    0.00476    0.00000    0.00183  0.00292
# 524139   0.000    0.21000    0.00000    0.00000    0.00000    0.12800  0.00000
# 524140   3.910    0.12600    0.08490    0.01900    0.05300    0.11000  0.03220
# 524141   0.000    0.00000    0.00943    0.00000    0.00000    0.00367  0.00000
# 524142 276.000    0.54400    0.60400    0.42900    0.65200    0.56700  0.51500
# 524143   0.000    0.00000    0.00943    0.00000    0.00000    0.00367  0.00000
# 524144   0.489    0.00000    0.00000    0.00000    0.00758    0.00000  0.00292
#        logFC    logCPM  F        p_val    p_adj.loc p_adj.glb contrast
# 1      -0.69400  2.9100 3.49e+00 6.19e-02 0.53900   1         df1-WT
# 2       0.08750  3.3800 8.36e-02 7.73e-01 0.98400   1         df1-WT
# 3       0.34700  2.3200 5.66e-01 4.52e-01 0.95300   1         df1-WT
# 4      -0.09930  1.7200 2.56e-02 8.73e-01 0.98400   1         df1-WT
# 5       0.00032  8.1300 4.44e-06 9.98e-01 1.00000   1         df1-WT
# 6      -0.46800  1.2800 3.15e-01 5.75e-01 0.95300   1         df1-WT
# 7      -0.66000 -0.0846 7.49e-02 7.84e-01 0.98400   1         df1-WT
# 8       0.84700  0.0278 1.72e-01 6.78e-01 0.96400   1         df1-WT
# 9      -0.22500  5.2200 1.34e+00 2.48e-01 0.92100   1         df1-WT
# 10      0.29800  8.1400 3.85e+00 4.97e-02 0.48200   1         df1-WT
# 11      0.27700  1.0200 8.21e-02 7.74e-01 0.98400   1         df1-WT
# 12     -1.37000  0.9130 1.45e+00 2.28e-01 0.90000   1         df1-WT
# 13     -0.99900  0.3260 3.53e-01 5.52e-01 0.95300   1         df1-WT
# 14     -1.39000  3.3300 1.72e+01 3.44e-05 0.00214   1         df1-WT
# 15      0.22800  4.1800 9.08e-01 3.41e-01 0.95300   1         df1-WT
# 16      0.16300  1.1300 3.39e-02 8.54e-01 0.98400   1         df1-WT
# 17     -0.15600  4.6400 5.24e-01 4.69e-01 0.95300   1         df1-WT
# 18     -0.51500  1.0400 2.62e-01 6.09e-01 0.95300   1         df1-WT
# 19     -0.07980  1.3300 1.07e-02 9.17e-01 0.99100   1         df1-WT
# 20     -0.54000  1.9400 9.00e-01 3.43e-01 0.95300   1         df1-WT
# 21      0.22700  0.7900 4.20e-02 8.38e-01 0.98400   1         df1-WT
# 22     -0.19500  5.2900 1.02e+00 3.12e-01 0.95300   1         df1-WT
# 23     -0.06760  4.9500 1.10e-01 7.40e-01 0.97800   1         df1-WT
# 24      0.39200  3.9700 2.42e+00 1.20e-01 0.72900   1         df1-WT
# 25     -0.13100  2.5600 1.00e-01 7.51e-01 0.97800   1         df1-WT
# 26      0.26800  3.2200 7.12e-01 3.99e-01 0.95300   1         df1-WT
# 27      0.19200 -0.3510 3.94e-03 9.50e-01 0.99100   1         df1-WT
# 28     -0.54800  1.6400 6.63e-01 4.16e-01 0.95300   1         df1-WT
# 29     -0.15800 -0.2120 3.20e-03 9.55e-01 0.99100   1         df1-WT
# 30     -0.11900  5.0300 3.50e-01 5.54e-01 0.95300   1         df1-WT
# ⋮      ⋮        ⋮       ⋮        ⋮        ⋮         ⋮         ⋮
# 524115  0.514    5.480   2.6400  1.04e-01 0.98800   1.000     df1-WT
# 524116  0.963    3.850   7.1600  7.46e-03 0.38900   1.000     df1-WT
# 524117  1.500    2.900  10.8000  1.01e-03 0.14000   1.000     df1-WT
# 524118  1.120    2.460   4.2300  3.97e-02 0.78800   1.000     df1-WT
# 524119  0.659    1.700   0.6920  4.06e-01 0.98800   1.000     df1-WT
# 524120  1.090    3.400   7.1500  7.50e-03 0.38900   1.000     df1-WT
# 524121  1.180    3.230   8.0500  4.55e-03 0.31500   1.000     df1-WT
# 524122 -0.628    0.950   0.2160  6.42e-01 0.98800   1.000     df1-WT
# 524123  0.998    2.690   4.1900  4.06e-02 0.78800   1.000     df1-WT
# 524124  0.942    7.890   8.5800  3.40e-03 0.27700   1.000     df1-WT
# 524125  1.320    0.408   0.4720  4.92e-01 0.98800   1.000     df1-WT
# 524126 -1.410   -0.425   0.0854  7.70e-01 0.98800   1.000     df1-WT
# 524127 -1.410   -0.425   0.0854  7.70e-01 0.98800   1.000     df1-WT
# 524128 -3.220   -0.139   0.4960  4.81e-01 0.98800   1.000     df1-WT
# 524129 -1.410   -0.425   0.0854  7.70e-01 0.98800   1.000     df1-WT
# 524130  3.700   -0.404   0.7850  3.76e-01 0.98800   1.000     df1-WT
# 524131 -2.600   -0.412   0.2420  6.22e-01 0.98800   1.000     df1-WT
# 524132  3.700   -0.404   0.7850  3.76e-01 0.98800   1.000     df1-WT
# 524133  2.530   -0.408   0.3870  5.34e-01 0.98800   1.000     df1-WT
# 524134 -3.490   -0.255   0.5160  4.72e-01 0.98800   1.000     df1-WT
# 524135  4.680   -0.239   1.6600  1.98e-01 0.98800   1.000     df1-WT
# 524136  1.610    0.363   0.7400  3.90e-01 0.98800   1.000     df1-WT
# 524137  0.519    2.090   0.6660  4.15e-01 0.98800   1.000     df1-WT
# 524138  1.850   -0.260   0.2630  6.08e-01 0.98800   1.000     df1-WT
# 524139 -7.100    2.670  23.5000  1.28e-06 0.00118   0.666     df1-WT
# 524140 -0.974    2.730   3.3700  6.65e-02 0.93900   1.000     df1-WT
# 524141 -3.490   -0.255   0.5160  4.72e-01 0.98800   1.000     df1-WT
# 524142  1.090    7.610  11.7000  6.39e-04 0.10600   1.000     df1-WT
# 524143 -3.490   -0.255   0.5160  4.72e-01 0.98800   1.000     df1-WT
# 524144  2.530   -0.408   0.3870  5.34e-01 0.98800   1.000     df1-WT

# %%
## all genes background 

all_bg <- filter(res_to_write_frq,
                WT.frq >=0.1 | df1.frq >=0.1)

# %%
length(unique(all_bg$gene))
# Out:
# [1] 17075

# %%
#total DE genes p_adj.loc < 0.05, abs(logFC) > 1.5
sig_DE <- filter(res_to_write_frq, p_adj.loc<=0.05 & abs(logFC) > log2(1.5))
sig_DE <- left_join(sig_DE, feature_names, by=c("gene"="AGI"))

length(unique(sig_DE$gene))
# Out:
# [1] 2997

# %%
# filter gene freqs to avoid calling lowly detected genes
sig_DE_fil <- filter(sig_DE, WT.frq >=0.1 | df1.frq >=0.1)

# %%
length(unique(sig_DE_fil$gene))
# Out:
# [1] 2397

# %%
# load TFs
TF_list <- read_csv("./data/Kay_TF_thalemine_annotations.csv", col_names = c("gene", "TF_Name", "Description"))
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   gene = col_character(),
#   TF_Name = col_character(),
#   Description = col_character()
# )

# %%
sig_DE_fil <- left_join(sig_DE_fil, TF_list)
# Out:
# Joining, by = "gene"

# %%
# label up vs down
sig_DE_fil <- sig_DE_fil %>%
  mutate(up_dn_label = case_when(logFC >=log2(1.5) ~ "Up",  
                                       logFC <=log2(1/1.5) ~ "Down",
                                       TRUE ~ "Not DE"))

sig_DE_fil$clust_up_dn <- paste(sig_DE_fil$cluster_id, sig_DE_fil$up_dn_label, sep="_")

sig_DE_fil
# Out:
#      gene      cluster_id                    sc_122.cpm sc_126.cpm sc_124.cpm
# 1    AT1G02360 Distal Columella               38.30      57.60      82.00
# 2    AT1G03475 Distal Columella               17.00      21.30      28.20
# 3    AT1G03850 Distal Columella               35.40      39.20      26.30
# 4    AT1G03870 Distal Columella              163.00     100.00      53.30
# 5    AT1G05060 Distal Columella               20.40      30.70      47.10
# 6    AT1G05260 Distal Columella               45.80      40.60      20.80
# 7    AT1G05340 Distal Columella               87.50      83.20      56.30
# 8    AT1G05575 Distal Columella               47.20      82.70     108.00
# 9    AT1G05870 Distal Columella               22.70      27.60      11.00
# 10   AT1G06080 Distal Columella               10.70      15.20      69.20
# 11   AT1G06620 Distal Columella              130.00     136.00     201.00
# 12   AT1G06640 Distal Columella               28.50      23.50      18.40
# 13   AT1G07135 Distal Columella               74.00      60.20      88.20
# 14   AT1G07400 Distal Columella               47.80      34.40       8.57
# 15   AT1G07750 Distal Columella               62.20      54.70      31.20
# 16   AT1G08500 Distal Columella               28.50      19.40      10.40
# 17   AT1G10200 Distal Columella               40.60      41.40      25.70
# 18   AT1G10530 Distal Columella               32.20      55.20      24.50
# 19   AT1G10990 Distal Columella               11.20      19.10      25.70
# 20   AT1G11670 Distal Columella              187.00     113.00     252.00
# 21   AT1G11960 Distal Columella               32.20      23.50      37.30
# 22   AT1G12090 Distal Columella              198.00     143.00      89.40
# 23   AT1G12560 Distal Columella               12.10      20.30      13.50
# 24   AT1G12610 Distal Columella               41.20      20.30      42.90
# 25   AT1G12740 Distal Columella              398.00     328.00     642.00
# 26   AT1G13930 Distal Columella              173.00      99.40      61.20
# 27   AT1G17340 Distal Columella               44.30      41.60      71.00
# 28   AT1G17380 Distal Columella                8.06       3.87      11.60
# 29   AT1G18740 Distal Columella               54.70      30.50      60.00
# 30   AT1G20010 Distal Columella               38.00      27.60      17.80
# ⋮    ⋮         ⋮                             ⋮          ⋮          ⋮
# 4371 AT3G20340 Transition Domain_Trichoblast 130.00     108.00      62.30
# 4372 AT3G22540 Transition Domain_Trichoblast  29.80      20.80      14.80
# 4373 AT3G22740 Transition Domain_Trichoblast  15.70      14.40      41.00
# 4374 AT3G23605 Transition Domain_Trichoblast 102.00      63.00      36.10
# 4375 AT3G44860 Transition Domain_Trichoblast 353.00     223.00     153.00
# 4376 AT3G49550 Transition Domain_Trichoblast  25.20      15.10      12.30
# 4377 AT3G53650 Transition Domain_Trichoblast 386.00     179.00      82.00
# 4378 AT2G01021 Transition Domain_Trichoblast  50.90     109.00     242.00
# 4379 AT2G02130 Transition Domain_Trichoblast  54.00      16.90     166.00
# 4380 AT2G20880 Transition Domain_Trichoblast  43.10      22.50      20.50
# 4381 AT2G34600 Transition Domain_Trichoblast 106.00      65.80      31.10
# 4382 AT2G34880 Transition Domain_Trichoblast   0.00      70.00       0.00
# 4383 AT2G36100 Transition Domain_Trichoblast 252.00      34.80      72.10
# 4384 AT2G37470 Transition Domain_Trichoblast 329.00     138.00      67.20
# 4385 AT2G40890 Transition Domain_Trichoblast  11.50       8.44      39.30
# 4386 AT2G46410 Transition Domain_Trichoblast 105.00      62.60      35.20
# 4387 AT2G47770 Transition Domain_Trichoblast  20.00      18.30      11.50
# 4388 AT4G04745 Transition Domain_Trichoblast 180.00     131.00      59.00
# 4389 AT4G21840 Transition Domain_Trichoblast 222.00      96.40      56.60
# 4390 AT4G22360 Transition Domain_Trichoblast  22.80      16.50       6.56
# 4391 AT4G25820 Transition Domain_Trichoblast  62.40      38.30      54.90
# 4392 AT4G28240 Transition Domain_Trichoblast 179.00     111.00      57.40
# 4393 AT4G32480 Transition Domain_Trichoblast 220.00     156.00     102.00
# 4394 AT4G33467 Transition Domain_Trichoblast 189.00      86.50      55.70
# 4395 AT4G34800 Transition Domain_Trichoblast 144.00      73.90      41.00
# 4396 ATMG01320 Transition Domain_Trichoblast  15.60      28.10      46.70
# 4397 ATCG00150 Transition Domain_Trichoblast   1.35       5.98      13.10
# 4398 ATCG00450 Transition Domain_Trichoblast   0.00       0.00       0.00
# 4399 ATCG00680 Transition Domain_Trichoblast   4.40       7.39      20.50
# 4400 AT3G43990 Transition Domain_Trichoblast  15.20       0.00       0.00
#      sc_128.cpm sc_122.frq sc_126.frq sc_124.frq sc_128.frq ⋯ F     p_val
# 1     91.10     0.1560     0.2330     0.3070     0.3150     ⋯  24.7 6.67e-07
# 2     36.30     0.0969     0.1550     0.1780     0.2730     ⋯  12.5 4.03e-04
# 3     12.60     0.1830     0.2230     0.1730     0.0967     ⋯  24.6 7.30e-07
# 4     94.80     0.4690     0.4840     0.2920     0.3400     ⋯  21.2 4.08e-06
# 5     48.30     0.1010     0.1690     0.1980     0.2600     ⋯  20.8 5.23e-06
# 6     10.90     0.1510     0.1670     0.1530     0.0663     ⋯  49.7 1.90e-12
# 7     35.70     0.4040     0.4320     0.3610     0.2540     ⋯  28.6 9.01e-08
# 8    104.00     0.1440     0.2110     0.2820     0.2850     ⋯  18.8 1.45e-05
# 9     12.90     0.1150     0.1740     0.0842     0.1050     ⋯  19.7 9.14e-06
# 10    53.40     0.0503     0.0853     0.3660     0.2790     ⋯ 113.0 2.52e-26
# 11   212.00     0.4870     0.5230     0.7080     0.6550     ⋯  16.9 4.01e-05
# 12    12.90     0.1620     0.1690     0.1440     0.1080     ⋯  10.8 1.00e-03
# 13   138.00     0.1780     0.1590     0.2770     0.2400     ⋯  20.8 5.18e-06
# 14    40.60     0.1260     0.1300     0.0446     0.1240     ⋯  10.7 1.05e-03
# 15    25.70     0.3090     0.3370     0.2080     0.2240     ⋯  29.5 5.76e-08
# 16    14.00     0.1510     0.1410     0.0792     0.1190     ⋯  12.7 3.65e-04
# 17    22.00     0.2140     0.2830     0.1880     0.1770     ⋯  15.4 8.60e-05
# 18    27.40     0.1490     0.2170     0.1530     0.1960     ⋯  14.3 1.53e-04
# 19    29.10     0.0610     0.1300     0.1630     0.2100     ⋯  13.8 2.04e-04
# 20   279.00     0.4880     0.3970     0.6240     0.5830     ⋯  31.5 2.07e-08
# 21    48.30     0.1740     0.1570     0.2380     0.3290     ⋯  11.5 7.11e-04
# 22    94.00     0.5750     0.5850     0.4800     0.4590     ⋯  28.7 8.41e-08
# 23     5.71     0.0610     0.1430     0.0990     0.0525     ⋯  11.0 9.26e-04
# 24   102.00     0.1150     0.0853     0.1490     0.2070     ⋯  45.5 1.58e-11
# 25   546.00     0.7760     0.7540     0.9360     0.8650     ⋯  22.3 2.36e-06
# 26    57.40     0.6070     0.4960     0.3560     0.4030     ⋯  45.0 1.98e-11
# 27    78.30     0.2260     0.2600     0.3510     0.4140     ⋯  20.8 5.11e-06
# 28    17.40     0.0413     0.0291     0.0743     0.1220     ⋯  20.5 5.87e-06
# 29    82.60     0.2280     0.1800     0.2570     0.2980     ⋯  20.8 5.19e-06
# 30    14.00     0.1920     0.1940     0.1340     0.1240     ⋯  21.4 3.71e-06
# ⋮    ⋮          ⋮          ⋮          ⋮          ⋮          ⋱ ⋮     ⋮
# 4371  32.80     0.4410     0.4620     0.2760     0.2350     ⋯  19.0 1.32e-05
# 4372   4.89     0.1860     0.1650     0.0857     0.0758     ⋯  15.6 7.84e-05
# 4373  33.30     0.1320     0.1560     0.1620     0.1670     ⋯  15.7 7.38e-05
# 4374  32.30     0.4260     0.3440     0.1620     0.2200     ⋯  14.5 1.37e-04
# 4375  76.30     0.6700     0.6460     0.4950     0.4850     ⋯  18.2 2.03e-05
# 4376   3.42     0.2280     0.1130     0.0714     0.0455     ⋯  14.2 1.64e-04
# 4377  48.40     0.4380     0.4620     0.2330     0.3260     ⋯  38.9 4.60e-10
# 4378 138.00     0.5350     0.7450     0.6760     0.7650     ⋯  16.0 6.34e-05
# 4379 115.00     0.2160     0.1040     0.1950     0.1290     ⋯  44.4 2.77e-11
# 4380   5.87     0.2160     0.1790     0.1140     0.0758     ⋯  16.0 6.51e-05
# 4381  22.00     0.2970     0.2030     0.1330     0.1440     ⋯  25.8 3.78e-07
# 4382   0.00     0.0000     0.4580     0.0000     0.0000     ⋯  92.3 8.42e-22
# 4383  11.20     0.3330     0.2880     0.2330     0.1360     ⋯  25.9 3.56e-07
# 4384  30.30     0.4170     0.4290     0.2670     0.2730     ⋯  45.4 1.62e-11
# 4385  13.70     0.1530     0.0849     0.1520     0.0909     ⋯  14.3 1.59e-04
# 4386  31.80     0.3960     0.3110     0.1570     0.3030     ⋯  15.6 7.90e-05
# 4387   3.42     0.1920     0.1560     0.0476     0.0455     ⋯  14.2 1.64e-04
# 4388  44.00     0.4500     0.4250     0.2240     0.3330     ⋯  24.8 6.57e-07
# 4389  30.30     0.4440     0.3070     0.2380     0.2580     ⋯  31.4 2.09e-08
# 4390   4.89     0.2550     0.1460     0.0381     0.0606     ⋯  18.8 1.44e-05
# 4391   2.45     0.3150     0.3770     0.2760     0.0379     ⋯  15.9 6.61e-05
# 4392  43.50     0.4290     0.3580     0.2380     0.2580     ⋯  22.1 2.56e-06
# 4393  56.70     0.6010     0.5470     0.3570     0.3330     ⋯  16.4 5.28e-05
# 4394  46.50     0.4590     0.4340     0.2520     0.3480     ⋯  17.3 3.21e-05
# 4395  48.40     0.4350     0.3070     0.2000     0.3710     ⋯  13.9 1.92e-04
# 4396  51.40     0.1950     0.2450     0.2000     0.2880     ⋯  14.5 1.41e-04
# 4397  13.20     0.0240     0.0660     0.0619     0.1740     ⋯  19.4 1.05e-05
# 4398 140.00     0.0000     0.0000     0.0000     0.6360     ⋯ 134.0 6.49e-31
# 4399  12.70     0.0661     0.0991     0.0952     0.1360     ⋯  14.6 1.34e-04
# 4400   0.00     0.2100     0.0000     0.0000     0.0000     ⋯  23.5 1.28e-06
#      p_adj.loc p_adj.glb contrast Name      TF_Name
# 1    8.12e-05  3.49e-01  df1-WT   AT1G02360 NA
# 2    1.64e-02  1.00e+00  df1-WT   CPX1      NA
# 3    8.73e-05  3.82e-01  df1-WT   AT1G03850 NA
# 4    3.69e-04  1.00e+00  df1-WT   FLA9      NA
# 5    4.51e-04  1.00e+00  df1-WT   AT1G05060 NA
# 6    8.60e-10  9.94e-07  df1-WT   PER3      NA
# 7    1.42e-05  4.71e-02  df1-WT   AT1G05340 NA
# 8    1.06e-03  1.00e+00  df1-WT   AT1G05575 NA
# 9    7.15e-04  1.00e+00  df1-WT   AT1G05870 NA
# 10   5.45e-23  1.32e-20  df1-WT   ADS1      NA
# 11   2.40e-03  1.00e+00  df1-WT   AT1G06620 NA
# 12   3.34e-02  1.00e+00  df1-WT   AT1G06640 NA
# 13   4.50e-04  1.00e+00  df1-WT   AT1G07135 NA
# 14   3.48e-02  1.00e+00  df1-WT   HSP17.8   NA
# 15   9.44e-06  3.02e-02  df1-WT   AT1G07750 NA
# 16   1.51e-02  1.00e+00  df1-WT   ENODL18   NA
# 17   4.41e-03  1.00e+00  df1-WT   WLIM1     WLIM1
# 18   7.28e-03  1.00e+00  df1-WT   AT1G10530 NA
# 19   9.47e-03  1.00e+00  df1-WT   AT1G10990 NA
# 20   4.05e-06  1.08e-02  df1-WT   DTX36     NA
# 21   2.57e-02  1.00e+00  df1-WT   AT1G11960 NA
# 22   1.33e-05  4.40e-02  df1-WT   ELP       NA
# 23   3.16e-02  1.00e+00  df1-WT   EXPA7     NA
# 24   6.04e-09  8.29e-06  df1-WT   DREB1F    DDF1
# 25   2.35e-04  1.00e+00  df1-WT   CYP87A2   NA
# 26   7.41e-09  1.04e-05  df1-WT   AT1G13930 NA
# 27   4.48e-04  1.00e+00  df1-WT   SAC5      NA
# 28   4.99e-04  1.00e+00  df1-WT   TIFY11A   JAZ5
# 29   4.50e-04  1.00e+00  df1-WT   AT1G18740 NA
# 30   3.37e-04  1.00e+00  df1-WT   TUBB5     NA
# ⋮    ⋮         ⋮         ⋮        ⋮         ⋮
# 4371 7.21e-03  1.00e+00  df1-WT   AT3G20340 NA
# 4372 2.44e-02  1.00e+00  df1-WT   AT3G22540 NA
# 4373 2.40e-02  1.00e+00  df1-WT   HMT3      NA
# 4374 3.82e-02  1.00e+00  df1-WT   PUX12     NA
# 4375 1.01e-02  1.00e+00  df1-WT   FAMT      NA
# 4376 4.32e-02  1.00e+00  df1-WT   AT3G49550 NA
# 4377 1.12e-06  2.41e-04  df1-WT   AT3G53650 NA
# 4378 2.21e-02  1.00e+00  df1-WT   AT2G01021 NA
# 4379 9.00e-08  1.45e-05  df1-WT   PDF2.3    NA
# 4380 2.22e-02  1.00e+00  df1-WT   ERF053    ERF53
# 4381 4.10e-04  1.98e-01  df1-WT   TIFY 5B   JAZ7
# 4382 5.47e-18  4.41e-16  df1-WT   JMJ15     MEE27
# 4383 4.08e-04  1.86e-01  df1-WT   CASP1     NA
# 4384 7.68e-08  8.50e-06  df1-WT   AT2G37470 NA
# 4385 4.31e-02  1.00e+00  df1-WT   CYP98A3   NA
# 4386 2.44e-02  1.00e+00  df1-WT   CPC       CPC
# 4387 4.32e-02  1.00e+00  df1-WT   TSPO      NA
# 4388 6.74e-04  3.44e-01  df1-WT   AT4G04745 NA
# 4389 4.07e-05  1.09e-02  df1-WT   MSRB8     NA
# 4390 7.57e-03  1.00e+00  df1-WT   AT4G22360 AT4G22360
# 4391 2.22e-02  1.00e+00  df1-WT   XTH14     NA
# 4392 2.08e-03  1.00e+00  df1-WT   AT4G28240 NA
# 4393 1.94e-02  1.00e+00  df1-WT   AT4G32480 NA
# 4394 1.28e-02  1.00e+00  df1-WT   AT4G33467 NA
# 4395 4.80e-02  1.00e+00  df1-WT   AT4G34800 NA
# 4396 3.88e-02  1.00e+00  df1-WT   NAD2B     NA
# 4397 6.37e-03  1.00e+00  df1-WT   ATPI      NA
# 4398 6.33e-27  3.40e-25  df1-WT   TRNV.1    NA
# 4399 3.79e-02  1.00e+00  df1-WT   PSBB      NA
# 4400 1.18e-03  6.66e-01  df1-WT   AT3G43990 NA
#      Description
# 1    NA
# 2    NA
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   NA
# 14   NA
# 15   NA
# 16   NA
# 17   GATA type zinc finger transcription factor family protein
# 18   NA
# 19   NA
# 20   NA
# 21   NA
# 22   NA
# 23   NA
# 24   Integrase-type DNA-binding superfamily protein
# 25   NA
# 26   NA
# 27   NA
# 28   jasmonate-zim-domain protein 5
# 29   NA
# 30   NA
# ⋮    ⋮
# 4371 NA
# 4372 NA
# 4373 NA
# 4374 NA
# 4375 NA
# 4376 NA
# 4377 NA
# 4378 NA
# 4379 NA
# 4380 Integrase-type DNA-binding superfamily protein
# 4381 jasmonate-zim-domain protein 7
# 4382 Transcription factor jumonji (jmj) family protein / zinc finger (C5HC2 type) family protein
# 4383 NA
# 4384 NA
# 4385 NA
# 4386 Homeodomain-like superfamily protein
# 4387 NA
# 4388 NA
# 4389 NA
# 4390 SWIB complex BAF60b domain-containing protein
# 4391 NA
# 4392 NA
# 4393 NA
# 4394 NA
# 4395 NA
# 4396 NA
# 4397 NA
# 4398 NA
# 4399 NA
# 4400 NA
#      up_dn_label clust_up_dn
# 1    Up          Distal Columella_Up
# 2    Up          Distal Columella_Up
# 3    Down        Distal Columella_Down
# 4    Down        Distal Columella_Down
# 5    Up          Distal Columella_Up
# 6    Down        Distal Columella_Down
# 7    Down        Distal Columella_Down
# 8    Up          Distal Columella_Up
# 9    Down        Distal Columella_Down
# 10   Up          Distal Columella_Up
# 11   Up          Distal Columella_Up
# 12   Down        Distal Columella_Down
# 13   Up          Distal Columella_Up
# 14   Down        Distal Columella_Down
# 15   Down        Distal Columella_Down
# 16   Down        Distal Columella_Down
# 17   Down        Distal Columella_Down
# 18   Down        Distal Columella_Down
# 19   Up          Distal Columella_Up
# 20   Up          Distal Columella_Up
# 21   Up          Distal Columella_Up
# 22   Down        Distal Columella_Down
# 23   Down        Distal Columella_Down
# 24   Up          Distal Columella_Up
# 25   Up          Distal Columella_Up
# 26   Down        Distal Columella_Down
# 27   Up          Distal Columella_Up
# 28   Up          Distal Columella_Up
# 29   Up          Distal Columella_Up
# 30   Down        Distal Columella_Down
# ⋮    ⋮           ⋮
# 4371 Down        Transition Domain_Trichoblast_Down
# 4372 Down        Transition Domain_Trichoblast_Down
# 4373 Up          Transition Domain_Trichoblast_Up
# 4374 Down        Transition Domain_Trichoblast_Down
# 4375 Down        Transition Domain_Trichoblast_Down
# 4376 Down        Transition Domain_Trichoblast_Down
# 4377 Down        Transition Domain_Trichoblast_Down
# 4378 Up          Transition Domain_Trichoblast_Up
# 4379 Up          Transition Domain_Trichoblast_Up
# 4380 Down        Transition Domain_Trichoblast_Down
# 4381 Down        Transition Domain_Trichoblast_Down
# 4382 Down        Transition Domain_Trichoblast_Down
# 4383 Down        Transition Domain_Trichoblast_Down
# 4384 Down        Transition Domain_Trichoblast_Down
# 4385 Up          Transition Domain_Trichoblast_Up
# 4386 Down        Transition Domain_Trichoblast_Down
# 4387 Down        Transition Domain_Trichoblast_Down
# 4388 Down        Transition Domain_Trichoblast_Down
# 4389 Down        Transition Domain_Trichoblast_Down
# 4390 Down        Transition Domain_Trichoblast_Down
# 4391 Down        Transition Domain_Trichoblast_Down
# 4392 Down        Transition Domain_Trichoblast_Down
# 4393 Down        Transition Domain_Trichoblast_Down
# 4394 Down        Transition Domain_Trichoblast_Down
# 4395 Down        Transition Domain_Trichoblast_Down
# 4396 Up          Transition Domain_Trichoblast_Up
# 4397 Up          Transition Domain_Trichoblast_Up
# 4398 Up          Transition Domain_Trichoblast_Up
# 4399 Up          Transition Domain_Trichoblast_Up
# 4400 Down        Transition Domain_Trichoblast_Down

# %%
sig_DE_fil
write.csv(sig_DE_fil, file = "./output/v4_df1_v_WT_cell_time_EdgeR_q0.05_FC1.5_r_v_4_20220121.csv")
# Out:
#      gene      cluster_id                    sc_122.cpm sc_126.cpm sc_124.cpm
# 1    AT1G02360 Distal Columella               38.30      57.60      82.00
# 2    AT1G03475 Distal Columella               17.00      21.30      28.20
# 3    AT1G03850 Distal Columella               35.40      39.20      26.30
# 4    AT1G03870 Distal Columella              163.00     100.00      53.30
# 5    AT1G05060 Distal Columella               20.40      30.70      47.10
# 6    AT1G05260 Distal Columella               45.80      40.60      20.80
# 7    AT1G05340 Distal Columella               87.50      83.20      56.30
# 8    AT1G05575 Distal Columella               47.20      82.70     108.00
# 9    AT1G05870 Distal Columella               22.70      27.60      11.00
# 10   AT1G06080 Distal Columella               10.70      15.20      69.20
# 11   AT1G06620 Distal Columella              130.00     136.00     201.00
# 12   AT1G06640 Distal Columella               28.50      23.50      18.40
# 13   AT1G07135 Distal Columella               74.00      60.20      88.20
# 14   AT1G07400 Distal Columella               47.80      34.40       8.57
# 15   AT1G07750 Distal Columella               62.20      54.70      31.20
# 16   AT1G08500 Distal Columella               28.50      19.40      10.40
# 17   AT1G10200 Distal Columella               40.60      41.40      25.70
# 18   AT1G10530 Distal Columella               32.20      55.20      24.50
# 19   AT1G10990 Distal Columella               11.20      19.10      25.70
# 20   AT1G11670 Distal Columella              187.00     113.00     252.00
# 21   AT1G11960 Distal Columella               32.20      23.50      37.30
# 22   AT1G12090 Distal Columella              198.00     143.00      89.40
# 23   AT1G12560 Distal Columella               12.10      20.30      13.50
# 24   AT1G12610 Distal Columella               41.20      20.30      42.90
# 25   AT1G12740 Distal Columella              398.00     328.00     642.00
# 26   AT1G13930 Distal Columella              173.00      99.40      61.20
# 27   AT1G17340 Distal Columella               44.30      41.60      71.00
# 28   AT1G17380 Distal Columella                8.06       3.87      11.60
# 29   AT1G18740 Distal Columella               54.70      30.50      60.00
# 30   AT1G20010 Distal Columella               38.00      27.60      17.80
# ⋮    ⋮         ⋮                             ⋮          ⋮          ⋮
# 4371 AT3G20340 Transition Domain_Trichoblast 130.00     108.00      62.30
# 4372 AT3G22540 Transition Domain_Trichoblast  29.80      20.80      14.80
# 4373 AT3G22740 Transition Domain_Trichoblast  15.70      14.40      41.00
# 4374 AT3G23605 Transition Domain_Trichoblast 102.00      63.00      36.10
# 4375 AT3G44860 Transition Domain_Trichoblast 353.00     223.00     153.00
# 4376 AT3G49550 Transition Domain_Trichoblast  25.20      15.10      12.30
# 4377 AT3G53650 Transition Domain_Trichoblast 386.00     179.00      82.00
# 4378 AT2G01021 Transition Domain_Trichoblast  50.90     109.00     242.00
# 4379 AT2G02130 Transition Domain_Trichoblast  54.00      16.90     166.00
# 4380 AT2G20880 Transition Domain_Trichoblast  43.10      22.50      20.50
# 4381 AT2G34600 Transition Domain_Trichoblast 106.00      65.80      31.10
# 4382 AT2G34880 Transition Domain_Trichoblast   0.00      70.00       0.00
# 4383 AT2G36100 Transition Domain_Trichoblast 252.00      34.80      72.10
# 4384 AT2G37470 Transition Domain_Trichoblast 329.00     138.00      67.20
# 4385 AT2G40890 Transition Domain_Trichoblast  11.50       8.44      39.30
# 4386 AT2G46410 Transition Domain_Trichoblast 105.00      62.60      35.20
# 4387 AT2G47770 Transition Domain_Trichoblast  20.00      18.30      11.50
# 4388 AT4G04745 Transition Domain_Trichoblast 180.00     131.00      59.00
# 4389 AT4G21840 Transition Domain_Trichoblast 222.00      96.40      56.60
# 4390 AT4G22360 Transition Domain_Trichoblast  22.80      16.50       6.56
# 4391 AT4G25820 Transition Domain_Trichoblast  62.40      38.30      54.90
# 4392 AT4G28240 Transition Domain_Trichoblast 179.00     111.00      57.40
# 4393 AT4G32480 Transition Domain_Trichoblast 220.00     156.00     102.00
# 4394 AT4G33467 Transition Domain_Trichoblast 189.00      86.50      55.70
# 4395 AT4G34800 Transition Domain_Trichoblast 144.00      73.90      41.00
# 4396 ATMG01320 Transition Domain_Trichoblast  15.60      28.10      46.70
# 4397 ATCG00150 Transition Domain_Trichoblast   1.35       5.98      13.10
# 4398 ATCG00450 Transition Domain_Trichoblast   0.00       0.00       0.00
# 4399 ATCG00680 Transition Domain_Trichoblast   4.40       7.39      20.50
# 4400 AT3G43990 Transition Domain_Trichoblast  15.20       0.00       0.00
#      sc_128.cpm sc_122.frq sc_126.frq sc_124.frq sc_128.frq ⋯ F     p_val
# 1     91.10     0.1560     0.2330     0.3070     0.3150     ⋯  24.7 6.67e-07
# 2     36.30     0.0969     0.1550     0.1780     0.2730     ⋯  12.5 4.03e-04
# 3     12.60     0.1830     0.2230     0.1730     0.0967     ⋯  24.6 7.30e-07
# 4     94.80     0.4690     0.4840     0.2920     0.3400     ⋯  21.2 4.08e-06
# 5     48.30     0.1010     0.1690     0.1980     0.2600     ⋯  20.8 5.23e-06
# 6     10.90     0.1510     0.1670     0.1530     0.0663     ⋯  49.7 1.90e-12
# 7     35.70     0.4040     0.4320     0.3610     0.2540     ⋯  28.6 9.01e-08
# 8    104.00     0.1440     0.2110     0.2820     0.2850     ⋯  18.8 1.45e-05
# 9     12.90     0.1150     0.1740     0.0842     0.1050     ⋯  19.7 9.14e-06
# 10    53.40     0.0503     0.0853     0.3660     0.2790     ⋯ 113.0 2.52e-26
# 11   212.00     0.4870     0.5230     0.7080     0.6550     ⋯  16.9 4.01e-05
# 12    12.90     0.1620     0.1690     0.1440     0.1080     ⋯  10.8 1.00e-03
# 13   138.00     0.1780     0.1590     0.2770     0.2400     ⋯  20.8 5.18e-06
# 14    40.60     0.1260     0.1300     0.0446     0.1240     ⋯  10.7 1.05e-03
# 15    25.70     0.3090     0.3370     0.2080     0.2240     ⋯  29.5 5.76e-08
# 16    14.00     0.1510     0.1410     0.0792     0.1190     ⋯  12.7 3.65e-04
# 17    22.00     0.2140     0.2830     0.1880     0.1770     ⋯  15.4 8.60e-05
# 18    27.40     0.1490     0.2170     0.1530     0.1960     ⋯  14.3 1.53e-04
# 19    29.10     0.0610     0.1300     0.1630     0.2100     ⋯  13.8 2.04e-04
# 20   279.00     0.4880     0.3970     0.6240     0.5830     ⋯  31.5 2.07e-08
# 21    48.30     0.1740     0.1570     0.2380     0.3290     ⋯  11.5 7.11e-04
# 22    94.00     0.5750     0.5850     0.4800     0.4590     ⋯  28.7 8.41e-08
# 23     5.71     0.0610     0.1430     0.0990     0.0525     ⋯  11.0 9.26e-04
# 24   102.00     0.1150     0.0853     0.1490     0.2070     ⋯  45.5 1.58e-11
# 25   546.00     0.7760     0.7540     0.9360     0.8650     ⋯  22.3 2.36e-06
# 26    57.40     0.6070     0.4960     0.3560     0.4030     ⋯  45.0 1.98e-11
# 27    78.30     0.2260     0.2600     0.3510     0.4140     ⋯  20.8 5.11e-06
# 28    17.40     0.0413     0.0291     0.0743     0.1220     ⋯  20.5 5.87e-06
# 29    82.60     0.2280     0.1800     0.2570     0.2980     ⋯  20.8 5.19e-06
# 30    14.00     0.1920     0.1940     0.1340     0.1240     ⋯  21.4 3.71e-06
# ⋮    ⋮          ⋮          ⋮          ⋮          ⋮          ⋱ ⋮     ⋮
# 4371  32.80     0.4410     0.4620     0.2760     0.2350     ⋯  19.0 1.32e-05
# 4372   4.89     0.1860     0.1650     0.0857     0.0758     ⋯  15.6 7.84e-05
# 4373  33.30     0.1320     0.1560     0.1620     0.1670     ⋯  15.7 7.38e-05
# 4374  32.30     0.4260     0.3440     0.1620     0.2200     ⋯  14.5 1.37e-04
# 4375  76.30     0.6700     0.6460     0.4950     0.4850     ⋯  18.2 2.03e-05
# 4376   3.42     0.2280     0.1130     0.0714     0.0455     ⋯  14.2 1.64e-04
# 4377  48.40     0.4380     0.4620     0.2330     0.3260     ⋯  38.9 4.60e-10
# 4378 138.00     0.5350     0.7450     0.6760     0.7650     ⋯  16.0 6.34e-05
# 4379 115.00     0.2160     0.1040     0.1950     0.1290     ⋯  44.4 2.77e-11
# 4380   5.87     0.2160     0.1790     0.1140     0.0758     ⋯  16.0 6.51e-05
# 4381  22.00     0.2970     0.2030     0.1330     0.1440     ⋯  25.8 3.78e-07
# 4382   0.00     0.0000     0.4580     0.0000     0.0000     ⋯  92.3 8.42e-22
# 4383  11.20     0.3330     0.2880     0.2330     0.1360     ⋯  25.9 3.56e-07
# 4384  30.30     0.4170     0.4290     0.2670     0.2730     ⋯  45.4 1.62e-11
# 4385  13.70     0.1530     0.0849     0.1520     0.0909     ⋯  14.3 1.59e-04
# 4386  31.80     0.3960     0.3110     0.1570     0.3030     ⋯  15.6 7.90e-05
# 4387   3.42     0.1920     0.1560     0.0476     0.0455     ⋯  14.2 1.64e-04
# 4388  44.00     0.4500     0.4250     0.2240     0.3330     ⋯  24.8 6.57e-07
# 4389  30.30     0.4440     0.3070     0.2380     0.2580     ⋯  31.4 2.09e-08
# 4390   4.89     0.2550     0.1460     0.0381     0.0606     ⋯  18.8 1.44e-05
# 4391   2.45     0.3150     0.3770     0.2760     0.0379     ⋯  15.9 6.61e-05
# 4392  43.50     0.4290     0.3580     0.2380     0.2580     ⋯  22.1 2.56e-06
# 4393  56.70     0.6010     0.5470     0.3570     0.3330     ⋯  16.4 5.28e-05
# 4394  46.50     0.4590     0.4340     0.2520     0.3480     ⋯  17.3 3.21e-05
# 4395  48.40     0.4350     0.3070     0.2000     0.3710     ⋯  13.9 1.92e-04
# 4396  51.40     0.1950     0.2450     0.2000     0.2880     ⋯  14.5 1.41e-04
# 4397  13.20     0.0240     0.0660     0.0619     0.1740     ⋯  19.4 1.05e-05
# 4398 140.00     0.0000     0.0000     0.0000     0.6360     ⋯ 134.0 6.49e-31
# 4399  12.70     0.0661     0.0991     0.0952     0.1360     ⋯  14.6 1.34e-04
# 4400   0.00     0.2100     0.0000     0.0000     0.0000     ⋯  23.5 1.28e-06
#      p_adj.loc p_adj.glb contrast Name      TF_Name
# 1    8.12e-05  3.49e-01  df1-WT   AT1G02360 NA
# 2    1.64e-02  1.00e+00  df1-WT   CPX1      NA
# 3    8.73e-05  3.82e-01  df1-WT   AT1G03850 NA
# 4    3.69e-04  1.00e+00  df1-WT   FLA9      NA
# 5    4.51e-04  1.00e+00  df1-WT   AT1G05060 NA
# 6    8.60e-10  9.94e-07  df1-WT   PER3      NA
# 7    1.42e-05  4.71e-02  df1-WT   AT1G05340 NA
# 8    1.06e-03  1.00e+00  df1-WT   AT1G05575 NA
# 9    7.15e-04  1.00e+00  df1-WT   AT1G05870 NA
# 10   5.45e-23  1.32e-20  df1-WT   ADS1      NA
# 11   2.40e-03  1.00e+00  df1-WT   AT1G06620 NA
# 12   3.34e-02  1.00e+00  df1-WT   AT1G06640 NA
# 13   4.50e-04  1.00e+00  df1-WT   AT1G07135 NA
# 14   3.48e-02  1.00e+00  df1-WT   HSP17.8   NA
# 15   9.44e-06  3.02e-02  df1-WT   AT1G07750 NA
# 16   1.51e-02  1.00e+00  df1-WT   ENODL18   NA
# 17   4.41e-03  1.00e+00  df1-WT   WLIM1     WLIM1
# 18   7.28e-03  1.00e+00  df1-WT   AT1G10530 NA
# 19   9.47e-03  1.00e+00  df1-WT   AT1G10990 NA
# 20   4.05e-06  1.08e-02  df1-WT   DTX36     NA
# 21   2.57e-02  1.00e+00  df1-WT   AT1G11960 NA
# 22   1.33e-05  4.40e-02  df1-WT   ELP       NA
# 23   3.16e-02  1.00e+00  df1-WT   EXPA7     NA
# 24   6.04e-09  8.29e-06  df1-WT   DREB1F    DDF1
# 25   2.35e-04  1.00e+00  df1-WT   CYP87A2   NA
# 26   7.41e-09  1.04e-05  df1-WT   AT1G13930 NA
# 27   4.48e-04  1.00e+00  df1-WT   SAC5      NA
# 28   4.99e-04  1.00e+00  df1-WT   TIFY11A   JAZ5
# 29   4.50e-04  1.00e+00  df1-WT   AT1G18740 NA
# 30   3.37e-04  1.00e+00  df1-WT   TUBB5     NA
# ⋮    ⋮         ⋮         ⋮        ⋮         ⋮
# 4371 7.21e-03  1.00e+00  df1-WT   AT3G20340 NA
# 4372 2.44e-02  1.00e+00  df1-WT   AT3G22540 NA
# 4373 2.40e-02  1.00e+00  df1-WT   HMT3      NA
# 4374 3.82e-02  1.00e+00  df1-WT   PUX12     NA
# 4375 1.01e-02  1.00e+00  df1-WT   FAMT      NA
# 4376 4.32e-02  1.00e+00  df1-WT   AT3G49550 NA
# 4377 1.12e-06  2.41e-04  df1-WT   AT3G53650 NA
# 4378 2.21e-02  1.00e+00  df1-WT   AT2G01021 NA
# 4379 9.00e-08  1.45e-05  df1-WT   PDF2.3    NA
# 4380 2.22e-02  1.00e+00  df1-WT   ERF053    ERF53
# 4381 4.10e-04  1.98e-01  df1-WT   TIFY 5B   JAZ7
# 4382 5.47e-18  4.41e-16  df1-WT   JMJ15     MEE27
# 4383 4.08e-04  1.86e-01  df1-WT   CASP1     NA
# 4384 7.68e-08  8.50e-06  df1-WT   AT2G37470 NA
# 4385 4.31e-02  1.00e+00  df1-WT   CYP98A3   NA
# 4386 2.44e-02  1.00e+00  df1-WT   CPC       CPC
# 4387 4.32e-02  1.00e+00  df1-WT   TSPO      NA
# 4388 6.74e-04  3.44e-01  df1-WT   AT4G04745 NA
# 4389 4.07e-05  1.09e-02  df1-WT   MSRB8     NA
# 4390 7.57e-03  1.00e+00  df1-WT   AT4G22360 AT4G22360
# 4391 2.22e-02  1.00e+00  df1-WT   XTH14     NA
# 4392 2.08e-03  1.00e+00  df1-WT   AT4G28240 NA
# 4393 1.94e-02  1.00e+00  df1-WT   AT4G32480 NA
# 4394 1.28e-02  1.00e+00  df1-WT   AT4G33467 NA
# 4395 4.80e-02  1.00e+00  df1-WT   AT4G34800 NA
# 4396 3.88e-02  1.00e+00  df1-WT   NAD2B     NA
# 4397 6.37e-03  1.00e+00  df1-WT   ATPI      NA
# 4398 6.33e-27  3.40e-25  df1-WT   TRNV.1    NA
# 4399 3.79e-02  1.00e+00  df1-WT   PSBB      NA
# 4400 1.18e-03  6.66e-01  df1-WT   AT3G43990 NA
#      Description
# 1    NA
# 2    NA
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   NA
# 14   NA
# 15   NA
# 16   NA
# 17   GATA type zinc finger transcription factor family protein
# 18   NA
# 19   NA
# 20   NA
# 21   NA
# 22   NA
# 23   NA
# 24   Integrase-type DNA-binding superfamily protein
# 25   NA
# 26   NA
# 27   NA
# 28   jasmonate-zim-domain protein 5
# 29   NA
# 30   NA
# ⋮    ⋮
# 4371 NA
# 4372 NA
# 4373 NA
# 4374 NA
# 4375 NA
# 4376 NA
# 4377 NA
# 4378 NA
# 4379 NA
# 4380 Integrase-type DNA-binding superfamily protein
# 4381 jasmonate-zim-domain protein 7
# 4382 Transcription factor jumonji (jmj) family protein / zinc finger (C5HC2 type) family protein
# 4383 NA
# 4384 NA
# 4385 NA
# 4386 Homeodomain-like superfamily protein
# 4387 NA
# 4388 NA
# 4389 NA
# 4390 SWIB complex BAF60b domain-containing protein
# 4391 NA
# 4392 NA
# 4393 NA
# 4394 NA
# 4395 NA
# 4396 NA
# 4397 NA
# 4398 NA
# 4399 NA
# 4400 NA
#      up_dn_label clust_up_dn
# 1    Up          Distal Columella_Up
# 2    Up          Distal Columella_Up
# 3    Down        Distal Columella_Down
# 4    Down        Distal Columella_Down
# 5    Up          Distal Columella_Up
# 6    Down        Distal Columella_Down
# 7    Down        Distal Columella_Down
# 8    Up          Distal Columella_Up
# 9    Down        Distal Columella_Down
# 10   Up          Distal Columella_Up
# 11   Up          Distal Columella_Up
# 12   Down        Distal Columella_Down
# 13   Up          Distal Columella_Up
# 14   Down        Distal Columella_Down
# 15   Down        Distal Columella_Down
# 16   Down        Distal Columella_Down
# 17   Down        Distal Columella_Down
# 18   Down        Distal Columella_Down
# 19   Up          Distal Columella_Up
# 20   Up          Distal Columella_Up
# 21   Up          Distal Columella_Up
# 22   Down        Distal Columella_Down
# 23   Down        Distal Columella_Down
# 24   Up          Distal Columella_Up
# 25   Up          Distal Columella_Up
# 26   Down        Distal Columella_Down
# 27   Up          Distal Columella_Up
# 28   Up          Distal Columella_Up
# 29   Up          Distal Columella_Up
# 30   Down        Distal Columella_Down
# ⋮    ⋮           ⋮
# 4371 Down        Transition Domain_Trichoblast_Down
# 4372 Down        Transition Domain_Trichoblast_Down
# 4373 Up          Transition Domain_Trichoblast_Up
# 4374 Down        Transition Domain_Trichoblast_Down
# 4375 Down        Transition Domain_Trichoblast_Down
# 4376 Down        Transition Domain_Trichoblast_Down
# 4377 Down        Transition Domain_Trichoblast_Down
# 4378 Up          Transition Domain_Trichoblast_Up
# 4379 Up          Transition Domain_Trichoblast_Up
# 4380 Down        Transition Domain_Trichoblast_Down
# 4381 Down        Transition Domain_Trichoblast_Down
# 4382 Down        Transition Domain_Trichoblast_Down
# 4383 Down        Transition Domain_Trichoblast_Down
# 4384 Down        Transition Domain_Trichoblast_Down
# 4385 Up          Transition Domain_Trichoblast_Up
# 4386 Down        Transition Domain_Trichoblast_Down
# 4387 Down        Transition Domain_Trichoblast_Down
# 4388 Down        Transition Domain_Trichoblast_Down
# 4389 Down        Transition Domain_Trichoblast_Down
# 4390 Down        Transition Domain_Trichoblast_Down
# 4391 Down        Transition Domain_Trichoblast_Down
# 4392 Down        Transition Domain_Trichoblast_Down
# 4393 Down        Transition Domain_Trichoblast_Down
# 4394 Down        Transition Domain_Trichoblast_Down
# 4395 Down        Transition Domain_Trichoblast_Down
# 4396 Up          Transition Domain_Trichoblast_Up
# 4397 Up          Transition Domain_Trichoblast_Up
# 4398 Up          Transition Domain_Trichoblast_Up
# 4399 Up          Transition Domain_Trichoblast_Up
# 4400 Down        Transition Domain_Trichoblast_Down

# %%
# add DE and up/dn to total list
sig_to_join <- sig_DE_fil %>%
mutate(clust_gene=paste(cluster_id, gene, sep="_")) %>%
select(clust_gene, up_dn_label, clust_up_dn)

# %%
# join all genes list to DE labels
all_bg <- mutate(all_bg, clust_gene=paste(cluster_id, gene, sep="_"))

all_bg <- left_join(all_bg, feature_names, by=c("gene"="AGI"))

all_bg$DE <- all_bg$clust_gene %in% sig_to_join$clust_gene


all_bg <- all_bg %>%
left_join(sig_to_join, by="clust_gene") %>%
arrange(all_bg, p_adj.loc)

write.csv(all_bg, file = "./output/v4_all_df1_v_WT_cell_time_EdgeR_q0.05_FC1.5_r_v_4_20220121.csv")
