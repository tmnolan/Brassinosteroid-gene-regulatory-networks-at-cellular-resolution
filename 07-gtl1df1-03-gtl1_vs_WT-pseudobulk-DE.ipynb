# %% [markdown]
# # Pseudobulk differential expression to compare gtl1 vs WT

# %%
library(tidyverse)
library(Seurat)
library(cowplot)
library(ComplexHeatmap)
library(circlize)
library(GeneOverlap)
library(gprofiler2)
library(ggrepel)
library(muscat)
library(purrr)
library(limma)
library(scran)
library(future)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Registered S3 method overwritten by 'spatstat.geom':
#   method     from
#   print.boxx cli
#
# Attaching SeuratObject
#
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.11.1
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite:
# Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#   genomic data. Bioinformatics 2016.
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
# ========================================
# circlize version 0.4.14
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: https://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(circlize))
# ========================================
#
#
# Warning message in checkMatrixPackageVersion():
# “Package version inconsistency detected.
# TMB was built with Matrix version 1.2.18
# Current Matrix version is 1.3.4
# Please re-install 'TMB' from source using install.packages('TMB', type = 'source') or ask CRAN for a binary version of 'TMB' matching CRAN's 'Matrix' package”
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SummarizedExperiment’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     Assays
#
#
# The following object is masked from ‘package:Seurat’:
#
#     Assays
#
#
#
# Attaching package: ‘future’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     values
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     values
#
#
# The following object is masked from ‘package:IRanges’:
#
#     values
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     values

# %%
#for 200gb ram 
options(future.globals.maxSize = 200000 * 1024^2)

# %%
rc.integrated <- readRDS("../data/integrations/rc.integrated_11S_gtl1_df1_Li_seu3_clean.rds")

# %%
rc.integrated
# Out:
# An object of class Seurat
# 70780 features across 74810 samples within 3 assays
# Active assay: integrated (17681 features, 17681 variable features)
#  2 other assays present: RNA, SCT
#  4 dimensional reductions calculated: pca, umap, umap_3D, umap_2D

# %% [markdown]
# ## Cell type and developmental stage metadata
#
# - Developmental stage: `time_zone`
# - Cell type:`cell_type`
# - Combination of cell type and developmental stage: `time_zone_cell_type`
# - Combination of cell type and developmental stage with cell subtypes (not used): `time_zone_cell_subtypes`

# %%
feature_names <- read_tsv("./data/features.tsv.gz", col_names = c("AGI", "Name", "Type")) %>%
  select(-Type) %>%
  distinct()
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   AGI = col_character(),
#   Name = col_character(),
#   Type = col_character()
# )

# %%
table(rc.integrated$genotype)
# Out:
#      df1     gtl1 gtl1_df1       WT
#    15678    22594    17634    18904

# %%
rc.integrated <- subset(rc.integrated, 
                        subset = sample %in% c("sc_122",
                                              "sc_123",
                                              "sc_124",
                                              "sc_125",
                                              "sc_126",
                                              "sc_127",
                                              "sc_128",
                                              "sc_129"))

# %%
rc.integrated$genotype <- factor(rc.integrated$genotype, 
                                 levels=c("WT", 
                                          "gtl1", 
                                          "df1", 
                                          "gtl1_df1"))

# %%
table(rc.integrated$genotype)
# Out:
#       WT     gtl1      df1 gtl1_df1
#    18904    22594    15678    17634

# %% [markdown]
# # Differential State Analysis with Muscat

# %%
# subset samples you want to compare

integrated.de <- subset(rc.integrated, subset = sample %in% c("sc_122", "sc_126","sc_123","sc_127"))
integrated.de$genotype <- factor(integrated.de$genotype, levels=c("WT", "gtl1"))

# %%
integrated.de
# Out:
# An object of class Seurat
# 70780 features across 41498 samples within 3 assays
# Active assay: integrated (17681 features, 17681 variable features)
#  2 other assays present: RNA, SCT
#  4 dimensional reductions calculated: pca, umap, umap_3D, umap_2D

# %% [markdown]
# ## Convert to sce

# %%
#  construct sce manually
my_metadata <- data.frame(sample_id = integrated.de$sample,
                              group_id = integrated.de$genotype,
                              cluster_id = integrated.de$time_zone_cell_type, 
                             rep=integrated.de$rep) # include experimental rep as co-variate

sce <- SingleCellExperiment(assays = list(counts = integrated.de@assays$RNA@counts),
	                            colData = my_metadata)

# %%
    (sce <- prepSCE(sce, 
        kid = "cluster_id", # subpopulation assignments
        gid = "group_id",   # group IDs (ctrl/stim)
        sid = "sample_id",    # sample IDs (ctrl/stim.1234)
        drop = FALSE))        # drop all other colData columns
# Out:
# class: SingleCellExperiment
# dim: 28688 41498
# metadata(1): experiment_info
# assays(1): counts
# rownames(28688): AT1G01010 AT1G01020 ... AT5G37474 AT5G07835
# rowData names(0):
# colnames(41498): AAACCCAAGAGCCGTA_4 AAACCCAAGCATTGTC_4 ...
#   TTTGTTGGTGTTCGTA_9 TTTGTTGGTTTACCTT_9
# colData names(4): cluster_id sample_id group_id rep
# reducedDimNames(0):
# altExpNames(0):

# %% [markdown]
# ## pre-filtering

# %%
# remove undetected genes
sce <- sce[rowSums(counts(sce) > 0) > 0, ]
dim(sce)
# Out:
# [1] 26374 41498

# %%
# remove lowly expressed genes
sce <- sce[rowSums(counts(sce) > 1) >= 1, ]
dim(sce)
# Out:
# [1] 21805 41498

# %%
# create pseudobulk profiles
pb <- aggregateData(sce,
    assay = "counts", fun = "sum",
    by = c("cluster_id", "sample_id"))
# one sheet per subpopulation
assayNames(pb)
# Out:
#  [1] "Distal Columella"
#  [2] "Distal Lateral Root Cap"
#  [3] "Elongation_Atrichoblast"
#  [4] "Elongation_Cortex"
#  [5] "Elongation_Endodermis"
#  [6] "Elongation_Pericycle"
#  [7] "Elongation_Phloem"
#  [8] "Elongation_Procambium"
#  [9] "Elongation_Trichoblast"
# [10] "Elongation_Xylem"
# [11] "Maturation_Atrichoblast"
# [12] "Maturation_Cortex"
# [13] "Maturation_Endodermis"
# [14] "Maturation_Pericycle"
# [15] "Maturation_Phloem"
# [16] "Maturation_Procambium"
# [17] "Maturation_Trichoblast"
# [18] "Maturation_Xylem"
# [19] "Proliferation Domain_Atrichoblast"
# [20] "Proliferation Domain_Cortex"
# [21] "Proliferation Domain_Endodermis"
# [22] "Proliferation Domain_Pericycle"
# [23] "Proliferation Domain_Phloem"
# [24] "Proliferation Domain_Quiescent Center"
# [25] "Proliferation Domain_Trichoblast"
# [26] "Proximal Columella"
# [27] "Proximal Lateral Root Cap"
# [28] "Transition Domain_Atrichoblast"
# [29] "Transition Domain_Cortex"
# [30] "Transition Domain_Pericycle"
# [31] "Transition Domain_Phloem"
# [32] "Transition Domain_Trichoblast"
# [33] "Transition Domain_Xylem"

# %%
# pseudobulks for 1st subpopulation
t(head(assay(pb)))
# Out:
#        AT1G01010 AT1G01020 AT1G01030 AT1G01040 AT1G01050 AT1G01060
# sc_122 37        32        12         9         862      6
# sc_123 45        48        13         5        1051      9
# sc_126 26        41        17        12        1287      9
# sc_127 48        31        12         7         857      9

# %%
# metadata to manually add to DE contrast
bscs <- read.csv("./data/GEO_upload_BR_time_scRNA_samples_metadata_with_stats.csv", na.strings=c("","NA"), stringsAsFactors = F)
bscs$date <- gsub('^([0-9]{4})([0-9]{2})([0-9]+)$', '\\1-\\2-\\3', bscs$date)

# %%
# experiment info for contrasts, add rep from csv

ei <- metadata(sce)$experiment_info
ei

sample_date <- select(bscs, sample_id=sample, rep=rep)

ei <- left_join(ei, sample_date)

ei
# Out:
#   sample_id group_id n_cells
# 1 sc_122    WT       11614
# 2 sc_123    gtl1     11141
# 3 sc_126    WT        7290
# 4 sc_127    gtl1     11453
# Joining, by = "sample_id"
#   sample_id group_id n_cells rep
# 1 sc_122    WT       11614   1
# 2 sc_123    gtl1     11141   1
# 3 sc_126    WT        7290   2
# 4 sc_127    gtl1     11453   2

# %%
mm <- model.matrix(~ 0 + ei$group_id + ei$rep)
dimnames(mm) <- list(ei$sample_id, c(levels(ei$group_id), "rep"))

mm
# Out:
#        WT gtl1 rep
# sc_122 1  0    1
# sc_123 0  1    1
# sc_126 1  0    2
# sc_127 0  1    2

# %%
contrast <- makeContrasts("gtl1-WT", levels = mm)

contrast
# Out:
#       Contrasts
# Levels gtl1-WT
#   WT   -1
#   gtl1  1
#   rep   0

# %%
res <- pbDS(pb, design = mm, 
            contrast = contrast, 
            method="edgeR", 
            min_cells=5, 
            filter = c("none"))
# Out:
# Distal Columella..Distal Lateral Root Cap..Elongation_Atrichoblast..Elongation_Cortex..Elongation_Endodermis..Elongation_Pericycle..Elongation_Phloem..Elongation_Procambium..Elongation_Trichoblast..Elongation_Xylem..Maturation_Atrichoblast..Maturation_Cortex..Maturation_Endodermis..Maturation_Pericycle..Maturation_Phloem..Maturation_Procambium..Maturation_Trichoblast..Maturation_Xylem..Proliferation Domain_Atrichoblast..Proliferation Domain_Cortex..Proliferation Domain_Endodermis..Proliferation Domain_Pericycle..Proliferation Domain_Phloem..Proliferation Domain_Quiescent Center..Proliferation Domain_Trichoblast..Proximal Columella..Proximal Lateral Root Cap..Transition Domain_Atrichoblast..Transition Domain_Cortex..Transition Domain_Pericycle..Transition Domain_Phloem..Transition Domain_Trichoblast..Transition Domain_Xylem..

# %% [markdown]
# ### DEG results

# %%
# DEG results with gene freqs
(res_to_write_frq <- resDS(sce, res, bind = "row", cpm=TRUE, frq=T))
# Out:
#        gene      cluster_id                    sc_122.cpm sc_126.cpm sc_123.cpm
# 1      AT1G01010 Distal Columella               11.100      6.520     11.600
# 2      AT1G01020 Distal Columella                9.580     10.300     12.400
# 3      AT1G01030 Distal Columella                3.590      4.270      3.350
# 4      AT1G01040 Distal Columella                2.690      3.010      1.290
# 5      AT1G01050 Distal Columella              258.000    323.000    271.000
# 6      AT1G01060 Distal Columella                1.800      2.260      2.320
# 7      AT1G01070 Distal Columella                0.599      0.251      0.000
# 8      AT1G01080 Distal Columella                0.299      0.251      0.258
# 9      AT1G01090 Distal Columella               39.200     41.900     31.500
# 10     AT1G01100 Distal Columella              279.000    248.000    263.000
# 11     AT1G01110 Distal Columella                1.200      1.250      3.100
# 12     AT1G01120 Distal Columella                2.090      1.510      5.160
# 13     AT1G01130 Distal Columella                0.299      1.250      0.000
# 14     AT1G01140 Distal Columella               13.500     13.300     10.800
# 15     AT1G01150 Distal Columella                0.000      0.000      0.000
# 16     AT1G01160 Distal Columella               20.300     14.100     13.900
# 17     AT1G01170 Distal Columella                1.800      1.250      4.390
# 18     AT1G01180 Distal Columella               23.600     29.100     27.400
# 19     AT1G01200 Distal Columella                2.990      0.753      1.550
# 20     AT1G01210 Distal Columella                1.200      2.760      1.550
# 21     AT1G01220 Distal Columella                4.490      3.260      4.390
# 22     AT1G01225 Distal Columella                1.500      0.753      1.810
# 23     AT1G01230 Distal Columella               41.600     42.700     38.400
# 24     AT1G01240 Distal Columella               26.600     36.900     24.300
# 25     AT1G01260 Distal Columella               12.600     14.800     13.400
# 26     AT1G01290 Distal Columella                5.390      6.020      5.930
# 27     AT1G01300 Distal Columella                8.380      8.280      8.000
# 28     AT1G01310 Distal Columella                0.000      0.251      0.000
# 29     AT1G01320 Distal Columella                2.090      3.510      1.810
# 30     AT1G01340 Distal Columella                0.599      0.000      0.774
# ⋮      ⋮         ⋮                             ⋮          ⋮          ⋮
# 527301 ATCG01040 Transition Domain_Trichoblast  5.740      14.700     11.600
# 527302 ATCG01050 Transition Domain_Trichoblast  2.030       7.010      5.470
# 527303 ATCG01060 Transition Domain_Trichoblast  0.169       0.000      0.608
# 527304 ATCG01070 Transition Domain_Trichoblast  1.520       5.960      3.650
# 527305 ATCG01080 Transition Domain_Trichoblast  1.180       3.160      1.820
# 527306 ATCG01090 Transition Domain_Trichoblast  4.050       9.120      4.560
# 527307 ATCG01100 Transition Domain_Trichoblast  2.870      10.200      5.780
# 527308 ATCG01110 Transition Domain_Trichoblast  1.010       2.100      0.304
# 527309 ATCG01120 Transition Domain_Trichoblast  2.700       6.310      4.560
# 527310 ATCG01130 Transition Domain_Trichoblast 94.800     251.000    169.000
# 527311 AT1G12665 Transition Domain_Trichoblast  0.169       0.000      0.000
# 527312 AT1G15610 Transition Domain_Trichoblast  0.000       0.000      0.608
# 527313 AT1G52940 Transition Domain_Trichoblast  0.338       0.351      0.000
# 527314 AT1G79770 Transition Domain_Trichoblast  0.000       0.000      0.000
# 527315 AT3G03830 Transition Domain_Trichoblast  0.000       0.351      0.000
# 527316 AT3G61910 Transition Domain_Trichoblast  0.169       0.000      0.000
# 527317 AT4G29450 Transition Domain_Trichoblast  0.000       0.000      0.000
# 527318 AT5G63340 Transition Domain_Trichoblast  0.000       0.701      0.608
# 527319 AT2G16360 Transition Domain_Trichoblast  0.000       0.000      0.304
# 527320 AT2G25055 Transition Domain_Trichoblast  0.169       0.701      0.608
# 527321 AT3G22570 Transition Domain_Trichoblast  3.710       2.450      4.870
# 527322 AT3G26450 Transition Domain_Trichoblast  0.000       0.000      0.304
# 527323 AT3G32400 Transition Domain_Trichoblast  0.169       0.000      0.000
# 527324 AT3G43990 Transition Domain_Trichoblast 15.200       0.000      0.000
# 527325 AT4G01595 Transition Domain_Trichoblast  0.338       0.000      0.000
# 527326 AT4G04615 Transition Domain_Trichoblast  7.760       6.660      4.870
# 527327 AT5G25756 Transition Domain_Trichoblast  0.000       0.701      0.000
# 527328 ATCG00030 Transition Domain_Trichoblast 72.200     196.000    137.000
# 527329 AT3G50320 Transition Domain_Trichoblast  0.000       0.000      0.000
# 527330 AT4G20520 Transition Domain_Trichoblast  0.000       0.701      0.000
#        sc_127.cpm sc_122.frq sc_126.frq sc_123.frq sc_127.frq WT.frq   gtl1.frq
# 1       14.700    0.06100    0.05040    0.07410    0.08850    0.055900 0.081100
# 2        9.490    0.05570    0.07170    0.07940    0.05840    0.063400 0.069200
# 3        3.670    0.01970    0.03290    0.02290    0.02070    0.026100 0.021900
# 4        2.140    0.01620    0.01940    0.00882    0.01320    0.017700 0.010900
# 5      262.000    0.69300    0.77900    0.72700    0.67600    0.734000 0.702000
# 6        2.760    0.01080    0.01740    0.01590    0.01510    0.014000 0.015500
# 7        0.000    0.00359    0.00194    0.00000    0.00000    0.002800 0.000000
# 8        0.612    0.00180    0.00194    0.00176    0.00377    0.001860 0.002730
# 9       42.600    0.19600    0.26400    0.17500    0.22800    0.228000 0.200000
# 10     298.000    0.68000    0.67600    0.66800    0.69300    0.678000 0.680000
# 11       2.140    0.00718    0.00969    0.02120    0.01320    0.008390 0.017300
# 12       3.670    0.01080    0.01160    0.03530    0.01690    0.011200 0.026400
# 13       0.000    0.00180    0.00775    0.00000    0.00000    0.004660 0.000000
# 14       6.430    0.07900    0.10100    0.06700    0.03770    0.089500 0.052800
# 15       0.306    0.00000    0.00000    0.00000    0.00188    0.000000 0.000911
# 16      14.700    0.11100    0.09880    0.09170    0.07910    0.105000 0.085600
# 17       1.840    0.01080    0.00969    0.02290    0.00942    0.010300 0.016400
# 18      25.100    0.11700    0.19000    0.15500    0.13600    0.152000 0.146000
# 19       0.612    0.01800    0.00581    0.01060    0.00377    0.012100 0.007290
# 20       2.140    0.00718    0.01740    0.00882    0.01320    0.012100 0.010900
# 21       3.670    0.02690    0.02520    0.03000    0.02260    0.026100 0.026400
# 22       1.220    0.00898    0.00581    0.01230    0.00753    0.007460 0.010000
# 23      40.400    0.22100    0.27300    0.22200    0.20900    0.246000 0.216000
# 24      28.500    0.14400    0.24400    0.14600    0.15600    0.192000 0.151000
# 25      13.500    0.06460    0.10500    0.08640    0.07910    0.083900 0.082900
# 26       3.370    0.03230    0.04460    0.03880    0.01880    0.038200 0.029100
# 27       6.740    0.04670    0.06200    0.05110    0.03950    0.054100 0.045500
# 28       0.000    0.00000    0.00194    0.00000    0.00000    0.000932 0.000000
# 29       3.060    0.01260    0.02710    0.01230    0.01880    0.019600 0.015500
# 30       0.612    0.00359    0.00000    0.00529    0.00377    0.001860 0.004550
# ⋮      ⋮          ⋮          ⋮          ⋮          ⋮          ⋮        ⋮
# 527301  12.300    0.09610    0.17000    0.11800    0.09660    0.12500  0.10500
# 527302   8.520    0.03600    0.09430    0.05540    0.05800    0.05870  0.05690
# 527303   0.587    0.00300    0.00000    0.00692    0.00483    0.00183  0.00569
# 527304   3.230    0.02700    0.08020    0.03810    0.02660    0.04770  0.03130
# 527305   2.350    0.02100    0.04250    0.02080    0.01930    0.02940  0.01990
# 527306   8.520    0.06310    0.10400    0.05190    0.06520    0.07890  0.05970
# 527307   5.290    0.04800    0.12300    0.05880    0.04110    0.07710  0.04840
# 527308   1.170    0.01800    0.02360    0.00346    0.00966    0.02020  0.00711
# 527309   5.580    0.04200    0.08020    0.05190    0.03860    0.05690  0.04410
# 527310 208.000    0.58000    0.59400    0.55000    0.51700    0.58500  0.53100
# 527311   0.000    0.00300    0.00000    0.00000    0.00000    0.00183  0.00000
# 527312   0.000    0.00000    0.00000    0.00346    0.00000    0.00000  0.00142
# 527313   0.000    0.00601    0.00472    0.00000    0.00000    0.00550  0.00000
# 527314   0.294    0.00000    0.00000    0.00000    0.00242    0.00000  0.00142
# 527315   0.294    0.00000    0.00472    0.00000    0.00242    0.00183  0.00142
# 527316   0.000    0.00300    0.00000    0.00000    0.00000    0.00183  0.00000
# 527317   0.294    0.00000    0.00000    0.00000    0.00242    0.00000  0.00142
# 527318   0.294    0.00000    0.00943    0.00692    0.00242    0.00367  0.00427
# 527319   0.000    0.00000    0.00000    0.00346    0.00000    0.00000  0.00142
# 527320   0.587    0.00300    0.00943    0.00692    0.00483    0.00550  0.00569
# 527321   1.170    0.06310    0.03300    0.04500    0.00966    0.05140  0.02420
# 527322   0.294    0.00000    0.00000    0.00346    0.00242    0.00000  0.00284
# 527323   0.000    0.00300    0.00000    0.00000    0.00000    0.00183  0.00000
# 527324   0.000    0.21000    0.00000    0.00000    0.00000    0.12800  0.00000
# 527325   0.294    0.00601    0.00000    0.00000    0.00242    0.00367  0.00142
# 527326   5.290    0.12600    0.08490    0.04500    0.03620    0.11000  0.03980
# 527327   0.000    0.00000    0.00943    0.00000    0.00000    0.00367  0.00000
# 527328   0.000    0.54400    0.60400    0.54000    0.00000    0.56700  0.22200
# 527329   0.294    0.00000    0.00000    0.00000    0.00242    0.00000  0.00142
# 527330   0.000    0.00000    0.00943    0.00000    0.00000    0.00367  0.00000
#        logFC    logCPM  F        p_val    p_adj.loc p_adj.glb contrast
# 1       0.59400  3.5100 5.010000 0.0252   0.632     1         gtl1-WT
# 2       0.13400  3.4600 0.250000 0.6170   0.999     1         gtl1-WT
# 3      -0.15800  2.1000 0.131000 0.7180   0.999     1         gtl1-WT
# 4      -0.73400  1.5000 1.510000 0.2190   0.999     1         gtl1-WT
# 5      -0.11400  8.1300 0.469000 0.4930   0.999     1         gtl1-WT
# 6       0.32100  1.5000 0.297000 0.5860   0.999     1         gtl1-WT
# 7      -3.77000 -0.3950 1.390000 0.2390   0.999     1         gtl1-WT
# 8       0.60000 -0.1540 0.092300 0.7610   0.999     1         gtl1-WT
# 9      -0.14200  5.3000 0.546000 0.4600   0.999     1         gtl1-WT
# 10      0.08990  8.0900 0.290000 0.5900   0.999     1         gtl1-WT
# 11      1.06000  1.3100 2.450000 0.1170   0.999     1         gtl1-WT
# 12      1.28000  1.8700 6.400000 0.0114   0.416     1         gtl1-WT
# 13     -4.48000 -0.0493 2.870000 0.0900   0.994     1         gtl1-WT
# 14     -0.64100  3.5400 5.850000 0.0155   0.483     1         gtl1-WT
# 15      2.50000 -0.6840 0.439000 0.5080   0.999     1         gtl1-WT
# 16     -0.25500  4.0200 1.220000 0.2690   0.999     1         gtl1-WT
# 17      0.98100  1.5400 2.680000 0.1020   0.999     1         gtl1-WT
# 18     -0.00445  4.7500 0.000472 0.9830   0.999     1         gtl1-WT
# 19     -0.75200  1.0000 0.831000 0.3620   0.999     1         gtl1-WT
# 20     -0.07680  1.3100 0.013400 0.9080   0.999     1         gtl1-WT
# 21      0.05960  2.1700 0.019800 0.8880   0.999     1         gtl1-WT
# 22      0.43100  0.9010 0.250000 0.6170   0.999     1         gtl1-WT
# 23     -0.09560  5.3700 0.253000 0.6150   0.999     1         gtl1-WT
# 24     -0.26000  4.8900 1.670000 0.1960   0.999     1         gtl1-WT
# 25     -0.02380  3.8200 0.009660 0.9220   0.999     1         gtl1-WT
# 26     -0.30300  2.5300 0.685000 0.4080   0.999     1         gtl1-WT
# 27     -0.17800  3.0700 0.348000 0.5550   0.999     1         gtl1-WT
# 28     -2.14000 -0.6850 0.330000 0.5660   0.999     1         gtl1-WT
# 29     -0.20200  1.6700 0.139000 0.7090   0.999     1         gtl1-WT
# 30      1.21000  0.0530 0.509000 0.4760   0.999     1         gtl1-WT
# ⋮      ⋮        ⋮       ⋮        ⋮        ⋮         ⋮         ⋮
# 527301  0.3470   3.4600  1.54000 2.15e-01 7.43e-01  1.00e+00  gtl1-WT
# 527302  0.7600   2.5400  4.31000 3.78e-02 3.46e-01  1.00e+00  gtl1-WT
# 527303  2.2000  -0.2490  1.07000 3.01e-01 8.11e-01  1.00e+00  gtl1-WT
# 527304  0.0770   1.9100  0.02760 8.68e-01 9.76e-01  1.00e+00  gtl1-WT
# 527305  0.0404   1.3100  0.00410 9.49e-01 9.87e-01  1.00e+00  gtl1-WT
# 527306  0.0178   2.7500  0.00277 9.58e-01 9.89e-01  1.00e+00  gtl1-WT
# 527307 -0.0554   2.6000  0.02400 8.77e-01 9.80e-01  1.00e+00  gtl1-WT
# 527308 -1.0900   0.6960  1.23000 2.67e-01 7.90e-01  1.00e+00  gtl1-WT
# 527309  0.2570   2.3200  0.43200 5.11e-01 9.01e-01  1.00e+00  gtl1-WT
# 527310  0.2730   7.4900  2.73000 9.86e-02 5.52e-01  1.00e+00  gtl1-WT
# 527311 -1.9000  -0.7840  0.24500 6.20e-01 9.07e-01  1.00e+00  gtl1-WT
# 527312  3.7300  -0.6270  1.21000 2.71e-01 7.90e-01  1.00e+00  gtl1-WT
# 527313 -3.5400  -0.4940  1.09000 2.96e-01 8.09e-01  1.00e+00  gtl1-WT
# 527314  2.0900  -0.7800  0.33800 5.61e-01 9.07e-01  1.00e+00  gtl1-WT
# 527315 -0.2050  -0.6270  0.00455 9.46e-01 9.86e-01  1.00e+00  gtl1-WT
# 527316 -1.9000  -0.7840  0.24500 6.20e-01 9.07e-01  1.00e+00  gtl1-WT
# 527317  2.0900  -0.7800  0.33800 5.61e-01 9.07e-01  1.00e+00  gtl1-WT
# 527318  0.7420  -0.2440  0.14200 7.07e-01 9.39e-01  1.00e+00  gtl1-WT
# 527319  2.8200  -0.7800  0.56900 4.51e-01 8.87e-01  1.00e+00  gtl1-WT
# 527320  0.6130  -0.0387  0.14000 7.08e-01 9.39e-01  1.00e+00  gtl1-WT
# 527321 -0.0176   1.8700  0.00131 9.71e-01 9.91e-01  1.00e+00  gtl1-WT
# 527322  3.3600  -0.6270  0.99600 3.18e-01 8.17e-01  1.00e+00  gtl1-WT
# 527323 -1.9000  -0.7840  0.24500 6.20e-01 9.07e-01  1.00e+00  gtl1-WT
# 527324 -7.8500   2.5300 62.40000 2.91e-15 2.68e-12  1.53e-09  gtl1-WT
# 527325 -0.4390  -0.4950  0.02730 8.69e-01 9.76e-01  1.00e+00  gtl1-WT
# 527326 -0.5170   2.7700  2.29000 1.30e-01 6.18e-01  1.00e+00  gtl1-WT
# 527327 -3.5400  -0.6260  0.92900 3.35e-01 8.29e-01  1.00e+00  gtl1-WT
# 527328 -1.5600   6.6500 45.60000 1.46e-11 5.78e-09  7.68e-06  gtl1-WT
# 527329  2.0900  -0.7800  0.33800 5.61e-01 9.07e-01  1.00e+00  gtl1-WT
# 527330 -3.5400  -0.6260  0.92900 3.35e-01 8.29e-01  1.00e+00  gtl1-WT

# %%
## all genes background 

all_bg <- filter(res_to_write_frq,
                WT.frq >=0.1 | gtl1.frq >=0.1)

# %%
length(unique(all_bg$gene))
# Out:
# [1] 16756

# %%
#total DE genes p_adj.loc < 0.05, abs(logFC) > 1.5
sig_DE <- filter(res_to_write_frq, p_adj.loc<=0.05 & abs(logFC) > log2(1.5))
sig_DE <- left_join(sig_DE, feature_names, by=c("gene"="AGI"))

length(unique(sig_DE$gene))
# Out:
# [1] 4385

# %%
# filter gene freqs to avoid calling lowly detected genes
sig_DE_fil <- filter(sig_DE, WT.frq >=0.1 | gtl1.frq >=0.1)

# %%
length(unique(sig_DE_fil$gene))
# Out:
# [1] 3281

# %%
# load TFs
TF_list <- read_csv("./data/Kay_TF_thalemine_annotations.csv", col_names = c("gene", "TF_Name", "Description"))
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   gene = col_character(),
#   TF_Name = col_character(),
#   Description = col_character()
# )

# %%
sig_DE_fil <- left_join(sig_DE_fil, TF_list)
# Out:
# Joining, by = "gene"

# %%
# label up vs down
sig_DE_fil <- sig_DE_fil %>%
  mutate(up_dn_label = case_when(logFC >=log2(1.5) ~ "Up",  
                                       logFC <=log2(1/1.5) ~ "Down",
                                       TRUE ~ "Not DE"))

sig_DE_fil$clust_up_dn <- paste(sig_DE_fil$cluster_id, sig_DE_fil$up_dn_label, sep="_")

sig_DE_fil
# Out:
#      gene      cluster_id                    sc_122.cpm sc_126.cpm sc_123.cpm
# 1    AT1G01470 Distal Columella              3150.0     3230.0     1790.00
# 2    AT1G05680 Distal Columella               735.0      812.0      509.00
# 3    AT1G06080 Distal Columella                11.1       15.8       43.10
# 4    AT1G12560 Distal Columella                12.6       21.1       29.40
# 5    AT1G14960 Distal Columella                48.8       56.7       84.40
# 6    AT1G15380 Distal Columella                15.6       52.7       57.30
# 7    AT1G19840 Distal Columella                10.5       10.8       23.00
# 8    AT1G23720 Distal Columella                41.0       53.7       81.00
# 9    AT1G30135 Distal Columella               102.0       39.4       92.10
# 10   AT1G32010 Distal Columella                 0.0        0.0       81.00
# 11   AT1G33800 Distal Columella                32.6       22.3       51.90
# 12   AT1G35140 Distal Columella                27.8       52.4       15.50
# 13   AT1G53060 Distal Columella                40.7       40.7       65.00
# 14   AT1G54000 Distal Columella               423.0      353.0      525.00
# 15   AT1G55240 Distal Columella                11.7       30.4       30.20
# 16   AT1G61740 Distal Columella                11.7       11.8       22.20
# 17   AT1G66200 Distal Columella                29.3       25.8       83.90
# 18   AT1G67920 Distal Columella                57.8       53.7       98.30
# 19   AT1G71380 Distal Columella                40.7       86.6       33.80
# 20   AT1G72140 Distal Columella                39.2       25.8       74.80
# 21   AT1G74930 Distal Columella                25.1       13.6       35.10
# 22   AT1G75600 Distal Columella               100.0      191.0       86.40
# 23   AT1G79040 Distal Columella                26.0       11.5        8.26
# 24   AT5G02550 Distal Columella                23.6       20.8       42.10
# 25   AT5G04120 Distal Columella                76.3       76.0       42.80
# 26   AT5G05500 Distal Columella                16.5       17.6       56.00
# 27   AT5G06760 Distal Columella                41.6       43.4       17.80
# 28   AT5G11670 Distal Columella                73.6       65.0      101.00
# 29   AT5G13220 Distal Columella               107.0       61.0      152.00
# 30   AT5G14700 Distal Columella                77.8       55.2      145.00
# ⋮    ⋮         ⋮                             ⋮          ⋮          ⋮
# 7813 AT4G28650 Transition Domain_Trichoblast   44.00      74.00      86.10
# 7814 AT4G28890 Transition Domain_Trichoblast   10.30      12.30      17.90
# 7815 AT4G29070 Transition Domain_Trichoblast   38.00      18.90      14.60
# 7816 AT4G29670 Transition Domain_Trichoblast   58.10      23.80      22.20
# 7817 AT4G30170 Transition Domain_Trichoblast 1790.00    2420.00    3020.00
# 7818 AT4G30670 Transition Domain_Trichoblast   74.90      74.00     139.00
# 7819 AT4G31320 Transition Domain_Trichoblast  211.00     159.00     109.00
# 7820 AT4G32480 Transition Domain_Trichoblast  219.00     156.00      87.30
# 7821 AT4G32590 Transition Domain_Trichoblast   18.70      11.60       9.12
# 7822 AT4G32620 Transition Domain_Trichoblast    6.58       7.72      12.50
# 7823 AT4G32720 Transition Domain_Trichoblast   17.70      14.70      31.30
# 7824 AT4G33467 Transition Domain_Trichoblast  188.00      86.30      69.30
# 7825 AT4G33666 Transition Domain_Trichoblast   27.50       5.96       7.91
# 7826 AT4G34050 Transition Domain_Trichoblast  197.00     143.00     273.00
# 7827 AT4G34210 Transition Domain_Trichoblast   37.80      25.60      12.20
# 7828 AT4G34580 Transition Domain_Trichoblast    7.59      13.00      25.20
# 7829 AT4G34800 Transition Domain_Trichoblast  143.00      73.60      45.90
# 7830 AT4G34810 Transition Domain_Trichoblast   30.20      20.00      12.20
# 7831 AT4G34920 Transition Domain_Trichoblast    5.91       5.61      13.70
# 7832 AT4G35920 Transition Domain_Trichoblast   15.40      10.20      24.00
# 7833 AT4G36010 Transition Domain_Trichoblast  394.00     507.00     202.00
# 7834 AT4G36500 Transition Domain_Trichoblast 1030.00     434.00     577.00
# 7835 AT4G36880 Transition Domain_Trichoblast  145.00     217.00      71.50
# 7836 AT4G36900 Transition Domain_Trichoblast  164.00     117.00      70.60
# 7837 AT4G36990 Transition Domain_Trichoblast   49.30      37.20      68.10
# 7838 AT4G37640 Transition Domain_Trichoblast  110.00     166.00     210.00
# 7839 ATMG00270 Transition Domain_Trichoblast   30.20      94.30      74.20
# 7840 ATCG00450 Transition Domain_Trichoblast    0.00       0.00       0.00
# 7841 AT3G43990 Transition Domain_Trichoblast   15.20       0.00       0.00
# 7842 ATCG00030 Transition Domain_Trichoblast   72.20     196.00     137.00
#      sc_127.cpm sc_122.frq sc_126.frq sc_123.frq sc_127.frq ⋯ F     p_val
# 1    1650.00    0.9660     0.9260     0.8660     0.8360     ⋯  28.7 8.68e-08
# 2     497.00    0.5870     0.5500     0.5100     0.4600     ⋯  13.9 1.98e-04
# 3      46.50    0.0503     0.0853     0.1900     0.2000     ⋯  66.9 2.97e-16
# 4      27.90    0.0610     0.1430     0.1570     0.1470     ⋯  13.4 2.55e-04
# 5      79.90    0.2440     0.3430     0.4230     0.3730     ⋯  12.8 3.53e-04
# 6      46.50    0.0664     0.1490     0.1990     0.1730     ⋯  13.9 1.95e-04
# 7      17.80    0.0610     0.0775     0.1360     0.1020     ⋯  15.4 8.50e-05
# 8      82.40    0.2030     0.2930     0.3490     0.3390     ⋯  19.3 1.13e-05
# 9     125.00    0.2550     0.1690     0.2650     0.2710     ⋯  16.3 5.47e-05
# 10      0.00    0.0000     0.0000     0.4090     0.0000     ⋯ 226.0 7.69e-51
# 11     38.00    0.1720     0.1490     0.2700     0.1980     ⋯  13.3 2.68e-04
# 12      9.49    0.0934     0.1630     0.0688     0.0490     ⋯  55.2 1.15e-13
# 13     66.10    0.1180     0.1400     0.1890     0.1860     ⋯  13.9 1.90e-04
# 14    677.00    0.6570     0.5720     0.7270     0.7250     ⋯  14.0 1.84e-04
# 15     37.00    0.0503     0.1120     0.1060     0.1260     ⋯  12.9 3.30e-04
# 16     19.90    0.0628     0.0775     0.1180     0.0998     ⋯  13.2 2.83e-04
# 17     88.80    0.1530     0.1650     0.4130     0.3940     ⋯  75.4 4.23e-18
# 18     76.80    0.2350     0.2270     0.3440     0.2660     ⋯  13.1 3.04e-04
# 19     39.20    0.0862     0.1940     0.0988     0.0923     ⋯  15.0 1.10e-04
# 20     62.80    0.1690     0.1360     0.2930     0.2350     ⋯  34.0 5.69e-09
# 21     40.40    0.1110     0.0853     0.1730     0.1470     ⋯  23.5 1.29e-06
# 22     75.90    0.2240     0.3020     0.2220     0.1810     ⋯  19.7 9.29e-06
# 23     10.40    0.1450     0.0833     0.0547     0.0527     ⋯  15.3 9.41e-05
# 24     35.80    0.1170     0.1260     0.2010     0.1680     ⋯  16.1 6.12e-05
# 25     39.80    0.3390     0.4150     0.2360     0.2130     ⋯  23.2 1.49e-06
# 26     39.50    0.0844     0.1120     0.2520     0.1860     ⋯  50.8 1.04e-12
# 27     14.40    0.1940     0.2210     0.1060     0.0810     ⋯  45.1 1.96e-11
# 28    113.00    0.2980     0.3430     0.4340     0.4260     ⋯  12.9 3.28e-04
# 29    170.00    0.3790     0.3200     0.5220     0.5050     ⋯  31.7 1.80e-08
# 30    133.00    0.3090     0.2730     0.4480     0.3950     ⋯  38.0 7.21e-10
# ⋮    ⋮          ⋮          ⋮          ⋮          ⋮          ⋱ ⋮     ⋮
# 7813   93.70    0.4290     0.4580     0.4190     0.3380     ⋯  12.2 4.80e-04
# 7814   22.00    0.1500     0.1320     0.1660     0.1430     ⋯  10.5 1.19e-03
# 7815   13.50    0.2760     0.1420     0.1180     0.0966     ⋯  17.3 3.22e-05
# 7816   14.70    0.3450     0.1890     0.1450     0.1140     ⋯  24.6 6.97e-07
# 7817 3260.00    0.9550     0.9860     0.9830     0.9570     ⋯  26.7 2.44e-07
# 7818   89.60    0.4590     0.4150     0.5260     0.4010     ⋯  10.9 9.67e-04
# 7819   79.00    0.6040     0.4200     0.4600     0.3650     ⋯  32.1 1.48e-08
# 7820   78.40    0.6010     0.5470     0.4390     0.4280     ⋯  44.3 2.82e-11
# 7821    5.87    0.2070     0.1040     0.0865     0.0435     ⋯  12.6 3.90e-04
# 7822   16.40    0.1140     0.0943     0.1180     0.1060     ⋯  12.4 4.40e-04
# 7823   28.20    0.2160     0.1700     0.2250     0.1690     ⋯  14.6 1.34e-04
# 7824   41.70    0.4590     0.4340     0.3940     0.2680     ⋯  45.8 1.35e-11
# 7825    4.11    0.1680     0.0472     0.0727     0.0338     ⋯  21.5 3.48e-06
# 7826  308.00    0.8200     0.7640     0.8790     0.7710     ⋯  24.2 8.90e-07
# 7827    9.40    0.2640     0.1700     0.1040     0.0725     ⋯  40.1 2.42e-10
# 7828   18.20    0.1110     0.1460     0.2210     0.1180     ⋯  20.6 5.73e-06
# 7829   33.80    0.4350     0.3070     0.2730     0.1860     ⋯  51.7 6.56e-13
# 7830    8.22    0.2460     0.1370     0.1070     0.0652     ⋯  26.2 3.12e-07
# 7831    9.11    0.0931     0.0660     0.1420     0.0749     ⋯  10.9 9.71e-04
# 7832   21.70    0.2040     0.1080     0.1830     0.1450     ⋯  11.6 6.60e-04
# 7833  208.00    0.6310     0.6840     0.5160     0.4490     ⋯  55.3 1.08e-13
# 7834  332.00    0.9580     0.9390     0.9450     0.9030     ⋯  19.8 8.80e-06
# 7835  150.00    0.4590     0.4620     0.2980     0.3140     ⋯  20.5 5.99e-06
# 7836   57.00    0.4950     0.4340     0.3490     0.3330     ⋯  38.9 4.56e-10
# 7837   75.50    0.4140     0.3920     0.3940     0.4370     ⋯  14.1 1.75e-04
# 7838  206.00    0.5560     0.5850     0.5570     0.5310     ⋯  14.6 1.33e-04
# 7839   92.50    0.3240     0.5470     0.4530     0.3700     ⋯  10.2 1.40e-03
# 7840  125.00    0.0000     0.0000     0.0000     0.4590     ⋯ 230.0 1.23e-51
# 7841    0.00    0.2100     0.0000     0.0000     0.0000     ⋯  62.4 2.91e-15
# 7842    0.00    0.5440     0.6040     0.5400     0.0000     ⋯  45.6 1.46e-11
#      p_adj.loc p_adj.glb contrast Name      TF_Name
# 1    4.75e-05  4.55e-02  gtl1-WT  LEA14     NA
# 2    3.00e-02  1.00e+00  gtl1-WT  UGT74E2   NA
# 3    1.15e-12  1.57e-10  gtl1-WT  ADS1      NA
# 4    3.54e-02  1.00e+00  gtl1-WT  EXPA7     NA
# 5    4.37e-02  1.00e+00  gtl1-WT  AT1G14960 NA
# 6    2.98e-02  1.00e+00  gtl1-WT  AT1G15380 NA
# 7    1.50e-02  1.00e+00  gtl1-WT  AT1G19840 NA
# 8    2.93e-03  1.00e+00  gtl1-WT  AT1G23720 NA
# 9    1.07e-02  1.00e+00  gtl1-WT  TIFY5A    JAZ8
# 10   1.51e-46  4.05e-45  gtl1-WT  AT1G32010 NA
# 11   3.59e-02  1.00e+00  gtl1-WT  GXM3      NA
# 12   2.82e-10  6.03e-08  gtl1-WT  EXL1      NA
# 13   2.93e-02  1.00e+00  gtl1-WT  AT1G53060 NA
# 14   2.85e-02  1.00e+00  gtl1-WT  GLL22     NA
# 15   4.16e-02  1.00e+00  gtl1-WT  AT1G55240 NA
# 16   3.72e-02  1.00e+00  gtl1-WT  AT1G61740 NA
# 17   2.78e-14  2.23e-12  gtl1-WT  ATGSR2    NA
# 18   3.91e-02  1.00e+00  gtl1-WT  AT1G67920 NA
# 19   1.83e-02  1.00e+00  gtl1-WT  CEL3      NA
# 20   4.31e-06  2.99e-03  gtl1-WT  NPF5.12   NA
# 21   4.17e-04  6.75e-01  gtl1-WT  ERF018    ORA47
# 22   2.51e-03  1.00e+00  gtl1-WT  AT1G75600 NA
# 23   1.63e-02  1.00e+00  gtl1-WT  PSBR      NA
# 24   1.15e-02  1.00e+00  gtl1-WT  AT5G02550 NA
# 25   4.73e-04  7.78e-01  gtl1-WT  IPSP      NA
# 26   2.04e-09  5.46e-07  gtl1-WT  AT5G05500 NA
# 27   2.98e-08  1.03e-05  gtl1-WT  LEA46     NA
# 28   4.16e-02  1.00e+00  gtl1-WT  NADP-ME2  NA
# 29   1.25e-05  9.43e-03  gtl1-WT  JAZ10     JAZ10
# 30   7.89e-07  3.79e-04  gtl1-WT  AT5G14700 NA
# ⋮    ⋮         ⋮         ⋮        ⋮         ⋮
# 7813 1.83e-02  1.00e+00  gtl1-WT  MIK1      NA
# 7814 3.64e-02  1.00e+00  gtl1-WT  ATL42     NA
# 7815 2.10e-03  1.00e+00  gtl1-WT  AT4G29070 NA
# 7816 7.68e-05  3.65e-01  gtl1-WT  ACHT2     NA
# 7817 3.29e-05  1.28e-01  gtl1-WT  PER45     NA
# 7818 3.13e-02  1.00e+00  gtl1-WT  AT4G30670 NA
# 7819 2.72e-06  7.79e-03  gtl1-WT  AT4G31320 NA
# 7820 9.99e-09  1.49e-05  gtl1-WT  AT4G32480 NA
# 7821 1.56e-02  1.00e+00  gtl1-WT  AT4G32590 NA
# 7822 1.72e-02  1.00e+00  gtl1-WT  AT4G32620 NA
# 7823 6.85e-03  1.00e+00  gtl1-WT  LA1       NA
# 7824 5.45e-09  7.09e-06  gtl1-WT  AT4G33467 NA
# 7825 3.04e-04  1.00e+00  gtl1-WT  AT4G33666 NA
# 7826 9.43e-05  4.66e-01  gtl1-WT  CCoAOMT1  NA
# 7827 7.27e-08  1.27e-04  gtl1-WT  ASK11     NA
# 7828 4.65e-04  1.00e+00  gtl1-WT  SFH1      NA
# 7829 3.47e-10  3.45e-07  gtl1-WT  AT4G34800 NA
# 7830 3.94e-05  1.64e-01  gtl1-WT  AT4G34810 NA
# 7831 3.13e-02  1.00e+00  gtl1-WT  AT4G34920 NA
# 7832 2.36e-02  1.00e+00  gtl1-WT  MCA1      NA
# 7833 7.38e-11  5.69e-08  gtl1-WT  AT4G36010 NA
# 7834 6.65e-04  1.00e+00  gtl1-WT  AT4G36500 NA
# 7835 4.81e-04  1.00e+00  gtl1-WT  CP1       NA
# 7836 1.25e-07  2.40e-04  gtl1-WT  RAP2-10   RAP2.10
# 7837 8.35e-03  1.00e+00  gtl1-WT  HSFB1     HSF4
# 7838 6.83e-03  1.00e+00  gtl1-WT  ACA2      NA
# 7839 4.10e-02  1.00e+00  gtl1-WT  NAD6      NA
# 7840 1.22e-47  6.49e-46  gtl1-WT  TRNV.1    NA
# 7841 2.68e-12  1.53e-09  gtl1-WT  AT3G43990 NA
# 7842 5.78e-09  7.68e-06  gtl1-WT  TRNK      NA
#      Description                                    up_dn_label
# 1    NA                                             Down
# 2    NA                                             Down
# 3    NA                                             Up
# 4    NA                                             Up
# 5    NA                                             Up
# 6    NA                                             Up
# 7    NA                                             Up
# 8    NA                                             Up
# 9    jasmonate-zim-domain protein 8                 Up
# 10   NA                                             Up
# 11   NA                                             Up
# 12   NA                                             Down
# 13   NA                                             Up
# 14   NA                                             Up
# 15   NA                                             Up
# 16   NA                                             Up
# 17   NA                                             Up
# 18   NA                                             Up
# 19   NA                                             Down
# 20   NA                                             Up
# 21   Integrase-type DNA-binding superfamily protein Up
# 22   NA                                             Down
# 23   NA                                             Down
# 24   NA                                             Up
# 25   NA                                             Down
# 26   NA                                             Up
# 27   NA                                             Down
# 28   NA                                             Up
# 29   jasmonate-zim-domain protein 10                Up
# 30   NA                                             Up
# ⋮    ⋮                                              ⋮
# 7813 NA                                             Up
# 7814 NA                                             Up
# 7815 NA                                             Down
# 7816 NA                                             Down
# 7817 NA                                             Up
# 7818 NA                                             Up
# 7819 NA                                             Down
# 7820 NA                                             Down
# 7821 NA                                             Down
# 7822 NA                                             Up
# 7823 NA                                             Up
# 7824 NA                                             Down
# 7825 NA                                             Down
# 7826 NA                                             Up
# 7827 NA                                             Down
# 7828 NA                                             Up
# 7829 NA                                             Down
# 7830 NA                                             Down
# 7831 NA                                             Up
# 7832 NA                                             Up
# 7833 NA                                             Down
# 7834 NA                                             Down
# 7835 NA                                             Down
# 7836 related to AP2 10                              Down
# 7837 heat shock factor 4                            Up
# 7838 NA                                             Up
# 7839 NA                                             Up
# 7840 NA                                             Up
# 7841 NA                                             Down
# 7842 NA                                             Down
#      clust_up_dn
# 1    Distal Columella_Down
# 2    Distal Columella_Down
# 3    Distal Columella_Up
# 4    Distal Columella_Up
# 5    Distal Columella_Up
# 6    Distal Columella_Up
# 7    Distal Columella_Up
# 8    Distal Columella_Up
# 9    Distal Columella_Up
# 10   Distal Columella_Up
# 11   Distal Columella_Up
# 12   Distal Columella_Down
# 13   Distal Columella_Up
# 14   Distal Columella_Up
# 15   Distal Columella_Up
# 16   Distal Columella_Up
# 17   Distal Columella_Up
# 18   Distal Columella_Up
# 19   Distal Columella_Down
# 20   Distal Columella_Up
# 21   Distal Columella_Up
# 22   Distal Columella_Down
# 23   Distal Columella_Down
# 24   Distal Columella_Up
# 25   Distal Columella_Down
# 26   Distal Columella_Up
# 27   Distal Columella_Down
# 28   Distal Columella_Up
# 29   Distal Columella_Up
# 30   Distal Columella_Up
# ⋮    ⋮
# 7813 Transition Domain_Trichoblast_Up
# 7814 Transition Domain_Trichoblast_Up
# 7815 Transition Domain_Trichoblast_Down
# 7816 Transition Domain_Trichoblast_Down
# 7817 Transition Domain_Trichoblast_Up
# 7818 Transition Domain_Trichoblast_Up
# 7819 Transition Domain_Trichoblast_Down
# 7820 Transition Domain_Trichoblast_Down
# 7821 Transition Domain_Trichoblast_Down
# 7822 Transition Domain_Trichoblast_Up
# 7823 Transition Domain_Trichoblast_Up
# 7824 Transition Domain_Trichoblast_Down
# 7825 Transition Domain_Trichoblast_Down
# 7826 Transition Domain_Trichoblast_Up
# 7827 Transition Domain_Trichoblast_Down
# 7828 Transition Domain_Trichoblast_Up
# 7829 Transition Domain_Trichoblast_Down
# 7830 Transition Domain_Trichoblast_Down
# 7831 Transition Domain_Trichoblast_Up
# 7832 Transition Domain_Trichoblast_Up
# 7833 Transition Domain_Trichoblast_Down
# 7834 Transition Domain_Trichoblast_Down
# 7835 Transition Domain_Trichoblast_Down
# 7836 Transition Domain_Trichoblast_Down
# 7837 Transition Domain_Trichoblast_Up
# 7838 Transition Domain_Trichoblast_Up
# 7839 Transition Domain_Trichoblast_Up
# 7840 Transition Domain_Trichoblast_Up
# 7841 Transition Domain_Trichoblast_Down
# 7842 Transition Domain_Trichoblast_Down

# %%
sig_DE_fil
write.csv(sig_DE_fil, file = "./output/v4_gtl1_v_WT_cell_time_EdgeR_q0.05_FC1.5_r_v_4_20220121.csv")
# Out:
#      gene      cluster_id                    sc_122.cpm sc_126.cpm sc_123.cpm
# 1    AT1G01470 Distal Columella              3150.0     3230.0     1790.00
# 2    AT1G05680 Distal Columella               735.0      812.0      509.00
# 3    AT1G06080 Distal Columella                11.1       15.8       43.10
# 4    AT1G12560 Distal Columella                12.6       21.1       29.40
# 5    AT1G14960 Distal Columella                48.8       56.7       84.40
# 6    AT1G15380 Distal Columella                15.6       52.7       57.30
# 7    AT1G19840 Distal Columella                10.5       10.8       23.00
# 8    AT1G23720 Distal Columella                41.0       53.7       81.00
# 9    AT1G30135 Distal Columella               102.0       39.4       92.10
# 10   AT1G32010 Distal Columella                 0.0        0.0       81.00
# 11   AT1G33800 Distal Columella                32.6       22.3       51.90
# 12   AT1G35140 Distal Columella                27.8       52.4       15.50
# 13   AT1G53060 Distal Columella                40.7       40.7       65.00
# 14   AT1G54000 Distal Columella               423.0      353.0      525.00
# 15   AT1G55240 Distal Columella                11.7       30.4       30.20
# 16   AT1G61740 Distal Columella                11.7       11.8       22.20
# 17   AT1G66200 Distal Columella                29.3       25.8       83.90
# 18   AT1G67920 Distal Columella                57.8       53.7       98.30
# 19   AT1G71380 Distal Columella                40.7       86.6       33.80
# 20   AT1G72140 Distal Columella                39.2       25.8       74.80
# 21   AT1G74930 Distal Columella                25.1       13.6       35.10
# 22   AT1G75600 Distal Columella               100.0      191.0       86.40
# 23   AT1G79040 Distal Columella                26.0       11.5        8.26
# 24   AT5G02550 Distal Columella                23.6       20.8       42.10
# 25   AT5G04120 Distal Columella                76.3       76.0       42.80
# 26   AT5G05500 Distal Columella                16.5       17.6       56.00
# 27   AT5G06760 Distal Columella                41.6       43.4       17.80
# 28   AT5G11670 Distal Columella                73.6       65.0      101.00
# 29   AT5G13220 Distal Columella               107.0       61.0      152.00
# 30   AT5G14700 Distal Columella                77.8       55.2      145.00
# ⋮    ⋮         ⋮                             ⋮          ⋮          ⋮
# 7813 AT4G28650 Transition Domain_Trichoblast   44.00      74.00      86.10
# 7814 AT4G28890 Transition Domain_Trichoblast   10.30      12.30      17.90
# 7815 AT4G29070 Transition Domain_Trichoblast   38.00      18.90      14.60
# 7816 AT4G29670 Transition Domain_Trichoblast   58.10      23.80      22.20
# 7817 AT4G30170 Transition Domain_Trichoblast 1790.00    2420.00    3020.00
# 7818 AT4G30670 Transition Domain_Trichoblast   74.90      74.00     139.00
# 7819 AT4G31320 Transition Domain_Trichoblast  211.00     159.00     109.00
# 7820 AT4G32480 Transition Domain_Trichoblast  219.00     156.00      87.30
# 7821 AT4G32590 Transition Domain_Trichoblast   18.70      11.60       9.12
# 7822 AT4G32620 Transition Domain_Trichoblast    6.58       7.72      12.50
# 7823 AT4G32720 Transition Domain_Trichoblast   17.70      14.70      31.30
# 7824 AT4G33467 Transition Domain_Trichoblast  188.00      86.30      69.30
# 7825 AT4G33666 Transition Domain_Trichoblast   27.50       5.96       7.91
# 7826 AT4G34050 Transition Domain_Trichoblast  197.00     143.00     273.00
# 7827 AT4G34210 Transition Domain_Trichoblast   37.80      25.60      12.20
# 7828 AT4G34580 Transition Domain_Trichoblast    7.59      13.00      25.20
# 7829 AT4G34800 Transition Domain_Trichoblast  143.00      73.60      45.90
# 7830 AT4G34810 Transition Domain_Trichoblast   30.20      20.00      12.20
# 7831 AT4G34920 Transition Domain_Trichoblast    5.91       5.61      13.70
# 7832 AT4G35920 Transition Domain_Trichoblast   15.40      10.20      24.00
# 7833 AT4G36010 Transition Domain_Trichoblast  394.00     507.00     202.00
# 7834 AT4G36500 Transition Domain_Trichoblast 1030.00     434.00     577.00
# 7835 AT4G36880 Transition Domain_Trichoblast  145.00     217.00      71.50
# 7836 AT4G36900 Transition Domain_Trichoblast  164.00     117.00      70.60
# 7837 AT4G36990 Transition Domain_Trichoblast   49.30      37.20      68.10
# 7838 AT4G37640 Transition Domain_Trichoblast  110.00     166.00     210.00
# 7839 ATMG00270 Transition Domain_Trichoblast   30.20      94.30      74.20
# 7840 ATCG00450 Transition Domain_Trichoblast    0.00       0.00       0.00
# 7841 AT3G43990 Transition Domain_Trichoblast   15.20       0.00       0.00
# 7842 ATCG00030 Transition Domain_Trichoblast   72.20     196.00     137.00
#      sc_127.cpm sc_122.frq sc_126.frq sc_123.frq sc_127.frq ⋯ F     p_val
# 1    1650.00    0.9660     0.9260     0.8660     0.8360     ⋯  28.7 8.68e-08
# 2     497.00    0.5870     0.5500     0.5100     0.4600     ⋯  13.9 1.98e-04
# 3      46.50    0.0503     0.0853     0.1900     0.2000     ⋯  66.9 2.97e-16
# 4      27.90    0.0610     0.1430     0.1570     0.1470     ⋯  13.4 2.55e-04
# 5      79.90    0.2440     0.3430     0.4230     0.3730     ⋯  12.8 3.53e-04
# 6      46.50    0.0664     0.1490     0.1990     0.1730     ⋯  13.9 1.95e-04
# 7      17.80    0.0610     0.0775     0.1360     0.1020     ⋯  15.4 8.50e-05
# 8      82.40    0.2030     0.2930     0.3490     0.3390     ⋯  19.3 1.13e-05
# 9     125.00    0.2550     0.1690     0.2650     0.2710     ⋯  16.3 5.47e-05
# 10      0.00    0.0000     0.0000     0.4090     0.0000     ⋯ 226.0 7.69e-51
# 11     38.00    0.1720     0.1490     0.2700     0.1980     ⋯  13.3 2.68e-04
# 12      9.49    0.0934     0.1630     0.0688     0.0490     ⋯  55.2 1.15e-13
# 13     66.10    0.1180     0.1400     0.1890     0.1860     ⋯  13.9 1.90e-04
# 14    677.00    0.6570     0.5720     0.7270     0.7250     ⋯  14.0 1.84e-04
# 15     37.00    0.0503     0.1120     0.1060     0.1260     ⋯  12.9 3.30e-04
# 16     19.90    0.0628     0.0775     0.1180     0.0998     ⋯  13.2 2.83e-04
# 17     88.80    0.1530     0.1650     0.4130     0.3940     ⋯  75.4 4.23e-18
# 18     76.80    0.2350     0.2270     0.3440     0.2660     ⋯  13.1 3.04e-04
# 19     39.20    0.0862     0.1940     0.0988     0.0923     ⋯  15.0 1.10e-04
# 20     62.80    0.1690     0.1360     0.2930     0.2350     ⋯  34.0 5.69e-09
# 21     40.40    0.1110     0.0853     0.1730     0.1470     ⋯  23.5 1.29e-06
# 22     75.90    0.2240     0.3020     0.2220     0.1810     ⋯  19.7 9.29e-06
# 23     10.40    0.1450     0.0833     0.0547     0.0527     ⋯  15.3 9.41e-05
# 24     35.80    0.1170     0.1260     0.2010     0.1680     ⋯  16.1 6.12e-05
# 25     39.80    0.3390     0.4150     0.2360     0.2130     ⋯  23.2 1.49e-06
# 26     39.50    0.0844     0.1120     0.2520     0.1860     ⋯  50.8 1.04e-12
# 27     14.40    0.1940     0.2210     0.1060     0.0810     ⋯  45.1 1.96e-11
# 28    113.00    0.2980     0.3430     0.4340     0.4260     ⋯  12.9 3.28e-04
# 29    170.00    0.3790     0.3200     0.5220     0.5050     ⋯  31.7 1.80e-08
# 30    133.00    0.3090     0.2730     0.4480     0.3950     ⋯  38.0 7.21e-10
# ⋮    ⋮          ⋮          ⋮          ⋮          ⋮          ⋱ ⋮     ⋮
# 7813   93.70    0.4290     0.4580     0.4190     0.3380     ⋯  12.2 4.80e-04
# 7814   22.00    0.1500     0.1320     0.1660     0.1430     ⋯  10.5 1.19e-03
# 7815   13.50    0.2760     0.1420     0.1180     0.0966     ⋯  17.3 3.22e-05
# 7816   14.70    0.3450     0.1890     0.1450     0.1140     ⋯  24.6 6.97e-07
# 7817 3260.00    0.9550     0.9860     0.9830     0.9570     ⋯  26.7 2.44e-07
# 7818   89.60    0.4590     0.4150     0.5260     0.4010     ⋯  10.9 9.67e-04
# 7819   79.00    0.6040     0.4200     0.4600     0.3650     ⋯  32.1 1.48e-08
# 7820   78.40    0.6010     0.5470     0.4390     0.4280     ⋯  44.3 2.82e-11
# 7821    5.87    0.2070     0.1040     0.0865     0.0435     ⋯  12.6 3.90e-04
# 7822   16.40    0.1140     0.0943     0.1180     0.1060     ⋯  12.4 4.40e-04
# 7823   28.20    0.2160     0.1700     0.2250     0.1690     ⋯  14.6 1.34e-04
# 7824   41.70    0.4590     0.4340     0.3940     0.2680     ⋯  45.8 1.35e-11
# 7825    4.11    0.1680     0.0472     0.0727     0.0338     ⋯  21.5 3.48e-06
# 7826  308.00    0.8200     0.7640     0.8790     0.7710     ⋯  24.2 8.90e-07
# 7827    9.40    0.2640     0.1700     0.1040     0.0725     ⋯  40.1 2.42e-10
# 7828   18.20    0.1110     0.1460     0.2210     0.1180     ⋯  20.6 5.73e-06
# 7829   33.80    0.4350     0.3070     0.2730     0.1860     ⋯  51.7 6.56e-13
# 7830    8.22    0.2460     0.1370     0.1070     0.0652     ⋯  26.2 3.12e-07
# 7831    9.11    0.0931     0.0660     0.1420     0.0749     ⋯  10.9 9.71e-04
# 7832   21.70    0.2040     0.1080     0.1830     0.1450     ⋯  11.6 6.60e-04
# 7833  208.00    0.6310     0.6840     0.5160     0.4490     ⋯  55.3 1.08e-13
# 7834  332.00    0.9580     0.9390     0.9450     0.9030     ⋯  19.8 8.80e-06
# 7835  150.00    0.4590     0.4620     0.2980     0.3140     ⋯  20.5 5.99e-06
# 7836   57.00    0.4950     0.4340     0.3490     0.3330     ⋯  38.9 4.56e-10
# 7837   75.50    0.4140     0.3920     0.3940     0.4370     ⋯  14.1 1.75e-04
# 7838  206.00    0.5560     0.5850     0.5570     0.5310     ⋯  14.6 1.33e-04
# 7839   92.50    0.3240     0.5470     0.4530     0.3700     ⋯  10.2 1.40e-03
# 7840  125.00    0.0000     0.0000     0.0000     0.4590     ⋯ 230.0 1.23e-51
# 7841    0.00    0.2100     0.0000     0.0000     0.0000     ⋯  62.4 2.91e-15
# 7842    0.00    0.5440     0.6040     0.5400     0.0000     ⋯  45.6 1.46e-11
#      p_adj.loc p_adj.glb contrast Name      TF_Name
# 1    4.75e-05  4.55e-02  gtl1-WT  LEA14     NA
# 2    3.00e-02  1.00e+00  gtl1-WT  UGT74E2   NA
# 3    1.15e-12  1.57e-10  gtl1-WT  ADS1      NA
# 4    3.54e-02  1.00e+00  gtl1-WT  EXPA7     NA
# 5    4.37e-02  1.00e+00  gtl1-WT  AT1G14960 NA
# 6    2.98e-02  1.00e+00  gtl1-WT  AT1G15380 NA
# 7    1.50e-02  1.00e+00  gtl1-WT  AT1G19840 NA
# 8    2.93e-03  1.00e+00  gtl1-WT  AT1G23720 NA
# 9    1.07e-02  1.00e+00  gtl1-WT  TIFY5A    JAZ8
# 10   1.51e-46  4.05e-45  gtl1-WT  AT1G32010 NA
# 11   3.59e-02  1.00e+00  gtl1-WT  GXM3      NA
# 12   2.82e-10  6.03e-08  gtl1-WT  EXL1      NA
# 13   2.93e-02  1.00e+00  gtl1-WT  AT1G53060 NA
# 14   2.85e-02  1.00e+00  gtl1-WT  GLL22     NA
# 15   4.16e-02  1.00e+00  gtl1-WT  AT1G55240 NA
# 16   3.72e-02  1.00e+00  gtl1-WT  AT1G61740 NA
# 17   2.78e-14  2.23e-12  gtl1-WT  ATGSR2    NA
# 18   3.91e-02  1.00e+00  gtl1-WT  AT1G67920 NA
# 19   1.83e-02  1.00e+00  gtl1-WT  CEL3      NA
# 20   4.31e-06  2.99e-03  gtl1-WT  NPF5.12   NA
# 21   4.17e-04  6.75e-01  gtl1-WT  ERF018    ORA47
# 22   2.51e-03  1.00e+00  gtl1-WT  AT1G75600 NA
# 23   1.63e-02  1.00e+00  gtl1-WT  PSBR      NA
# 24   1.15e-02  1.00e+00  gtl1-WT  AT5G02550 NA
# 25   4.73e-04  7.78e-01  gtl1-WT  IPSP      NA
# 26   2.04e-09  5.46e-07  gtl1-WT  AT5G05500 NA
# 27   2.98e-08  1.03e-05  gtl1-WT  LEA46     NA
# 28   4.16e-02  1.00e+00  gtl1-WT  NADP-ME2  NA
# 29   1.25e-05  9.43e-03  gtl1-WT  JAZ10     JAZ10
# 30   7.89e-07  3.79e-04  gtl1-WT  AT5G14700 NA
# ⋮    ⋮         ⋮         ⋮        ⋮         ⋮
# 7813 1.83e-02  1.00e+00  gtl1-WT  MIK1      NA
# 7814 3.64e-02  1.00e+00  gtl1-WT  ATL42     NA
# 7815 2.10e-03  1.00e+00  gtl1-WT  AT4G29070 NA
# 7816 7.68e-05  3.65e-01  gtl1-WT  ACHT2     NA
# 7817 3.29e-05  1.28e-01  gtl1-WT  PER45     NA
# 7818 3.13e-02  1.00e+00  gtl1-WT  AT4G30670 NA
# 7819 2.72e-06  7.79e-03  gtl1-WT  AT4G31320 NA
# 7820 9.99e-09  1.49e-05  gtl1-WT  AT4G32480 NA
# 7821 1.56e-02  1.00e+00  gtl1-WT  AT4G32590 NA
# 7822 1.72e-02  1.00e+00  gtl1-WT  AT4G32620 NA
# 7823 6.85e-03  1.00e+00  gtl1-WT  LA1       NA
# 7824 5.45e-09  7.09e-06  gtl1-WT  AT4G33467 NA
# 7825 3.04e-04  1.00e+00  gtl1-WT  AT4G33666 NA
# 7826 9.43e-05  4.66e-01  gtl1-WT  CCoAOMT1  NA
# 7827 7.27e-08  1.27e-04  gtl1-WT  ASK11     NA
# 7828 4.65e-04  1.00e+00  gtl1-WT  SFH1      NA
# 7829 3.47e-10  3.45e-07  gtl1-WT  AT4G34800 NA
# 7830 3.94e-05  1.64e-01  gtl1-WT  AT4G34810 NA
# 7831 3.13e-02  1.00e+00  gtl1-WT  AT4G34920 NA
# 7832 2.36e-02  1.00e+00  gtl1-WT  MCA1      NA
# 7833 7.38e-11  5.69e-08  gtl1-WT  AT4G36010 NA
# 7834 6.65e-04  1.00e+00  gtl1-WT  AT4G36500 NA
# 7835 4.81e-04  1.00e+00  gtl1-WT  CP1       NA
# 7836 1.25e-07  2.40e-04  gtl1-WT  RAP2-10   RAP2.10
# 7837 8.35e-03  1.00e+00  gtl1-WT  HSFB1     HSF4
# 7838 6.83e-03  1.00e+00  gtl1-WT  ACA2      NA
# 7839 4.10e-02  1.00e+00  gtl1-WT  NAD6      NA
# 7840 1.22e-47  6.49e-46  gtl1-WT  TRNV.1    NA
# 7841 2.68e-12  1.53e-09  gtl1-WT  AT3G43990 NA
# 7842 5.78e-09  7.68e-06  gtl1-WT  TRNK      NA
#      Description                                    up_dn_label
# 1    NA                                             Down
# 2    NA                                             Down
# 3    NA                                             Up
# 4    NA                                             Up
# 5    NA                                             Up
# 6    NA                                             Up
# 7    NA                                             Up
# 8    NA                                             Up
# 9    jasmonate-zim-domain protein 8                 Up
# 10   NA                                             Up
# 11   NA                                             Up
# 12   NA                                             Down
# 13   NA                                             Up
# 14   NA                                             Up
# 15   NA                                             Up
# 16   NA                                             Up
# 17   NA                                             Up
# 18   NA                                             Up
# 19   NA                                             Down
# 20   NA                                             Up
# 21   Integrase-type DNA-binding superfamily protein Up
# 22   NA                                             Down
# 23   NA                                             Down
# 24   NA                                             Up
# 25   NA                                             Down
# 26   NA                                             Up
# 27   NA                                             Down
# 28   NA                                             Up
# 29   jasmonate-zim-domain protein 10                Up
# 30   NA                                             Up
# ⋮    ⋮                                              ⋮
# 7813 NA                                             Up
# 7814 NA                                             Up
# 7815 NA                                             Down
# 7816 NA                                             Down
# 7817 NA                                             Up
# 7818 NA                                             Up
# 7819 NA                                             Down
# 7820 NA                                             Down
# 7821 NA                                             Down
# 7822 NA                                             Up
# 7823 NA                                             Up
# 7824 NA                                             Down
# 7825 NA                                             Down
# 7826 NA                                             Up
# 7827 NA                                             Down
# 7828 NA                                             Up
# 7829 NA                                             Down
# 7830 NA                                             Down
# 7831 NA                                             Up
# 7832 NA                                             Up
# 7833 NA                                             Down
# 7834 NA                                             Down
# 7835 NA                                             Down
# 7836 related to AP2 10                              Down
# 7837 heat shock factor 4                            Up
# 7838 NA                                             Up
# 7839 NA                                             Up
# 7840 NA                                             Up
# 7841 NA                                             Down
# 7842 NA                                             Down
#      clust_up_dn
# 1    Distal Columella_Down
# 2    Distal Columella_Down
# 3    Distal Columella_Up
# 4    Distal Columella_Up
# 5    Distal Columella_Up
# 6    Distal Columella_Up
# 7    Distal Columella_Up
# 8    Distal Columella_Up
# 9    Distal Columella_Up
# 10   Distal Columella_Up
# 11   Distal Columella_Up
# 12   Distal Columella_Down
# 13   Distal Columella_Up
# 14   Distal Columella_Up
# 15   Distal Columella_Up
# 16   Distal Columella_Up
# 17   Distal Columella_Up
# 18   Distal Columella_Up
# 19   Distal Columella_Down
# 20   Distal Columella_Up
# 21   Distal Columella_Up
# 22   Distal Columella_Down
# 23   Distal Columella_Down
# 24   Distal Columella_Up
# 25   Distal Columella_Down
# 26   Distal Columella_Up
# 27   Distal Columella_Down
# 28   Distal Columella_Up
# 29   Distal Columella_Up
# 30   Distal Columella_Up
# ⋮    ⋮
# 7813 Transition Domain_Trichoblast_Up
# 7814 Transition Domain_Trichoblast_Up
# 7815 Transition Domain_Trichoblast_Down
# 7816 Transition Domain_Trichoblast_Down
# 7817 Transition Domain_Trichoblast_Up
# 7818 Transition Domain_Trichoblast_Up
# 7819 Transition Domain_Trichoblast_Down
# 7820 Transition Domain_Trichoblast_Down
# 7821 Transition Domain_Trichoblast_Down
# 7822 Transition Domain_Trichoblast_Up
# 7823 Transition Domain_Trichoblast_Up
# 7824 Transition Domain_Trichoblast_Down
# 7825 Transition Domain_Trichoblast_Down
# 7826 Transition Domain_Trichoblast_Up
# 7827 Transition Domain_Trichoblast_Down
# 7828 Transition Domain_Trichoblast_Up
# 7829 Transition Domain_Trichoblast_Down
# 7830 Transition Domain_Trichoblast_Down
# 7831 Transition Domain_Trichoblast_Up
# 7832 Transition Domain_Trichoblast_Up
# 7833 Transition Domain_Trichoblast_Down
# 7834 Transition Domain_Trichoblast_Down
# 7835 Transition Domain_Trichoblast_Down
# 7836 Transition Domain_Trichoblast_Down
# 7837 Transition Domain_Trichoblast_Up
# 7838 Transition Domain_Trichoblast_Up
# 7839 Transition Domain_Trichoblast_Up
# 7840 Transition Domain_Trichoblast_Up
# 7841 Transition Domain_Trichoblast_Down
# 7842 Transition Domain_Trichoblast_Down

# %%
# add DE and up/dn to total list
sig_to_join <- sig_DE_fil %>%
mutate(clust_gene=paste(cluster_id, gene, sep="_")) %>%
select(clust_gene, up_dn_label, clust_up_dn)

# %%
# join all genes list to DE labels
all_bg <- mutate(all_bg, clust_gene=paste(cluster_id, gene, sep="_"))

all_bg <- left_join(all_bg, feature_names, by=c("gene"="AGI"))

all_bg$DE <- all_bg$clust_gene %in% sig_to_join$clust_gene


all_bg <- all_bg %>%
left_join(sig_to_join, by="clust_gene") %>%
arrange(all_bg, p_adj.loc)

write.csv(all_bg, file = "./output/v4_all_gtl1_v_WT_cell_time_EdgeR_q0.05_FC1.5_r_v_4_20220121.csv")
