# %% [markdown]
# ## bri1-related DEG plots

# %%
library(tidyverse)
library(Seurat)
library(cowplot)
library(ComplexHeatmap)
library(circlize)
library(GeneOverlap)
library(gprofiler2)
library(patchwork)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Registered S3 method overwritten by 'spatstat.geom':
#   method     from
#   print.boxx cli
#
# Attaching SeuratObject
#
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.11.1
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite:
# Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#   genomic data. Bioinformatics 2016.
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
# ========================================
# circlize version 0.4.14
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: https://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(circlize))
# ========================================
#
#
#
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     align_plots

# %%
sessionInfo()
# Out:
# R version 4.0.0 (2020-04-24)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 16.04.6 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/tmnolan7/anaconda3/envs/r_4/lib/libopenblasp-r0.3.9.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] grid      stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] patchwork_1.1.0       gprofiler2_0.2.0      GeneOverlap_1.24.0
#  [4] circlize_0.4.14       ComplexHeatmap_2.11.1 cowplot_1.1.0
#  [7] SeuratObject_4.0.2    Seurat_4.0.5          forcats_0.5.0
# [10] stringr_1.4.0         dplyr_1.0.7           purrr_0.3.4
# [13] readr_1.4.0           tidyr_1.1.4           tibble_3.1.5
# [16] ggplot2_3.3.5         tidyverse_1.3.0
#
# loaded via a namespace (and not attached):
#   [1] readxl_1.3.1          uuid_0.1-4            backports_1.2.0
#   [4] plyr_1.8.6            igraph_1.2.7          repr_1.1.0
#   [7] lazyeval_0.2.2        splines_4.0.0         listenv_0.8.0
#  [10] scattermore_0.7       digest_0.6.29         foreach_1.5.2
#  [13] htmltools_0.5.0       fansi_0.5.0           magrittr_2.0.1
#  [16] tensor_1.5            cluster_2.1.0         doParallel_1.0.17
#  [19] ROCR_1.0-11           globals_0.14.0        modelr_0.1.8
#  [22] matrixStats_0.61.0    spatstat.sparse_2.0-0 colorspace_2.0-3
#  [25] rvest_0.3.6           ggrepel_0.8.2         haven_2.3.1
#  [28] crayon_1.5.0          jsonlite_1.7.1        spatstat.data_2.1-0
#  [31] survival_3.2-7        zoo_1.8-8             iterators_1.0.14
#  [34] glue_1.4.2            polyclip_1.10-0       gtable_0.3.0
#  [37] leiden_0.3.5          GetoptLong_1.0.5      shape_1.4.6
#  [40] future.apply_1.8.1    BiocGenerics_0.36.1   abind_1.4-5
#  [43] scales_1.1.1          DBI_1.1.0             miniUI_0.1.1.1
#  [46] Rcpp_1.0.7            viridisLite_0.4.0     xtable_1.8-4
#  [49] clue_0.3-60           reticulate_1.18       spatstat.core_2.3-0
#  [52] stats4_4.0.0          htmlwidgets_1.5.2     httr_1.4.2
#  [55] gplots_3.1.0          RColorBrewer_1.1-2    ellipsis_0.3.2
#  [58] ica_1.0-2             pkgconfig_2.0.3       uwot_0.1.10
#  [61] dbplyr_2.0.0          deldir_1.0-5          utf8_1.2.2
#  [64] tidyselect_1.1.1      rlang_0.4.12          reshape2_1.4.4
#  [67] later_1.1.0.1         munsell_0.5.0         cellranger_1.1.0
#  [70] tools_4.0.0           cli_3.0.1             generics_0.1.0
#  [73] broom_0.7.2           ggridges_0.5.2        evaluate_0.14
#  [76] fastmap_1.0.1         goftest_1.2-3         fs_1.5.0
#  [79] fitdistrplus_1.1-1    caTools_1.18.0        RANN_2.6.1
#  [82] pbapply_1.5-0         future_1.22.1         nlme_3.1-150
#  [85] mime_0.9              xml2_1.3.2            compiler_4.0.0
#  [88] rstudioapi_0.11       plotly_4.9.2.1        png_0.1-7
#  [91] spatstat.utils_2.2-0  reprex_0.3.0          stringi_1.4.6
#  [94] lattice_0.20-41       IRdisplay_0.7.0       Matrix_1.3-4
#  [97] vctrs_0.3.8           pillar_1.6.4          lifecycle_1.0.1
# [100] spatstat.geom_2.3-0   lmtest_0.9-38         GlobalOptions_0.1.2
# [103] RcppAnnoy_0.0.19      bitops_1.0-7          data.table_1.14.2
# [106] irlba_2.3.3           httpuv_1.5.4          R6_2.5.1
# [109] promises_1.1.1        KernSmooth_2.23-18    gridExtra_2.3
# [112] IRanges_2.24.1        parallelly_1.28.1     codetools_0.2-18
# [115] gtools_3.8.2          MASS_7.3-53           assertthat_0.2.1
# [118] rjson_0.2.21          withr_2.4.2           sctransform_0.3.2
# [121] S4Vectors_0.28.1      mgcv_1.8-33           parallel_4.0.0
# [124] hms_0.5.3             rpart_4.1-15          IRkernel_1.1.1
# [127] Rtsne_0.15            pbdZMQ_0.3-3.1        shiny_1.5.0
# [130] lubridate_1.8.0       base64enc_0.1-3

# %%
sig_DE_fil <- read_csv("./output/v4_bri1_T_v_WT_cell_time_EdgeR_q0.05_FC1.5_r_v_4_20220112.csv")

nb_genes_per_clust <- sig_DE_fil  %>%
  group_by(cluster_id) %>%
  tally()

# color up and down

nb_up_dn <- sig_DE_fil  %>%
  group_by(cluster_id, up_dn_label) %>%
  tally(name = "n_up_dn") %>%
left_join(nb_genes_per_clust)

nb_up_dn
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”
#
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   .default = col_double(),
#   gene = col_character(),
#   cluster_id = col_character(),
#   contrast = col_character(),
#   Name = col_character(),
#   TF_Name = col_character(),
#   Description = col_character(),
#   up_dn_label = col_character(),
#   clust_up_dn = col_character()
# )
# ℹ Use `spec()` for the full column specifications.
#
#
# Joining, by = "cluster_id"
#    cluster_id                        up_dn_label n_up_dn n
# 1  Distal Columella                  Down         520    1036
# 2  Distal Columella                  Up           516    1036
# 3  Distal Lateral Root Cap           Down         711    1271
# 4  Distal Lateral Root Cap           Up           560    1271
# 5  Elongation_Atrichoblast           Down        1509    2491
# 6  Elongation_Atrichoblast           Up           982    2491
# 7  Elongation_Cortex                 Down        1634    2765
# 8  Elongation_Cortex                 Up          1131    2765
# 9  Elongation_Endodermis             Down        1550    3141
# 10 Elongation_Endodermis             Up          1591    3141
# 11 Elongation_Pericycle              Down         453    1349
# 12 Elongation_Pericycle              Up           896    1349
# 13 Elongation_Phloem                 Down         198     497
# 14 Elongation_Phloem                 Up           299     497
# 15 Elongation_Procambium             Down         530    1175
# 16 Elongation_Procambium             Up           645    1175
# 17 Elongation_Trichoblast            Down         709    1360
# 18 Elongation_Trichoblast            Up           651    1360
# 19 Elongation_Xylem                  Down         675    1384
# 20 Elongation_Xylem                  Up           709    1384
# 21 Maturation_Atrichoblast           Down        1681    2783
# 22 Maturation_Atrichoblast           Up          1102    2783
# 23 Maturation_Cortex                 Down        1131    2187
# 24 Maturation_Cortex                 Up          1056    2187
# 25 Maturation_Endodermis             Down          12      37
# 26 Maturation_Endodermis             Up            25      37
# 27 Maturation_Pericycle              Down          30      73
# 28 Maturation_Pericycle              Up            43      73
# 29 Maturation_Phloem                 Down          66     115
# 30 Maturation_Phloem                 Up            49     115
# 31 Maturation_Procambium             Down         502    1237
# 32 Maturation_Procambium             Up           735    1237
# 33 Maturation_Trichoblast            Down        1639    2848
# 34 Maturation_Trichoblast            Up          1209    2848
# 35 Maturation_Xylem                  Down          25      57
# 36 Maturation_Xylem                  Up            32      57
# 37 Proliferation Domain_Atrichoblast Down         755    1944
# 38 Proliferation Domain_Atrichoblast Up          1189    1944
# 39 Proliferation Domain_Pericycle    Down         404     694
# 40 Proliferation Domain_Pericycle    Up           290     694
# 41 Proliferation Domain_Trichoblast  Down         764    1726
# 42 Proliferation Domain_Trichoblast  Up           962    1726
# 43 Proximal Columella                Down         390     453
# 44 Proximal Columella                Up            63     453
# 45 Proximal Lateral Root Cap         Down         794    1513
# 46 Proximal Lateral Root Cap         Up           719    1513
# 47 Transition Domain_Atrichoblast    Down         545    1038
# 48 Transition Domain_Atrichoblast    Up           493    1038
# 49 Transition Domain_Cortex          Down         680    1626
# 50 Transition Domain_Cortex          Up           946    1626
# 51 Transition Domain_Trichoblast     Down         391     949
# 52 Transition Domain_Trichoblast     Up           558     949

# %%
options(repr.plot.width=10, repr.plot.height=8)

nb_v <- ggplot(data=nb_up_dn, aes(x=reorder(cluster_id, n), y=n_up_dn, fill=factor(up_dn_label, levels=c("Up", "Down")))) +
  geom_bar(stat="identity", position="stack") + ylab("Number of DEGs") + xlab("") + 
scale_y_continuous(limits = c(0, 3400)) +
geom_text(aes(label=n, y = n), hjust=0, vjust=0.5, size=4)  + 
theme_cowplot()  +theme(plot.margin = margin(1,3,1,1, "cm"), 
                        legend.title=element_blank(), 
                       legend.position = c(0.7, 0.5)) + ggtitle("bri1-T vs WT DEGs")

(bri1_v_WT <- nb_v + coord_flip())
# Out:
# plot without title

# %%
# GO enrichment of DEGs

markers_sel <- select(sig_DE_fil, gene, clust_up_dn)

markers_list <- split(markers_sel, f=markers_sel$clust_up_dn)
 
#this makes list from long df of gene lists - TARGET is what we want to keep
markers_list  <- lapply(markers_list, function(x) x[names(x)=="gene"])
# convert each sublist into character and eliminate duplicates
markers_list  <- lapply(markers_list, function(x) as.character(unique(x$gene)))

cluster_GO <- gost(markers_list, organism = "athaliana", correction_method = "fdr", significant = F, multi_query = F)

# %%
cluster_GO_df <- cluster_GO[[1]]

cluster_GO_sig <- filter(cluster_GO_df, p_value<=0.01)

# top  terms for each cluster

cluster_GO_sig %>%
  filter(source=="GO:BP", intersection_size>=8) %>%
  group_by(query) %>%
  top_n(1, wt = -p_value) %>%
  arrange(desc(p_value)) -> top_GO

GO_n <- cluster_GO_sig %>%
  filter(source=="GO:BP", intersection_size>=8) %>%
  group_by(term_id) %>%
  tally() %>%
  arrange(desc(n))


GO_n <- dplyr::rename(GO_n, "n_clusters"=n)

cluster_GO_sig_n <- left_join(cluster_GO_sig, GO_n)

# get all terms for the top ones so that all clusters have values

top_GO_all <- filter(cluster_GO_df, term_id %in% top_GO$term_id)


#spread and plot


top_GO_sel <- select(top_GO_all, query, p_value, term_id, term_name)

spread_GO <- spread(top_GO_sel, key = query, p_value)

spread_GO[is.na(spread_GO)] <- 1

spread_GO_m <- as.matrix(-log10(spread_GO[3:ncol(spread_GO)]))
rownames(spread_GO_m) <- spread_GO$term_name


spread_GO_m_t <- t(spread_GO_m)

GO_hm_t <- Heatmap(spread_GO_m_t, 
                 name = "-log10_pval", 
                 heatmap_legend_param = list(title_position="leftcenter-rot", color_bar = "continuous"), 
                 col = colorRamp2(c(0, 20), c("beige", "darkgreen")), 
                 cluster_rows = T, 
                 cluster_columns = T, 
                 use_raster= FALSE, 
                 show_column_names = TRUE, 
                 show_row_names = TRUE, 
                 show_row_dend = TRUE, 
                 show_column_dend = TRUE,
                 column_names_rot = 45,
                 clustering_distance_columns = "pearson", 
                 clustering_distance_rows = "pearson",
                 row_names_gp = gpar(fontsize = 14), 
                column_names_gp = gpar(fontsize = 14))
# Out:
# Joining, by = "term_id"

# %%
options(repr.plot.width = 14, repr.plot.height = 16)

# padding - bottom, left, top, right
draw(GO_hm_t, padding = unit(c(80, 30, 5, 80), "mm"), heatmap_legend_side = "left")
# Out:
# plot without title

# %%
pdf("./output/bri1-T_GO_hm.pdf", width = 14, height = 16)


# padding - bottom, left, top, right
draw(GO_hm_t, padding = unit(c(80, 30, 5, 80), "mm"), heatmap_legend_side = "left")

dev.off()
# Out:
# png
#   2

# %%
sig_DE_fil <- read_csv("./output/v4_pGL2-BRI1-bri1_T_v_WT_cell_time_EdgeR_q0.05_FC1.5_r_v_4_20220112.csv")

nb_genes_per_clust <- sig_DE_fil  %>%
  group_by(cluster_id) %>%
  tally()

# color up and down

nb_up_dn <- sig_DE_fil  %>%
  group_by(cluster_id, up_dn_label) %>%
  tally(name = "n_up_dn") %>%
left_join(nb_genes_per_clust)

nb_up_dn
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”
#
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   .default = col_double(),
#   gene = col_character(),
#   cluster_id = col_character(),
#   contrast = col_character(),
#   Name = col_character(),
#   TF_Name = col_character(),
#   Description = col_character(),
#   up_dn_label = col_character(),
#   clust_up_dn = col_character()
# )
# ℹ Use `spec()` for the full column specifications.
#
#
# Joining, by = "cluster_id"
#    cluster_id                        up_dn_label n_up_dn n
# 1  Distal Columella                  Down         197     320
# 2  Distal Columella                  Up           123     320
# 3  Distal Lateral Root Cap           Down         386     588
# 4  Distal Lateral Root Cap           Up           202     588
# 5  Elongation_Atrichoblast           Down        1193    1964
# 6  Elongation_Atrichoblast           Up           771    1964
# 7  Elongation_Cortex                 Down         713    1252
# 8  Elongation_Cortex                 Up           539    1252
# 9  Elongation_Endodermis             Down        1346    2265
# 10 Elongation_Endodermis             Up           919    2265
# 11 Elongation_Pericycle              Down         634    1291
# 12 Elongation_Pericycle              Up           657    1291
# 13 Elongation_Phloem                 Down           8      29
# 14 Elongation_Phloem                 Up            21      29
# 15 Elongation_Procambium             Down         149     291
# 16 Elongation_Procambium             Up           142     291
# 17 Elongation_Trichoblast            Down         168     392
# 18 Elongation_Trichoblast            Up           224     392
# 19 Elongation_Xylem                  Down         399     680
# 20 Elongation_Xylem                  Up           281     680
# 21 Maturation_Cortex                 Down         159     410
# 22 Maturation_Cortex                 Up           251     410
# 23 Maturation_Endodermis             Down          54     164
# 24 Maturation_Endodermis             Up           110     164
# 25 Maturation_Pericycle              Up             3       3
# 26 Maturation_Phloem                 Down          40      85
# 27 Maturation_Phloem                 Up            45      85
# 28 Maturation_Procambium             Down         262     707
# 29 Maturation_Procambium             Up           445     707
# 30 Maturation_Trichoblast            Down         610    1076
# 31 Maturation_Trichoblast            Up           466    1076
# 32 Maturation_Xylem                  Down         231     366
# 33 Maturation_Xylem                  Up           135     366
# 34 Proliferation Domain_Atrichoblast Down        1301    3244
# 35 Proliferation Domain_Atrichoblast Up          1943    3244
# 36 Proliferation Domain_Pericycle    Down         147     345
# 37 Proliferation Domain_Pericycle    Up           198     345
# 38 Proliferation Domain_Trichoblast  Down         141     497
# 39 Proliferation Domain_Trichoblast  Up           356     497
# 40 Proximal Columella                Down          81      92
# 41 Proximal Columella                Up            11      92
# 42 Proximal Lateral Root Cap         Down         895    1564
# 43 Proximal Lateral Root Cap         Up           669    1564
# 44 Transition Domain_Atrichoblast    Down         796    1460
# 45 Transition Domain_Atrichoblast    Up           664    1460
# 46 Transition Domain_Cortex          Down         183     557
# 47 Transition Domain_Cortex          Up           374     557
# 48 Transition Domain_Trichoblast     Down          29     132
# 49 Transition Domain_Trichoblast     Up           103     132

# %%
options(repr.plot.width=10, repr.plot.height=8)

nb_v <- ggplot(data=nb_up_dn, aes(x=reorder(cluster_id, n), y=n_up_dn, fill=factor(up_dn_label, levels=c("Up", "Down")))) +
  geom_bar(stat="identity", position="stack") + ylab("Number of DEGs") + xlab("") + 
scale_y_continuous(limits = c(0, 3400)) +
geom_text(aes(label=n, y = n), hjust=0, vjust=0.5, size=4)  + 
theme_cowplot()  +theme(plot.margin = margin(1,3,1,1, "cm"), 
                        legend.title=element_blank(), 
                       legend.position = c(0.7, 0.5)) + ggtitle("pGL2-BRI1-bri1-T vs WT DEGs")

(pGL2_BRI1_bri1_T_v_WT <- nb_v + coord_flip())
# Out:
# plot without title

# %%
# GO enrichment of DEGs

markers_sel <- select(sig_DE_fil, gene, clust_up_dn)

markers_list <- split(markers_sel, f=markers_sel$clust_up_dn)
 
#this makes list from long df of gene lists - TARGET is what we want to keep
markers_list  <- lapply(markers_list, function(x) x[names(x)=="gene"])
# convert each sublist into character and eliminate duplicates
markers_list  <- lapply(markers_list, function(x) as.character(unique(x$gene)))

cluster_GO <- gost(markers_list, organism = "athaliana", correction_method = "fdr", significant = F, multi_query = F)

# %%
cluster_GO_df <- cluster_GO[[1]]

cluster_GO_sig <- filter(cluster_GO_df, p_value<=0.01)

# top  terms for each cluster

cluster_GO_sig %>%
  filter(source=="GO:BP", intersection_size>=8) %>%
  group_by(query) %>%
  top_n(1, wt = -p_value) %>%
  arrange(desc(p_value)) -> top_GO

GO_n <- cluster_GO_sig %>%
  filter(source=="GO:BP", intersection_size>=8) %>%
  group_by(term_id) %>%
  tally() %>%
  arrange(desc(n))


GO_n <- dplyr::rename(GO_n, "n_clusters"=n)

cluster_GO_sig_n <- left_join(cluster_GO_sig, GO_n)

# get all terms for the top ones so that all clusters have values

top_GO_all <- filter(cluster_GO_df, term_id %in% top_GO$term_id)


#spread and plot


top_GO_sel <- select(top_GO_all, query, p_value, term_id, term_name)

spread_GO <- spread(top_GO_sel, key = query, p_value)

spread_GO[is.na(spread_GO)] <- 1

spread_GO_m <- as.matrix(-log10(spread_GO[3:ncol(spread_GO)]))
rownames(spread_GO_m) <- spread_GO$term_name


spread_GO_m_t <- t(spread_GO_m)

GO_hm_t <- Heatmap(spread_GO_m_t, 
                 name = "-log10_pval", 
                 heatmap_legend_param = list(title_position="leftcenter-rot", color_bar = "continuous"), 
                 col = colorRamp2(c(0, 20), c("beige", "darkgreen")), 
                 cluster_rows = T, 
                 cluster_columns = T, 
                 use_raster= FALSE, 
                 show_column_names = TRUE, 
                 show_row_names = TRUE, 
                 show_row_dend = TRUE, 
                 show_column_dend = TRUE,
                 column_names_rot = 45,
                 clustering_distance_columns = "pearson", 
                 clustering_distance_rows = "pearson",
                 row_names_gp = gpar(fontsize = 14), 
                column_names_gp = gpar(fontsize = 14))
# Out:
# Joining, by = "term_id"

# %%
options(repr.plot.width = 14, repr.plot.height = 16)

# padding - bottom, left, top, right
draw(GO_hm_t, padding = unit(c(80, 30, 5, 80), "mm"), heatmap_legend_side = "left")
# Out:
# plot without title

# %%
pdf("./output/pGL2_BRI1_bri1_T_v_WT_GO_hm.pdf", width = 14, height = 16)


# padding - bottom, left, top, right
draw(GO_hm_t, padding = unit(c(80, 30, 5, 80), "mm"), heatmap_legend_side = "left")

dev.off()
# Out:
# png
#   2

# %%
sig_DE_fil <- read_csv("./output/v4_pGL2-BRI1-bri1_T_v_bri1-T_cell_time_EdgeR_q0.05_FC1.5_r_v_4_20220112.csv")

nb_genes_per_clust <- sig_DE_fil  %>%
  group_by(cluster_id) %>%
  tally()

# color up and down

nb_up_dn <- sig_DE_fil  %>%
  group_by(cluster_id, up_dn_label) %>%
  tally(name = "n_up_dn") %>%
left_join(nb_genes_per_clust)

nb_up_dn
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”
#
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   .default = col_double(),
#   gene = col_character(),
#   cluster_id = col_character(),
#   contrast = col_character(),
#   Name = col_character(),
#   TF_Name = col_character(),
#   Description = col_character(),
#   up_dn_label = col_character(),
#   clust_up_dn = col_character()
# )
# ℹ Use `spec()` for the full column specifications.
#
#
# Joining, by = "cluster_id"
#    cluster_id                        up_dn_label n_up_dn n
# 1  Distal Columella                  Down         210     477
# 2  Distal Columella                  Up           267     477
# 3  Distal Lateral Root Cap           Down         305     692
# 4  Distal Lateral Root Cap           Up           387     692
# 5  Elongation_Atrichoblast           Down         947    2044
# 6  Elongation_Atrichoblast           Up          1097    2044
# 7  Elongation_Cortex                 Down         655    1271
# 8  Elongation_Cortex                 Up           616    1271
# 9  Elongation_Endodermis             Down        1044    2077
# 10 Elongation_Endodermis             Up          1033    2077
# 11 Elongation_Pericycle              Down        1517    2447
# 12 Elongation_Pericycle              Up           930    2447
# 13 Elongation_Phloem                 Down         149     248
# 14 Elongation_Phloem                 Up            99     248
# 15 Elongation_Procambium             Down         376     508
# 16 Elongation_Procambium             Up           132     508
# 17 Elongation_Trichoblast            Down         416     576
# 18 Elongation_Trichoblast            Up           160     576
# 19 Elongation_Xylem                  Down         402     655
# 20 Elongation_Xylem                  Up           253     655
# 21 Maturation_Atrichoblast           Down         797    1417
# 22 Maturation_Atrichoblast           Up           620    1417
# 23 Maturation_Cortex                 Down         391     933
# 24 Maturation_Cortex                 Up           542     933
# 25 Maturation_Endodermis             Down          88     191
# 26 Maturation_Endodermis             Up           103     191
# 27 Maturation_Pericycle              Down         134     235
# 28 Maturation_Pericycle              Up           101     235
# 29 Maturation_Phloem                 Down          66     127
# 30 Maturation_Phloem                 Up            61     127
# 31 Maturation_Procambium             Down         235     485
# 32 Maturation_Procambium             Up           250     485
# 33 Maturation_Xylem                  Down         174     209
# 34 Maturation_Xylem                  Up            35     209
# 35 Proliferation Domain_Atrichoblast Down         969    1880
# 36 Proliferation Domain_Atrichoblast Up           911    1880
# 37 Proliferation Domain_Cortex       Down         383     469
# 38 Proliferation Domain_Cortex       Up            86     469
# 39 Proliferation Domain_Endodermis   Down         131     181
# 40 Proliferation Domain_Endodermis   Up            50     181
# 41 Proliferation Domain_Pericycle    Down         210     515
# 42 Proliferation Domain_Pericycle    Up           305     515
# 43 Proliferation Domain_Trichoblast  Down         574    1167
# 44 Proliferation Domain_Trichoblast  Up           593    1167
# 45 Proximal Columella                Down          11      34
# 46 Proximal Columella                Up            23      34
# 47 Proximal Lateral Root Cap         Down         494    1145
# 48 Proximal Lateral Root Cap         Up           651    1145
# 49 Transition Domain_Atrichoblast    Down         648    1368
# 50 Transition Domain_Atrichoblast    Up           720    1368
# 51 Transition Domain_Cortex          Down         560    1189
# 52 Transition Domain_Cortex          Up           629    1189
# 53 Transition Domain_Phloem          Up             1       1
# 54 Transition Domain_Trichoblast     Down         301     473
# 55 Transition Domain_Trichoblast     Up           172     473

# %%
options(repr.plot.width=10, repr.plot.height=8)

nb_v <- ggplot(data=nb_up_dn, aes(x=reorder(cluster_id, n), y=n_up_dn, fill=factor(up_dn_label, levels=c("Up", "Down")))) +
  geom_bar(stat="identity", position="stack") + ylab("Number of DEGs") + xlab("") + 
scale_y_continuous(limits = c(0, 3400)) +
geom_text(aes(label=n, y = n), hjust=0, vjust=0.5, size=4)  + 
theme_cowplot()  +theme(plot.margin = margin(1,3,1,1, "cm"), 
                        legend.title=element_blank(), 
                       legend.position = c(0.7, 0.5)) + ggtitle("pGL2-BRI1-bri1-T vs bri1-T DEGs")

(pGL2_BRI1_bri1_T_v_bri1_T <- nb_v + coord_flip())

#ggsave("./output/BL2hr_v_BRZ_vertical_num_DE_genes.png", width = 10, height = 8)
# Out:
# plot without title

# %%
options(repr.plot.width=27, repr.plot.height=8)

bri1_v_WT + pGL2_BRI1_bri1_T_v_WT + pGL2_BRI1_bri1_T_v_bri1_T

ggsave("./output/bri1-pGL2-n_DEGs_barplot.pdf", width = 30, height = 8)
# Out:
# plot without title

# %%
# GO enrichment of DEGs

markers_sel <- select(sig_DE_fil, gene, clust_up_dn)

markers_list <- split(markers_sel, f=markers_sel$clust_up_dn)
 
#this makes list from long df of gene lists - TARGET is what we want to keep
markers_list  <- lapply(markers_list, function(x) x[names(x)=="gene"])
# convert each sublist into character and eliminate duplicates
markers_list  <- lapply(markers_list, function(x) as.character(unique(x$gene)))

cluster_GO <- gost(markers_list, organism = "athaliana", correction_method = "fdr", significant = F, multi_query = F)

# %%
cluster_GO_df <- cluster_GO[[1]]

cluster_GO_sig <- filter(cluster_GO_df, p_value<=0.01)

# top  terms for each cluster

cluster_GO_sig %>%
  filter(source=="GO:BP", intersection_size>=8) %>%
  group_by(query) %>%
  top_n(1, wt = -p_value) %>%
  arrange(desc(p_value)) -> top_GO

GO_n <- cluster_GO_sig %>%
  filter(source=="GO:BP", intersection_size>=8) %>%
  group_by(term_id) %>%
  tally() %>%
  arrange(desc(n))


GO_n <- dplyr::rename(GO_n, "n_clusters"=n)

cluster_GO_sig_n <- left_join(cluster_GO_sig, GO_n)

# get all terms for the top ones so that all clusters have values

top_GO_all <- filter(cluster_GO_df, term_id %in% top_GO$term_id)


#spread and plot


top_GO_sel <- select(top_GO_all, query, p_value, term_id, term_name)

spread_GO <- spread(top_GO_sel, key = query, p_value)

spread_GO[is.na(spread_GO)] <- 1

spread_GO_m <- as.matrix(-log10(spread_GO[3:ncol(spread_GO)]))
rownames(spread_GO_m) <- spread_GO$term_name


spread_GO_m_t <- t(spread_GO_m)

GO_hm_t <- Heatmap(spread_GO_m_t, 
                 name = "-log10_pval", 
                 heatmap_legend_param = list(title_position="leftcenter-rot", color_bar = "continuous"), 
                 col = colorRamp2(c(0, 20), c("beige", "darkgreen")), 
                 cluster_rows = T, 
                 cluster_columns = T, 
                 use_raster= FALSE, 
                 show_column_names = TRUE, 
                 show_row_names = TRUE, 
                 show_row_dend = TRUE, 
                 show_column_dend = TRUE,
                 column_names_rot = 45,
                 clustering_distance_columns = "pearson", 
                 clustering_distance_rows = "pearson",
                 row_names_gp = gpar(fontsize = 14), 
                column_names_gp = gpar(fontsize = 14))
# Out:
# Joining, by = "term_id"

# %%
options(repr.plot.width = 14, repr.plot.height = 16)

# padding - bottom, left, top, right
draw(GO_hm_t, padding = unit(c(80, 30, 5, 80), "mm"), heatmap_legend_side = "left")
# Out:
# plot without title

# %%
pdf("./output/pGL2-BRI1-bri1-T_vs_bri1-T_GO_hm.pdf", width = 14, height = 16)


# padding - bottom, left, top, right
draw(GO_hm_t, padding = unit(c(80, 30, 5, 80), "mm"), heatmap_legend_side = "left")

dev.off()
# Out:
# png
#   2
