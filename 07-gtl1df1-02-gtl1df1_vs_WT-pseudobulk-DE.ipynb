# %% [markdown]
# # Pseudobulk differential expression to compare gtl1 df1 vs WT

# %%
library(tidyverse)
library(Seurat)
library(cowplot)
library(ComplexHeatmap)
library(circlize)
library(GeneOverlap)
library(gprofiler2)
library(ggrepel)
library(muscat)
library(purrr)
library(limma)
library(scran)
library(future)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Registered S3 method overwritten by 'spatstat.geom':
#   method     from
#   print.boxx cli
#
# Attaching SeuratObject
#
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.11.1
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite:
# Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#   genomic data. Bioinformatics 2016.
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
# ========================================
# circlize version 0.4.14
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: https://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(circlize))
# ========================================
#
#
# Warning message in checkMatrixPackageVersion():
# “Package version inconsistency detected.
# TMB was built with Matrix version 1.2.18
# Current Matrix version is 1.3.4
# Please re-install 'TMB' from source using install.packages('TMB', type = 'source') or ask CRAN for a binary version of 'TMB' matching CRAN's 'Matrix' package”
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SummarizedExperiment’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     Assays
#
#
# The following object is masked from ‘package:Seurat’:
#
#     Assays
#
#
#
# Attaching package: ‘future’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     values
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     values
#
#
# The following object is masked from ‘package:IRanges’:
#
#     values
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     values

# %%
#for 200gb ram 
options(future.globals.maxSize = 200000 * 1024^2)

# %%
rc.integrated <- readRDS("../data/integrations/rc.integrated_11S_gtl1_df1_Li_seu3_clean.rds")

# %%
rc.integrated
# Out:
# An object of class Seurat
# 70780 features across 74810 samples within 3 assays
# Active assay: integrated (17681 features, 17681 variable features)
#  2 other assays present: RNA, SCT
#  4 dimensional reductions calculated: pca, umap, umap_3D, umap_2D

# %% [markdown]
# ## Cell type and developmental stage metadata
#
# - Developmental stage: `time_zone`
# - Cell type:`cell_type`
# - Combination of cell type and developmental stage: `time_zone_cell_type`
# - Combination of cell type and developmental stage with cell subtypes (not used): `time_zone_cell_subtypes`

# %%
feature_names <- read_tsv("./data/features.tsv.gz", col_names = c("AGI", "Name", "Type")) %>%
  select(-Type) %>%
  distinct()
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   AGI = col_character(),
#   Name = col_character(),
#   Type = col_character()
# )

# %%
table(rc.integrated$genotype)
# Out:
#      df1     gtl1 gtl1_df1       WT
#    15678    22594    17634    18904

# %%
rc.integrated <- subset(rc.integrated, 
                        subset = sample %in% c("sc_122",
                                              "sc_123",
                                              "sc_124",
                                              "sc_125",
                                              "sc_126",
                                              "sc_127",
                                              "sc_128",
                                              "sc_129"))

# %%
rc.integrated$genotype <- factor(rc.integrated$genotype, 
                                 levels=c("WT", 
                                          "gtl1", 
                                          "df1", 
                                          "gtl1_df1"))

# %%
table(rc.integrated$genotype)
# Out:
#       WT     gtl1      df1 gtl1_df1
#    18904    22594    15678    17634

# %% [markdown]
# # Differential State Analysis with Muscat

# %%
# subset samples you want to compare

integrated.de <- subset(rc.integrated, subset = sample %in% c("sc_122", "sc_126","sc_125","sc_129"))
integrated.de$genotype <- factor(integrated.de$genotype, levels=c("WT", "gtl1_df1"))

# %%
integrated.de
# Out:
# An object of class Seurat
# 70780 features across 36538 samples within 3 assays
# Active assay: integrated (17681 features, 17681 variable features)
#  2 other assays present: RNA, SCT
#  4 dimensional reductions calculated: pca, umap, umap_3D, umap_2D

# %% [markdown]
# ## Convert to sce

# %%
#  construct sce manually
my_metadata <- data.frame(sample_id = integrated.de$sample,
                              group_id = integrated.de$genotype,
                              cluster_id = integrated.de$time_zone_cell_type, 
                             rep=integrated.de$rep) # include experimental rep as co-variate

sce <- SingleCellExperiment(assays = list(counts = integrated.de@assays$RNA@counts),
	                            colData = my_metadata)

# %%
    (sce <- prepSCE(sce, 
        kid = "cluster_id", # subpopulation assignments
        gid = "group_id",   # group IDs (ctrl/stim)
        sid = "sample_id",    # sample IDs (ctrl/stim.1234)
        drop = FALSE))        # drop all other colData columns
# Out:
# class: SingleCellExperiment
# dim: 28688 36538
# metadata(1): experiment_info
# assays(1): counts
# rownames(28688): AT1G01010 AT1G01020 ... AT5G37474 AT5G07835
# rowData names(0):
# colnames(36538): AAACCCAAGAGCCGTA_4 AAACCCAAGCATTGTC_4 ...
#   TTTGTTGTCGGCTGGT_11 TTTGTTGTCTCTGACC_11
# colData names(4): cluster_id sample_id group_id rep
# reducedDimNames(0):
# altExpNames(0):

# %% [markdown]
# ## pre-filtering

# %%
# remove undetected genes
sce <- sce[rowSums(counts(sce) > 0) > 0, ]
dim(sce)
# Out:
# [1] 26618 36538

# %%
# remove lowly expressed genes
sce <- sce[rowSums(counts(sce) > 1) >= 1, ]
dim(sce)
# Out:
# [1] 22341 36538

# %%
# create pseudobulk profiles
pb <- aggregateData(sce,
    assay = "counts", fun = "sum",
    by = c("cluster_id", "sample_id"))
# one sheet per subpopulation
assayNames(pb)
# Out:
#  [1] "Distal Columella"
#  [2] "Distal Lateral Root Cap"
#  [3] "Elongation_Atrichoblast"
#  [4] "Elongation_Cortex"
#  [5] "Elongation_Endodermis"
#  [6] "Elongation_Pericycle"
#  [7] "Elongation_Phloem"
#  [8] "Elongation_Procambium"
#  [9] "Elongation_Trichoblast"
# [10] "Elongation_Xylem"
# [11] "Maturation_Atrichoblast"
# [12] "Maturation_Cortex"
# [13] "Maturation_Endodermis"
# [14] "Maturation_Pericycle"
# [15] "Maturation_Phloem"
# [16] "Maturation_Procambium"
# [17] "Maturation_Trichoblast"
# [18] "Maturation_Xylem"
# [19] "Proliferation Domain_Atrichoblast"
# [20] "Proliferation Domain_Cortex"
# [21] "Proliferation Domain_Endodermis"
# [22] "Proliferation Domain_Pericycle"
# [23] "Proliferation Domain_Quiescent Center"
# [24] "Proliferation Domain_Trichoblast"
# [25] "Proximal Columella"
# [26] "Proximal Lateral Root Cap"
# [27] "Transition Domain_Atrichoblast"
# [28] "Transition Domain_Cortex"
# [29] "Transition Domain_Pericycle"
# [30] "Transition Domain_Phloem"
# [31] "Transition Domain_Trichoblast"
# [32] "Transition Domain_Xylem"

# %%
# pseudobulks for 1st subpopulation
t(head(assay(pb)))
# Out:
#        AT1G01010 AT1G01020 AT1G01030 AT1G01040 AT1G01050 AT1G01060
# sc_122 37        32        12         9         862      6
# sc_125 22        43        11        11         765      2
# sc_126 26        41        17        12        1287      9
# sc_129 18        36         9         8         735      3

# %%
# metadata to manually add to DE contrast
bscs <- read.csv("./data/GEO_upload_BR_time_scRNA_samples_metadata_with_stats.csv", na.strings=c("","NA"), stringsAsFactors = F)
bscs$date <- gsub('^([0-9]{4})([0-9]{2})([0-9]+)$', '\\1-\\2-\\3', bscs$date)

# %%
# experiment info for contrasts, add rep from csv

ei <- metadata(sce)$experiment_info
ei

sample_date <- select(bscs, sample_id=sample, rep=rep)

ei <- left_join(ei, sample_date)

ei
# Out:
#   sample_id group_id n_cells
# 1 sc_122    WT       11614
# 2 sc_125    gtl1_df1 10012
# 3 sc_126    WT        7290
# 4 sc_129    gtl1_df1  7622
# Joining, by = "sample_id"
#   sample_id group_id n_cells rep
# 1 sc_122    WT       11614   1
# 2 sc_125    gtl1_df1 10012   1
# 3 sc_126    WT        7290   2
# 4 sc_129    gtl1_df1  7622   2

# %%
mm <- model.matrix(~ 0 + ei$group_id + ei$rep)
dimnames(mm) <- list(ei$sample_id, c(levels(ei$group_id), "rep"))

mm
# Out:
#        WT gtl1_df1 rep
# sc_122 1  0        1
# sc_125 0  1        1
# sc_126 1  0        2
# sc_129 0  1        2

# %%
contrast <- makeContrasts("gtl1_df1-WT", levels = mm)

contrast
# Out:
#           Contrasts
# Levels     gtl1_df1-WT
#   WT       -1
#   gtl1_df1  1
#   rep       0

# %%
res <- pbDS(pb, design = mm, 
            contrast = contrast, 
            method="edgeR", 
            min_cells=5, 
            filter = c("none"))
# Out:
# Distal Columella..Distal Lateral Root Cap..Elongation_Atrichoblast..Elongation_Cortex..Elongation_Endodermis..Elongation_Pericycle..Elongation_Phloem..Elongation_Procambium..Elongation_Trichoblast..Elongation_Xylem..Maturation_Atrichoblast..Maturation_Cortex..Maturation_Endodermis..Maturation_Pericycle..Maturation_Phloem..Maturation_Procambium..Maturation_Trichoblast..Maturation_Xylem..Proliferation Domain_Atrichoblast..Proliferation Domain_Cortex..Proliferation Domain_Endodermis..Proliferation Domain_Pericycle..Proliferation Domain_Quiescent Center..Proliferation Domain_Trichoblast..Proximal Columella..Proximal Lateral Root Cap..Transition Domain_Atrichoblast..Transition Domain_Cortex..Transition Domain_Pericycle..Transition Domain_Phloem..Transition Domain_Trichoblast..Transition Domain_Xylem..

# %% [markdown]
# ### DEG results

# %%
# DEG results with gene freqs
(res_to_write_frq <- resDS(sce, res, bind = "row", cpm=TRUE, frq=T))
# Out:
#        gene      cluster_id                    sc_122.cpm sc_126.cpm sc_125.cpm
# 1      AT1G01010 Distal Columella               10.500      6.230      6.110
# 2      AT1G01020 Distal Columella                9.120      9.820     12.000
# 3      AT1G01030 Distal Columella                3.420      4.070      3.060
# 4      AT1G01040 Distal Columella                2.570      2.870      3.060
# 5      AT1G01050 Distal Columella              246.000    308.000    213.000
# 6      AT1G01060 Distal Columella                1.710      2.160      0.556
# 7      AT1G01070 Distal Columella                0.570      0.240      0.000
# 8      AT1G01080 Distal Columella                0.285      0.240      0.556
# 9      AT1G01090 Distal Columella               37.300     40.000     31.400
# 10     AT1G01100 Distal Columella              266.000    237.000    333.000
# 11     AT1G01110 Distal Columella                1.140      1.200      1.110
# 12     AT1G01120 Distal Columella                2.000      1.440      4.170
# 13     AT1G01130 Distal Columella                0.285      1.200      0.556
# 14     AT1G01140 Distal Columella               12.800     12.700      6.670
# 15     AT1G01160 Distal Columella               19.400     13.400     13.300
# 16     AT1G01170 Distal Columella                1.710      1.200      1.670
# 17     AT1G01180 Distal Columella               22.500     27.800     24.500
# 18     AT1G01200 Distal Columella                2.850      0.719      1.110
# 19     AT1G01210 Distal Columella                1.140      2.630      1.950
# 20     AT1G01220 Distal Columella                4.280      3.110      1.670
# 21     AT1G01225 Distal Columella                1.430      0.719      0.556
# 22     AT1G01230 Distal Columella               39.600     40.700     38.100
# 23     AT1G01240 Distal Columella               25.400     35.200     37.000
# 24     AT1G01260 Distal Columella               12.000     14.100     18.100
# 25     AT1G01290 Distal Columella                5.130      5.750      3.060
# 26     AT1G01300 Distal Columella                7.980      7.900      6.390
# 27     AT1G01310 Distal Columella                0.000      0.240      0.000
# 28     AT1G01320 Distal Columella                2.000      3.350      2.500
# 29     AT1G01340 Distal Columella                0.570      0.000      0.000
# 30     AT1G01350 Distal Columella               35.600     30.400     29.500
# ⋮      ⋮         ⋮                             ⋮          ⋮          ⋮
# 531758 ATCG01130 Transition Domain_Trichoblast 94.200     249.000    220.0
# 531759 AT1G04053 Transition Domain_Trichoblast  0.838       0.000      0.0
# 531760 AT1G12665 Transition Domain_Trichoblast  0.168       0.000      0.0
# 531761 AT1G49100 Transition Domain_Trichoblast  0.168       0.000      0.0
# 531762 AT1G51870 Transition Domain_Trichoblast  0.168       0.000      0.0
# 531763 AT1G52940 Transition Domain_Trichoblast  0.335       0.348      0.0
# 531764 AT1G55755 Transition Domain_Trichoblast  0.168       0.000      0.0
# 531765 AT1G59171 Transition Domain_Trichoblast  0.000       0.348      0.0
# 531766 AT5G03668 Transition Domain_Trichoblast  0.168       0.000      0.0
# 531767 AT5G60265 Transition Domain_Trichoblast  0.000       0.000      0.0
# 531768 AT3G03830 Transition Domain_Trichoblast  0.000       0.348      0.0
# 531769 AT3G54310 Transition Domain_Trichoblast  0.168       0.000      0.0
# 531770 AT3G56410 Transition Domain_Trichoblast  0.671       0.000      0.5
# 531771 AT4G29450 Transition Domain_Trichoblast  0.000       0.000      0.5
# 531772 AT1G44130 Transition Domain_Trichoblast  0.000       0.000      0.5
# 531773 AT1G67860 Transition Domain_Trichoblast  0.000       0.000      5.0
# 531774 AT5G63340 Transition Domain_Trichoblast  0.000       0.696      0.0
# 531775 AT1G08763 Transition Domain_Trichoblast  0.000       0.000      0.5
# 531776 AT2G25055 Transition Domain_Trichoblast  0.168       0.696      0.5
# 531777 AT3G17080 Transition Domain_Trichoblast  0.168       0.000      0.0
# 531778 AT3G46880 Transition Domain_Trichoblast  0.000       0.000      1.0
# 531779 AT3G22570 Transition Domain_Trichoblast  3.690       2.440      3.5
# 531780 AT3G32400 Transition Domain_Trichoblast  0.168       0.000      0.0
# 531781 AT3G43990 Transition Domain_Trichoblast 15.100       0.000      0.0
# 531782 AT4G01595 Transition Domain_Trichoblast  0.335       0.000      0.5
# 531783 AT4G04615 Transition Domain_Trichoblast  7.710       6.610      3.5
# 531784 AT5G25756 Transition Domain_Trichoblast  0.000       0.696      0.0
# 531785 ATCG00030 Transition Domain_Trichoblast 71.700     195.000    161.0
# 531786 AT4G36570 Transition Domain_Trichoblast  0.000       0.000      2.5
# 531787 AT4G20520 Transition Domain_Trichoblast  0.000       0.696      0.0
#        sc_129.cpm sc_122.frq sc_126.frq sc_125.frq sc_129.frq WT.frq
# 1        4.870    0.06100    0.05040    0.04010    0.02360    0.055900
# 2        9.730    0.05570    0.07170    0.07470    0.06180    0.063400
# 3        2.430    0.01970    0.03290    0.02000    0.01270    0.026100
# 4        2.160    0.01620    0.01940    0.02000    0.01450    0.017700
# 5      199.000    0.69300    0.77900    0.63900    0.60000    0.734000
# 6        0.811    0.01080    0.01740    0.00364    0.00545    0.014000
# 7        0.000    0.00359    0.00194    0.00000    0.00000    0.002800
# 8        0.000    0.00180    0.00194    0.00364    0.00000    0.001860
# 9       20.800    0.19600    0.26400    0.18400    0.12000    0.228000
# 10     345.000    0.68000    0.67600    0.72700    0.81300    0.678000
# 11       1.620    0.00718    0.00969    0.00729    0.01090    0.008390
# 12       1.080    0.01080    0.01160    0.02370    0.00727    0.011200
# 13       0.270    0.00180    0.00775    0.00364    0.00182    0.004660
# 14       3.520    0.07900    0.10100    0.04370    0.02360    0.089500
# 15      12.200    0.11100    0.09880    0.08200    0.07640    0.105000
# 16       1.890    0.01080    0.00969    0.00911    0.01090    0.010300
# 17      29.700    0.11700    0.19000    0.14000    0.18000    0.152000
# 18       1.620    0.01800    0.00581    0.00729    0.01090    0.012100
# 19       1.080    0.00718    0.01740    0.01280    0.00727    0.012100
# 20       2.160    0.02690    0.02520    0.01090    0.01450    0.026100
# 21       1.620    0.00898    0.00581    0.00364    0.01090    0.007460
# 22      32.200    0.22100    0.27300    0.21300    0.18400    0.246000
# 23      37.600    0.14400    0.24400    0.20800    0.21500    0.192000
# 24      17.300    0.06460    0.10500    0.11100    0.10700    0.083900
# 25       4.600    0.03230    0.04460    0.01820    0.03090    0.038200
# 26       5.950    0.04670    0.06200    0.04190    0.03450    0.054100
# 27       0.811    0.00000    0.00194    0.00000    0.00545    0.000932
# 28       3.240    0.01260    0.02710    0.01640    0.02000    0.019600
# 29       0.000    0.00359    0.00000    0.00000    0.00000    0.001860
# 30      33.500    0.19900    0.21300    0.16800    0.18000    0.206000
# ⋮      ⋮          ⋮          ⋮          ⋮          ⋮          ⋮
# 531758 325.000    0.58000    0.59400    0.72300    0.72200    0.58500
# 531759   0.355    0.01500    0.00000    0.00000    0.00448    0.00917
# 531760   0.000    0.00300    0.00000    0.00000    0.00000    0.00183
# 531761   0.000    0.00300    0.00000    0.00000    0.00000    0.00183
# 531762   0.000    0.00300    0.00000    0.00000    0.00000    0.00183
# 531763   0.355    0.00601    0.00472    0.00000    0.00448    0.00550
# 531764   0.000    0.00300    0.00000    0.00000    0.00000    0.00183
# 531765   0.000    0.00000    0.00472    0.00000    0.00000    0.00183
# 531766   0.355    0.00300    0.00000    0.00000    0.00448    0.00183
# 531767   0.355    0.00000    0.00000    0.00000    0.00448    0.00000
# 531768   0.000    0.00000    0.00472    0.00000    0.00000    0.00183
# 531769   0.355    0.00300    0.00000    0.00000    0.00448    0.00183
# 531770   0.000    0.01200    0.00000    0.00513    0.00000    0.00734
# 531771   0.000    0.00000    0.00000    0.00513    0.00000    0.00000
# 531772   0.000    0.00000    0.00000    0.00513    0.00000    0.00000
# 531773   0.000    0.00000    0.00000    0.00513    0.00000    0.00000
# 531774   0.355    0.00000    0.00943    0.00000    0.00448    0.00367
# 531775   0.000    0.00000    0.00000    0.00513    0.00000    0.00000
# 531776   1.420    0.00300    0.00943    0.00513    0.01790    0.00550
# 531777   0.000    0.00300    0.00000    0.00000    0.00000    0.00183
# 531778   0.000    0.00000    0.00000    0.00513    0.00000    0.00000
# 531779   5.320    0.06310    0.03300    0.02560    0.05380    0.05140
# 531780   0.000    0.00300    0.00000    0.00000    0.00000    0.00183
# 531781   0.000    0.21000    0.00000    0.00000    0.00000    0.12800
# 531782   0.355    0.00601    0.00000    0.00513    0.00448    0.00367
# 531783  10.600    0.12600    0.08490    0.03080    0.11700    0.11000
# 531784   0.000    0.00000    0.00943    0.00000    0.00000    0.00367
# 531785 267.000    0.54400    0.60400    0.63100    0.71300    0.56700
# 531786   0.000    0.00000    0.00000    0.00513    0.00000    0.00000
# 531787   0.000    0.00000    0.00943    0.00000    0.00000    0.00367
#        gtl1_df1.frq logFC   logCPM  F        p_val    p_adj.loc p_adj.glb
# 1      0.03180      -0.5900  2.890  3.69e+00 5.47e-02 2.68e-01  1
# 2      0.06820       0.1850  3.420  5.04e-01 4.78e-01 8.24e-01  1
# 3      0.01640      -0.4530  1.930  1.01e+00 3.15e-01 7.25e-01  1
# 4      0.01730      -0.0749  1.680  2.18e-02 8.83e-01 9.73e-01  1
# 5      0.62000      -0.4230  7.920  7.31e+00 6.88e-03 5.84e-02  1
# 6      0.00455      -1.4600  0.901  2.84e+00 9.18e-02 3.75e-01  1
# 7      0.00000      -3.7000 -0.445  1.26e+00 2.62e-01 6.67e-01  1
# 8      0.00182      -0.0251 -0.320  1.32e-04 9.91e-01 9.96e-01  1
# 9      0.15200      -0.5860  5.040  1.00e+01 1.56e-03 1.77e-02  1
# 10     0.77000       0.4340  8.210  7.77e+00 5.32e-03 4.76e-02  1
# 11     0.00910       0.2250  0.850  7.21e-02 7.88e-01 9.31e-01  1
# 12     0.01550       0.5210  1.420  7.62e-01 3.83e-01 7.68e-01  1
# 13     0.00273      -0.8010  0.181  3.06e-01 5.80e-01 8.29e-01  1
# 14     0.03370      -1.3400  3.250  2.20e+01 2.70e-06 6.79e-05  1
# 15     0.07920      -0.3470  3.910  2.28e+00 1.31e-01 4.65e-01  1
# 16     0.01000       0.3040  1.100  1.82e-01 6.70e-01 8.82e-01  1
# 17     0.16000       0.1080  4.740  3.12e-01 5.77e-01 8.27e-01  1
# 18     0.00910      -0.2790  1.050  1.42e-01 7.06e-01 9.06e-01  1
# 19     0.01000      -0.3300  1.180  2.33e-01 6.29e-01 8.61e-01  1
# 20     0.01270      -0.9190  1.740  3.33e+00 6.82e-02 3.11e-01  1
# 21     0.00728       0.0548  0.681  3.36e-03 9.54e-01 9.96e-01  1
# 22     0.19800      -0.1990  5.260  1.25e+00 2.64e-01 6.70e-01  1
# 23     0.21100       0.3040  5.100  2.77e+00 9.59e-02 3.87e-01  1
# 24     0.10900       0.4340  3.990  3.70e+00 5.43e-02 2.67e-01  1
# 25     0.02460      -0.5030  2.380  1.86e+00 1.73e-01 5.42e-01  1
# 26     0.03820      -0.3640  2.930  1.46e+00 2.26e-01 6.27e-01  1
# 27     0.00273       1.5200 -0.320  4.01e-01 5.27e-01 8.24e-01  1
# 28     0.01820       0.1030  1.740  4.35e-02 8.35e-01 9.48e-01  1
# 29     0.00000      -3.2100 -0.582  7.85e-01 3.76e-01 7.68e-01  1
# 30     0.17400      -0.0629  5.030  1.18e-01 7.32e-01 9.18e-01  1
# ⋮      ⋮            ⋮       ⋮       ⋮        ⋮        ⋮         ⋮
# 531758 0.72200       0.7950  7.7900 10.8000  1.04e-03 1.84e-02  1.000000
# 531759 0.00239      -0.8980  0.0171  0.1450  7.03e-01 8.92e-01  1.000000
# 531760 0.00000      -1.6200 -0.6060  0.1360  7.13e-01 8.92e-01  1.000000
# 531761 0.00000      -1.6200 -0.6060  0.1360  7.13e-01 8.92e-01  1.000000
# 531762 0.00000      -1.6200 -0.6060  0.1360  7.13e-01 8.92e-01  1.000000
# 531763 0.00239      -0.8010 -0.1900  0.0902  7.64e-01 9.19e-01  1.000000
# 531764 0.00000      -1.6200 -0.6060  0.1360  7.13e-01 8.92e-01  1.000000
# 531765 0.00000      -2.6500 -0.5990  0.3180  5.73e-01 8.52e-01  1.000000
# 531766 0.00239       0.6480 -0.4510  0.0359  8.50e-01 9.49e-01  1.000000
# 531767 0.00239       2.2500 -0.5980  0.3280  5.67e-01 8.52e-01  1.000000
# 531768 0.00000      -2.6500 -0.5990  0.3180  5.73e-01 8.52e-01  1.000000
# 531769 0.00239       0.6480 -0.4510  0.0359  8.50e-01 9.49e-01  1.000000
# 531770 0.00239      -0.3710 -0.0835  0.0214  8.84e-01 9.60e-01  1.000000
# 531771 0.00239       3.2600 -0.5960  0.6420  4.23e-01 7.86e-01  1.000000
# 531772 0.00239       3.2600 -0.5960  0.6420  4.23e-01 7.86e-01  1.000000
# 531773 0.00239       6.5100  0.4480 10.2000  1.37e-03 2.22e-02  1.000000
# 531774 0.00239      -0.8420 -0.3030  0.0832  7.73e-01 9.22e-01  1.000000
# 531775 0.00239       3.2600 -0.5960  0.6420  4.23e-01 7.86e-01  1.000000
# 531776 0.01200       1.1200  0.2460  0.4560  4.99e-01 8.38e-01  1.000000
# 531777 0.00000      -1.6200 -0.6060  0.1360  7.13e-01 8.92e-01  1.000000
# 531778 0.00239       4.2100 -0.4390  1.3800  2.40e-01 6.25e-01  1.000000
# 531779 0.04070       0.4950  2.1100  1.0100  3.15e-01 7.11e-01  1.000000
# 531780 0.00000      -1.6200 -0.6060  0.1360  7.13e-01 8.92e-01  1.000000
# 531781 0.00000      -7.4200  2.6000 39.8000  2.82e-10 5.32e-08  0.000149
# 531782 0.00478       1.1100 -0.1870  0.2000  6.55e-01 8.92e-01  1.000000
# 531783 0.07660      -0.0801  2.9900  0.0465  8.29e-01 9.49e-01  1.000000
# 531784 0.00000      -3.5500 -0.4440  0.6880  4.07e-01 7.86e-01  1.000000
# 531785 0.67500       0.8010  7.4400 10.8000  1.04e-03 1.85e-02  1.000000
# 531786 0.00239       5.5100 -0.0456  4.1000  4.28e-02 2.37e-01  1.000000
# 531787 0.00000      -3.5500 -0.4440  0.6880  4.07e-01 7.86e-01  1.000000
#        contrast
# 1      gtl1_df1-WT
# 2      gtl1_df1-WT
# 3      gtl1_df1-WT
# 4      gtl1_df1-WT
# 5      gtl1_df1-WT
# 6      gtl1_df1-WT
# 7      gtl1_df1-WT
# 8      gtl1_df1-WT
# 9      gtl1_df1-WT
# 10     gtl1_df1-WT
# 11     gtl1_df1-WT
# 12     gtl1_df1-WT
# 13     gtl1_df1-WT
# 14     gtl1_df1-WT
# 15     gtl1_df1-WT
# 16     gtl1_df1-WT
# 17     gtl1_df1-WT
# 18     gtl1_df1-WT
# 19     gtl1_df1-WT
# 20     gtl1_df1-WT
# 21     gtl1_df1-WT
# 22     gtl1_df1-WT
# 23     gtl1_df1-WT
# 24     gtl1_df1-WT
# 25     gtl1_df1-WT
# 26     gtl1_df1-WT
# 27     gtl1_df1-WT
# 28     gtl1_df1-WT
# 29     gtl1_df1-WT
# 30     gtl1_df1-WT
# ⋮      ⋮
# 531758 gtl1_df1-WT
# 531759 gtl1_df1-WT
# 531760 gtl1_df1-WT
# 531761 gtl1_df1-WT
# 531762 gtl1_df1-WT
# 531763 gtl1_df1-WT
# 531764 gtl1_df1-WT
# 531765 gtl1_df1-WT
# 531766 gtl1_df1-WT
# 531767 gtl1_df1-WT
# 531768 gtl1_df1-WT
# 531769 gtl1_df1-WT
# 531770 gtl1_df1-WT
# 531771 gtl1_df1-WT
# 531772 gtl1_df1-WT
# 531773 gtl1_df1-WT
# 531774 gtl1_df1-WT
# 531775 gtl1_df1-WT
# 531776 gtl1_df1-WT
# 531777 gtl1_df1-WT
# 531778 gtl1_df1-WT
# 531779 gtl1_df1-WT
# 531780 gtl1_df1-WT
# 531781 gtl1_df1-WT
# 531782 gtl1_df1-WT
# 531783 gtl1_df1-WT
# 531784 gtl1_df1-WT
# 531785 gtl1_df1-WT
# 531786 gtl1_df1-WT
# 531787 gtl1_df1-WT

# %%
## all genes background 

all_bg <- filter(res_to_write_frq,
                WT.frq >=0.1 | gtl1_df1.frq >=0.1)

# %%
length(unique(all_bg$gene))
# Out:
# [1] 17649

# %%
#total DE genes p_adj.loc < 0.05, abs(logFC) > 1.5
sig_DE <- filter(res_to_write_frq, p_adj.loc<=0.05 & abs(logFC) > log2(1.5))
sig_DE <- left_join(sig_DE, feature_names, by=c("gene"="AGI"))

length(unique(sig_DE$gene))
# Out:
# [1] 10799

# %%
# filter gene freqs to avoid calling lowly detected genes
sig_DE_fil <- filter(sig_DE, WT.frq >=0.1 | gtl1_df1.frq >=0.1)

# %%
length(unique(sig_DE_fil$gene))
# Out:
# [1] 8391

# %%
# load TFs
TF_list <- read_csv("./data/Kay_TF_thalemine_annotations.csv", col_names = c("gene", "TF_Name", "Description"))
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   gene = col_character(),
#   TF_Name = col_character(),
#   Description = col_character()
# )

# %%
sig_DE_fil <- left_join(sig_DE_fil, TF_list)
# Out:
# Joining, by = "gene"

# %%
# label up vs down
sig_DE_fil <- sig_DE_fil %>%
  mutate(up_dn_label = case_when(logFC >=log2(1.5) ~ "Up",  
                                       logFC <=log2(1/1.5) ~ "Down",
                                       TRUE ~ "Not DE"))

sig_DE_fil$clust_up_dn <- paste(sig_DE_fil$cluster_id, sig_DE_fil$up_dn_label, sep="_")

sig_DE_fil
# Out:
#       gene      cluster_id                    sc_122.cpm sc_126.cpm sc_125.cpm
# 1     AT1G01090 Distal Columella                37.3       40.0       31.4
# 2     AT1G01470 Distal Columella              3000.0     3080.0     1090.0
# 3     AT1G01500 Distal Columella                11.1       14.9       25.0
# 4     AT1G01710 Distal Columella                16.5       16.0        7.5
# 5     AT1G01820 Distal Columella                43.0       46.5       73.9
# 6     AT1G02360 Distal Columella                37.9       57.0      158.0
# 7     AT1G02610 Distal Columella                12.3       18.9       25.3
# 8     AT1G02810 Distal Columella                14.0       10.5       22.5
# 9     AT1G02860 Distal Columella                37.3       63.7      112.0
# 10    AT1G02920 Distal Columella                16.0       82.4      387.0
# 11    AT1G02930 Distal Columella                12.3       37.1      123.0
# 12    AT1G03220 Distal Columella              2290.0     3660.0     5140.0
# 13    AT1G03370 Distal Columella                11.7       12.0       27.8
# 14    AT1G03475 Distal Columella                16.8       21.1       31.4
# 15    AT1G03730 Distal Columella                30.5       32.3       44.7
# 16    AT1G03740 Distal Columella                68.7       91.5      117.0
# 17    AT1G03870 Distal Columella               161.0       99.4       89.2
# 18    AT1G04040 Distal Columella                60.7       58.0       99.5
# 19    AT1G04280 Distal Columella                11.4       16.8       23.9
# 20    AT1G04410 Distal Columella               536.0      496.0      346.0
# 21    AT1G05060 Distal Columella                20.2       30.4       95.3
# 22    AT1G05260 Distal Columella                45.3       40.2       26.4
# 23    AT1G05280 Distal Columella                72.7       85.5       47.8
# 24    AT1G05340 Distal Columella                86.7       82.4       50.6
# 25    AT1G05575 Distal Columella                46.8       81.9      175.0
# 26    AT1G05680 Distal Columella               700.0      775.0      453.0
# 27    AT1G05870 Distal Columella                22.5       27.3       15.6
# 28    AT1G06040 Distal Columella                96.1       85.5       47.5
# 29    AT1G06080 Distal Columella                10.5       15.1      136.0
# 30    AT1G06130 Distal Columella                14.3       12.5       22.5
# ⋮     ⋮         ⋮                             ⋮          ⋮          ⋮
# 25601 ATMG00830 Transition Domain_Trichoblast  25.50      56.00      73.50
# 25602 ATMG01000 Transition Domain_Trichoblast  18.60      27.10      43.00
# 25603 ATMG01170 Transition Domain_Trichoblast   4.36       8.35      15.00
# 25604 ATMG01360 Transition Domain_Trichoblast 154.00     285.00     311.00
# 25605 ATMG01390 Transition Domain_Trichoblast 148.00     248.00     364.00
# 25606 ATCG00120 Transition Domain_Trichoblast   3.52       9.05      12.50
# 25607 ATCG00130 Transition Domain_Trichoblast  28.50      81.80      92.10
# 25608 ATCG00160 Transition Domain_Trichoblast  11.90      34.50      42.00
# 25609 ATCG00180 Transition Domain_Trichoblast   8.38      22.60      31.50
# 25610 ATCG00360 Transition Domain_Trichoblast  14.40      45.60      46.50
# 25611 ATCG00480 Transition Domain_Trichoblast   7.54      19.80      32.50
# 25612 ATCG00490 Transition Domain_Trichoblast  12.40      40.40      43.00
# 25613 ATCG00500 Transition Domain_Trichoblast  56.00     151.00     153.00
# 25614 ATCG00520 Transition Domain_Trichoblast   5.20      15.00      16.50
# 25615 ATCG00540 Transition Domain_Trichoblast  12.10      35.10      37.00
# 25616 ATCG00570 Transition Domain_Trichoblast  11.60      36.90      43.50
# 25617 ATCG00640 Transition Domain_Trichoblast   6.37      21.20      26.00
# 25618 ATCG00650 Transition Domain_Trichoblast   3.69       7.66       9.01
# 25619 ATCG00660 Transition Domain_Trichoblast   6.20      16.00      22.00
# 25620 ATCG00670 Transition Domain_Trichoblast  67.40     168.00     144.00
# 25621 ATCG00720 Transition Domain_Trichoblast  87.50     210.00     205.00
# 25622 ATCG00770 Transition Domain_Trichoblast   5.03      18.10      19.00
# 25623 ATCG00780 Transition Domain_Trichoblast  17.10      51.50      48.00
# 25624 ATCG00810 Transition Domain_Trichoblast  16.90      45.90      49.00
# 25625 ATCG01010 Transition Domain_Trichoblast  11.90      26.80      34.50
# 25626 ATCG01040 Transition Domain_Trichoblast   5.70      14.60      16.50
# 25627 ATCG01050 Transition Domain_Trichoblast   2.01       6.96      10.00
# 25628 ATCG01130 Transition Domain_Trichoblast  94.20     249.00     220.00
# 25629 AT3G43990 Transition Domain_Trichoblast  15.10       0.00       0.00
# 25630 ATCG00030 Transition Domain_Trichoblast  71.70     195.00     161.00
#       sc_129.cpm sc_122.frq sc_126.frq sc_125.frq sc_129.frq ⋯ F      p_val
# 1       20.8     0.1960     0.2640     0.1840     0.1200     ⋯  10.00 1.56e-03
# 2      994.0     0.9660     0.9260     0.6830     0.6040     ⋯  97.90 5.01e-23
# 3       24.9     0.0628     0.1050     0.1550     0.1490     ⋯  19.10 1.23e-05
# 4       11.4     0.0969     0.1180     0.0474     0.0745     ⋯  10.50 1.20e-03
# 5       70.3     0.2190     0.2970     0.3620     0.3450     ⋯  16.60 4.63e-05
# 6      175.0     0.1560     0.2330     0.3920     0.3800     ⋯ 119.00 1.20e-27
# 7       35.7     0.0718     0.1240     0.1350     0.1750     ⋯  22.60 1.98e-06
# 8       22.2     0.0754     0.0659     0.1150     0.1090     ⋯  15.90 6.84e-05
# 9      158.0     0.1870     0.3310     0.4500     0.5000     ⋯  74.90 5.38e-18
# 10     636.0     0.0395     0.1090     0.2900     0.3580     ⋯ 399.00 6.04e-88
# 11     220.0     0.0575     0.1220     0.2300     0.2890     ⋯ 249.00 1.09e-55
# 12    5510.0     0.9980     0.9960     1.0000     1.0000     ⋯  33.20 8.31e-09
# 13      25.7     0.0646     0.0950     0.1730     0.1490     ⋯  29.50 5.76e-08
# 14      27.8     0.0969     0.1550     0.1800     0.1600     ⋯  10.40 1.27e-03
# 15      51.6     0.1720     0.2170     0.2190     0.2820     ⋯  12.00 5.23e-04
# 16     123.0     0.3340     0.4840     0.5100     0.5250     ⋯  13.50 2.35e-04
# 17      73.5     0.4690     0.4840     0.3720     0.3200     ⋯  16.30 5.46e-05
# 18     111.0     0.3000     0.3600     0.4640     0.5240     ⋯  25.90 3.64e-07
# 19      26.2     0.0718     0.1220     0.1420     0.1440     ⋯  15.40 8.50e-05
# 20     332.0     0.9280     0.9220     0.8200     0.8000     ⋯  15.00 1.08e-04
# 21     116.0     0.1010     0.1690     0.3330     0.4040     ⋯ 136.00 2.47e-31
# 22      15.1     0.1510     0.1670     0.1070     0.0636     ⋯  31.90 1.63e-08
# 23      44.6     0.3500     0.4110     0.2500     0.2290     ⋯  21.30 3.99e-06
# 24      57.3     0.4040     0.4320     0.2730     0.2470     ⋯  15.40 8.90e-05
# 25     154.0     0.1440     0.2110     0.3610     0.3220     ⋯  71.00 3.77e-17
# 26     320.0     0.5870     0.5500     0.4040     0.3650     ⋯  36.50 1.59e-09
# 27      17.6     0.1150     0.1740     0.0929     0.0945     ⋯   8.05 4.56e-03
# 28      38.7     0.4130     0.4090     0.2200     0.1730     ⋯  41.20 1.41e-10
# 29     167.0     0.0503     0.0853     0.4280     0.4750     ⋯ 337.00 1.46e-74
# 30      18.4     0.0862     0.0911     0.1330     0.1040     ⋯   7.71 5.50e-03
# ⋮     ⋮          ⋮          ⋮          ⋮          ⋮          ⋱ ⋮      ⋮
# 25601  83.1      0.2700     0.4250     0.4050     0.466      ⋯ 16.50  4.91e-05
# 25602  49.0      0.2430     0.2500     0.2670     0.318      ⋯ 15.10  1.02e-04
# 25603  16.3      0.0691     0.1040     0.1330     0.166      ⋯ 17.10  3.62e-05
# 25604 366.0      0.7150     0.7920     0.7900     0.825      ⋯  8.19  4.22e-03
# 25605 277.0      0.8350     0.8770     0.9440     0.888      ⋯  9.07  2.59e-03
# 25606  14.6      0.0631     0.1080     0.1030     0.157      ⋯ 12.50  4.16e-04
# 25607  95.5      0.3510     0.4390     0.4460     0.516      ⋯ 13.50  2.43e-04
# 25608  41.5      0.1680     0.3160     0.3080     0.327      ⋯ 13.90  1.95e-04
# 25609  27.3      0.1200     0.2080     0.2100     0.233      ⋯ 14.00  1.79e-04
# 25610  53.6      0.2070     0.3300     0.3230     0.386      ⋯ 12.00  5.23e-04
# 25611  30.9      0.1080     0.1890     0.2460     0.265      ⋯ 22.40  2.27e-06
# 25612  44.4      0.1710     0.3250     0.2670     0.363      ⋯ 11.60  6.53e-04
# 25613 186.0      0.4440     0.5520     0.6260     0.691      ⋯ 12.10  5.13e-04
# 25614  24.5      0.0901     0.1600     0.1330     0.215      ⋯ 14.00  1.88e-04
# 25615  40.5      0.1890     0.2920     0.2970     0.336      ⋯ 10.30  1.34e-03
# 25616  47.2      0.1860     0.2920     0.2970     0.363      ⋯ 16.30  5.48e-05
# 25617  24.8      0.0961     0.2080     0.2150     0.233      ⋯ 13.40  2.55e-04
# 25618  13.8      0.0571     0.0943     0.0872     0.139      ⋯  8.58  3.41e-03
# 25619  23.8      0.0991     0.1560     0.1790     0.211      ⋯ 15.40  8.53e-05
# 25620 218.0      0.5320     0.5990     0.5900     0.722      ⋯  8.81  3.01e-03
# 25621 239.0      0.5830     0.6080     0.6510     0.726      ⋯  8.20  4.20e-03
# 25622  19.9      0.0781     0.1700     0.1640     0.202      ⋯  9.50  2.06e-03
# 25623  59.6      0.2460     0.3770     0.3280     0.426      ⋯  9.68  1.87e-03
# 25624  56.1      0.2160     0.3540     0.3080     0.381      ⋯ 11.30  7.74e-04
# 25625  38.7      0.1740     0.2500     0.2720     0.309      ⋯ 13.80  2.07e-04
# 25626  20.9      0.0961     0.1700     0.1330     0.202      ⋯ 10.40  1.29e-03
# 25627  11.0      0.0360     0.0943     0.0923     0.117      ⋯ 13.00  3.12e-04
# 25628 325.0      0.5800     0.5940     0.7230     0.722      ⋯ 10.80  1.04e-03
# 25629   0.0      0.2100     0.0000     0.0000     0.000      ⋯ 39.80  2.82e-10
# 25630 267.0      0.5440     0.6040     0.6310     0.713      ⋯ 10.80  1.04e-03
#       p_adj.loc p_adj.glb contrast    Name         TF_Name
# 1     1.77e-02  1.00e+00  gtl1_df1-WT PDH-E1 ALPHA NA
# 2     7.77e-21  2.66e-17  gtl1_df1-WT LEA14        NA
# 3     2.70e-04  1.00e+00  gtl1_df1-WT AT1G01500    NA
# 4     1.44e-02  1.00e+00  gtl1_df1-WT AT1G01710    NA
# 5     8.64e-04  1.00e+00  gtl1_df1-WT PEX11C       NA
# 6     2.46e-25  6.40e-22  gtl1_df1-WT AT1G02360    NA
# 7     5.14e-05  1.00e+00  gtl1_df1-WT AT1G02610    NA
# 8     1.23e-03  1.00e+00  gtl1_df1-WT PME7         NA
# 9     5.89e-16  2.86e-12  gtl1_df1-WT BAH1         NA
# 10    1.10e-84  3.21e-82  gtl1_df1-WT GSTF7        NA
# 11    7.05e-53  5.81e-50  gtl1_df1-WT GSTF6        NA
# 12    3.24e-07  4.37e-03  gtl1_df1-WT AT1G03220    NA
# 13    1.99e-06  3.02e-02  gtl1_df1-WT AT1G03370    NA
# 14    1.51e-02  1.00e+00  gtl1_df1-WT CPX1         NA
# 15    7.20e-03  1.00e+00  gtl1_df1-WT AT1G03730    NA
# 16    3.62e-03  1.00e+00  gtl1_df1-WT AT1G03740    NA
# 17    1.01e-03  1.00e+00  gtl1_df1-WT FLA9         NA
# 18    1.08e-05  1.90e-01  gtl1_df1-WT AT1G04040    NA
# 19    1.48e-03  1.00e+00  gtl1_df1-WT AT1G04280    NA
# 20    1.83e-03  1.00e+00  gtl1_df1-WT MDH1         NA
# 21    6.69e-29  1.31e-25  gtl1_df1-WT AT1G05060    NA
# 22    6.15e-07  8.57e-03  gtl1_df1-WT PER3         NA
# 23    9.73e-05  1.00e+00  gtl1_df1-WT AT1G05280    NA
# 24    1.54e-03  1.00e+00  gtl1_df1-WT AT1G05340    NA
# 25    3.78e-15  2.00e-11  gtl1_df1-WT AT1G05575    NA
# 26    6.99e-08  8.39e-04  gtl1_df1-WT UGT74E2      NA
# 27    4.22e-02  1.00e+00  gtl1_df1-WT AT1G05870    NA
# 28    7.05e-09  7.42e-05  gtl1_df1-WT BBX24        STO
# 29    1.83e-71  7.78e-69  gtl1_df1-WT ADS1         NA
# 30    4.89e-02  1.00e+00  gtl1_df1-WT GLX2-4       NA
# ⋮     ⋮         ⋮         ⋮           ⋮            ⋮
# 25601 1.66e-03  1.000000  gtl1_df1-WT CCB382       NA
# 25602 3.00e-03  1.000000  gtl1_df1-WT ORF114       NA
# 25603 1.30e-03  1.000000  gtl1_df1-WT ATP6-2       NA
# 25604 4.97e-02  1.000000  gtl1_df1-WT COX1         NA
# 25605 3.51e-02  1.000000  gtl1_df1-WT RRN18        NA
# 25606 9.07e-03  1.000000  gtl1_df1-WT ATPA         NA
# 25607 5.99e-03  1.000000  gtl1_df1-WT ATPF         NA
# 25608 5.08e-03  1.000000  gtl1_df1-WT RPS2         NA
# 25609 4.75e-03  1.000000  gtl1_df1-WT RPOC1        NA
# 25610 1.08e-02  1.000000  gtl1_df1-WT YCF3         NA
# 25611 1.32e-04  1.000000  gtl1_df1-WT ATPB         NA
# 25612 1.28e-02  1.000000  gtl1_df1-WT RBCL         NA
# 25613 1.06e-02  1.000000  gtl1_df1-WT ACCD         NA
# 25614 4.94e-03  1.000000  gtl1_df1-WT YCF4         NA
# 25615 2.19e-02  1.000000  gtl1_df1-WT PETA         NA
# 25616 1.81e-03  1.000000  gtl1_df1-WT PSBF         NA
# 25617 6.20e-03  1.000000  gtl1_df1-WT RPL33        NA
# 25618 4.29e-02  1.000000  gtl1_df1-WT RPS18        NA
# 25619 2.58e-03  1.000000  gtl1_df1-WT RPL20        NA
# 25620 3.91e-02  1.000000  gtl1_df1-WT CLPP1        NA
# 25621 4.96e-02  1.000000  gtl1_df1-WT PETB         NA
# 25622 2.97e-02  1.000000  gtl1_df1-WT RPS8         NA
# 25623 2.75e-02  1.000000  gtl1_df1-WT RPL14        NA
# 25624 1.47e-02  1.000000  gtl1_df1-WT RPL22        NA
# 25625 5.33e-03  1.000000  gtl1_df1-WT NDHF         NA
# 25626 2.14e-02  1.000000  gtl1_df1-WT CCSA         NA
# 25627 7.28e-03  1.000000  gtl1_df1-WT NDHD         NA
# 25628 1.84e-02  1.000000  gtl1_df1-WT YCF1.2       NA
# 25629 5.32e-08  0.000149  gtl1_df1-WT AT3G43990    NA
# 25630 1.85e-02  1.000000  gtl1_df1-WT TRNK         NA
#       Description                      up_dn_label
# 1     NA                               Down
# 2     NA                               Down
# 3     NA                               Up
# 4     NA                               Down
# 5     NA                               Up
# 6     NA                               Up
# 7     NA                               Up
# 8     NA                               Up
# 9     NA                               Up
# 10    NA                               Up
# 11    NA                               Up
# 12    NA                               Up
# 13    NA                               Up
# 14    NA                               Up
# 15    NA                               Up
# 16    NA                               Up
# 17    NA                               Down
# 18    NA                               Up
# 19    NA                               Up
# 20    NA                               Down
# 21    NA                               Up
# 22    NA                               Down
# 23    NA                               Down
# 24    NA                               Down
# 25    NA                               Up
# 26    NA                               Down
# 27    NA                               Down
# 28    B-box zinc finger family protein Down
# 29    NA                               Up
# 30    NA                               Up
# ⋮     ⋮                                ⋮
# 25601 NA                               Up
# 25602 NA                               Up
# 25603 NA                               Up
# 25604 NA                               Up
# 25605 NA                               Up
# 25606 NA                               Up
# 25607 NA                               Up
# 25608 NA                               Up
# 25609 NA                               Up
# 25610 NA                               Up
# 25611 NA                               Up
# 25612 NA                               Up
# 25613 NA                               Up
# 25614 NA                               Up
# 25615 NA                               Up
# 25616 NA                               Up
# 25617 NA                               Up
# 25618 NA                               Up
# 25619 NA                               Up
# 25620 NA                               Up
# 25621 NA                               Up
# 25622 NA                               Up
# 25623 NA                               Up
# 25624 NA                               Up
# 25625 NA                               Up
# 25626 NA                               Up
# 25627 NA                               Up
# 25628 NA                               Up
# 25629 NA                               Down
# 25630 NA                               Up
#       clust_up_dn
# 1     Distal Columella_Down
# 2     Distal Columella_Down
# 3     Distal Columella_Up
# 4     Distal Columella_Down
# 5     Distal Columella_Up
# 6     Distal Columella_Up
# 7     Distal Columella_Up
# 8     Distal Columella_Up
# 9     Distal Columella_Up
# 10    Distal Columella_Up
# 11    Distal Columella_Up
# 12    Distal Columella_Up
# 13    Distal Columella_Up
# 14    Distal Columella_Up
# 15    Distal Columella_Up
# 16    Distal Columella_Up
# 17    Distal Columella_Down
# 18    Distal Columella_Up
# 19    Distal Columella_Up
# 20    Distal Columella_Down
# 21    Distal Columella_Up
# 22    Distal Columella_Down
# 23    Distal Columella_Down
# 24    Distal Columella_Down
# 25    Distal Columella_Up
# 26    Distal Columella_Down
# 27    Distal Columella_Down
# 28    Distal Columella_Down
# 29    Distal Columella_Up
# 30    Distal Columella_Up
# ⋮     ⋮
# 25601 Transition Domain_Trichoblast_Up
# 25602 Transition Domain_Trichoblast_Up
# 25603 Transition Domain_Trichoblast_Up
# 25604 Transition Domain_Trichoblast_Up
# 25605 Transition Domain_Trichoblast_Up
# 25606 Transition Domain_Trichoblast_Up
# 25607 Transition Domain_Trichoblast_Up
# 25608 Transition Domain_Trichoblast_Up
# 25609 Transition Domain_Trichoblast_Up
# 25610 Transition Domain_Trichoblast_Up
# 25611 Transition Domain_Trichoblast_Up
# 25612 Transition Domain_Trichoblast_Up
# 25613 Transition Domain_Trichoblast_Up
# 25614 Transition Domain_Trichoblast_Up
# 25615 Transition Domain_Trichoblast_Up
# 25616 Transition Domain_Trichoblast_Up
# 25617 Transition Domain_Trichoblast_Up
# 25618 Transition Domain_Trichoblast_Up
# 25619 Transition Domain_Trichoblast_Up
# 25620 Transition Domain_Trichoblast_Up
# 25621 Transition Domain_Trichoblast_Up
# 25622 Transition Domain_Trichoblast_Up
# 25623 Transition Domain_Trichoblast_Up
# 25624 Transition Domain_Trichoblast_Up
# 25625 Transition Domain_Trichoblast_Up
# 25626 Transition Domain_Trichoblast_Up
# 25627 Transition Domain_Trichoblast_Up
# 25628 Transition Domain_Trichoblast_Up
# 25629 Transition Domain_Trichoblast_Down
# 25630 Transition Domain_Trichoblast_Up

# %%
sig_DE_fil
write.csv(sig_DE_fil, file = "./output/v4_gtl1_df1_v_WT_cell_time_EdgeR_q0.05_FC1.5_r_v_4_20220121.csv")
# Out:
#       gene      cluster_id                    sc_122.cpm sc_126.cpm sc_125.cpm
# 1     AT1G01090 Distal Columella                37.3       40.0       31.4
# 2     AT1G01470 Distal Columella              3000.0     3080.0     1090.0
# 3     AT1G01500 Distal Columella                11.1       14.9       25.0
# 4     AT1G01710 Distal Columella                16.5       16.0        7.5
# 5     AT1G01820 Distal Columella                43.0       46.5       73.9
# 6     AT1G02360 Distal Columella                37.9       57.0      158.0
# 7     AT1G02610 Distal Columella                12.3       18.9       25.3
# 8     AT1G02810 Distal Columella                14.0       10.5       22.5
# 9     AT1G02860 Distal Columella                37.3       63.7      112.0
# 10    AT1G02920 Distal Columella                16.0       82.4      387.0
# 11    AT1G02930 Distal Columella                12.3       37.1      123.0
# 12    AT1G03220 Distal Columella              2290.0     3660.0     5140.0
# 13    AT1G03370 Distal Columella                11.7       12.0       27.8
# 14    AT1G03475 Distal Columella                16.8       21.1       31.4
# 15    AT1G03730 Distal Columella                30.5       32.3       44.7
# 16    AT1G03740 Distal Columella                68.7       91.5      117.0
# 17    AT1G03870 Distal Columella               161.0       99.4       89.2
# 18    AT1G04040 Distal Columella                60.7       58.0       99.5
# 19    AT1G04280 Distal Columella                11.4       16.8       23.9
# 20    AT1G04410 Distal Columella               536.0      496.0      346.0
# 21    AT1G05060 Distal Columella                20.2       30.4       95.3
# 22    AT1G05260 Distal Columella                45.3       40.2       26.4
# 23    AT1G05280 Distal Columella                72.7       85.5       47.8
# 24    AT1G05340 Distal Columella                86.7       82.4       50.6
# 25    AT1G05575 Distal Columella                46.8       81.9      175.0
# 26    AT1G05680 Distal Columella               700.0      775.0      453.0
# 27    AT1G05870 Distal Columella                22.5       27.3       15.6
# 28    AT1G06040 Distal Columella                96.1       85.5       47.5
# 29    AT1G06080 Distal Columella                10.5       15.1      136.0
# 30    AT1G06130 Distal Columella                14.3       12.5       22.5
# ⋮     ⋮         ⋮                             ⋮          ⋮          ⋮
# 25601 ATMG00830 Transition Domain_Trichoblast  25.50      56.00      73.50
# 25602 ATMG01000 Transition Domain_Trichoblast  18.60      27.10      43.00
# 25603 ATMG01170 Transition Domain_Trichoblast   4.36       8.35      15.00
# 25604 ATMG01360 Transition Domain_Trichoblast 154.00     285.00     311.00
# 25605 ATMG01390 Transition Domain_Trichoblast 148.00     248.00     364.00
# 25606 ATCG00120 Transition Domain_Trichoblast   3.52       9.05      12.50
# 25607 ATCG00130 Transition Domain_Trichoblast  28.50      81.80      92.10
# 25608 ATCG00160 Transition Domain_Trichoblast  11.90      34.50      42.00
# 25609 ATCG00180 Transition Domain_Trichoblast   8.38      22.60      31.50
# 25610 ATCG00360 Transition Domain_Trichoblast  14.40      45.60      46.50
# 25611 ATCG00480 Transition Domain_Trichoblast   7.54      19.80      32.50
# 25612 ATCG00490 Transition Domain_Trichoblast  12.40      40.40      43.00
# 25613 ATCG00500 Transition Domain_Trichoblast  56.00     151.00     153.00
# 25614 ATCG00520 Transition Domain_Trichoblast   5.20      15.00      16.50
# 25615 ATCG00540 Transition Domain_Trichoblast  12.10      35.10      37.00
# 25616 ATCG00570 Transition Domain_Trichoblast  11.60      36.90      43.50
# 25617 ATCG00640 Transition Domain_Trichoblast   6.37      21.20      26.00
# 25618 ATCG00650 Transition Domain_Trichoblast   3.69       7.66       9.01
# 25619 ATCG00660 Transition Domain_Trichoblast   6.20      16.00      22.00
# 25620 ATCG00670 Transition Domain_Trichoblast  67.40     168.00     144.00
# 25621 ATCG00720 Transition Domain_Trichoblast  87.50     210.00     205.00
# 25622 ATCG00770 Transition Domain_Trichoblast   5.03      18.10      19.00
# 25623 ATCG00780 Transition Domain_Trichoblast  17.10      51.50      48.00
# 25624 ATCG00810 Transition Domain_Trichoblast  16.90      45.90      49.00
# 25625 ATCG01010 Transition Domain_Trichoblast  11.90      26.80      34.50
# 25626 ATCG01040 Transition Domain_Trichoblast   5.70      14.60      16.50
# 25627 ATCG01050 Transition Domain_Trichoblast   2.01       6.96      10.00
# 25628 ATCG01130 Transition Domain_Trichoblast  94.20     249.00     220.00
# 25629 AT3G43990 Transition Domain_Trichoblast  15.10       0.00       0.00
# 25630 ATCG00030 Transition Domain_Trichoblast  71.70     195.00     161.00
#       sc_129.cpm sc_122.frq sc_126.frq sc_125.frq sc_129.frq ⋯ F      p_val
# 1       20.8     0.1960     0.2640     0.1840     0.1200     ⋯  10.00 1.56e-03
# 2      994.0     0.9660     0.9260     0.6830     0.6040     ⋯  97.90 5.01e-23
# 3       24.9     0.0628     0.1050     0.1550     0.1490     ⋯  19.10 1.23e-05
# 4       11.4     0.0969     0.1180     0.0474     0.0745     ⋯  10.50 1.20e-03
# 5       70.3     0.2190     0.2970     0.3620     0.3450     ⋯  16.60 4.63e-05
# 6      175.0     0.1560     0.2330     0.3920     0.3800     ⋯ 119.00 1.20e-27
# 7       35.7     0.0718     0.1240     0.1350     0.1750     ⋯  22.60 1.98e-06
# 8       22.2     0.0754     0.0659     0.1150     0.1090     ⋯  15.90 6.84e-05
# 9      158.0     0.1870     0.3310     0.4500     0.5000     ⋯  74.90 5.38e-18
# 10     636.0     0.0395     0.1090     0.2900     0.3580     ⋯ 399.00 6.04e-88
# 11     220.0     0.0575     0.1220     0.2300     0.2890     ⋯ 249.00 1.09e-55
# 12    5510.0     0.9980     0.9960     1.0000     1.0000     ⋯  33.20 8.31e-09
# 13      25.7     0.0646     0.0950     0.1730     0.1490     ⋯  29.50 5.76e-08
# 14      27.8     0.0969     0.1550     0.1800     0.1600     ⋯  10.40 1.27e-03
# 15      51.6     0.1720     0.2170     0.2190     0.2820     ⋯  12.00 5.23e-04
# 16     123.0     0.3340     0.4840     0.5100     0.5250     ⋯  13.50 2.35e-04
# 17      73.5     0.4690     0.4840     0.3720     0.3200     ⋯  16.30 5.46e-05
# 18     111.0     0.3000     0.3600     0.4640     0.5240     ⋯  25.90 3.64e-07
# 19      26.2     0.0718     0.1220     0.1420     0.1440     ⋯  15.40 8.50e-05
# 20     332.0     0.9280     0.9220     0.8200     0.8000     ⋯  15.00 1.08e-04
# 21     116.0     0.1010     0.1690     0.3330     0.4040     ⋯ 136.00 2.47e-31
# 22      15.1     0.1510     0.1670     0.1070     0.0636     ⋯  31.90 1.63e-08
# 23      44.6     0.3500     0.4110     0.2500     0.2290     ⋯  21.30 3.99e-06
# 24      57.3     0.4040     0.4320     0.2730     0.2470     ⋯  15.40 8.90e-05
# 25     154.0     0.1440     0.2110     0.3610     0.3220     ⋯  71.00 3.77e-17
# 26     320.0     0.5870     0.5500     0.4040     0.3650     ⋯  36.50 1.59e-09
# 27      17.6     0.1150     0.1740     0.0929     0.0945     ⋯   8.05 4.56e-03
# 28      38.7     0.4130     0.4090     0.2200     0.1730     ⋯  41.20 1.41e-10
# 29     167.0     0.0503     0.0853     0.4280     0.4750     ⋯ 337.00 1.46e-74
# 30      18.4     0.0862     0.0911     0.1330     0.1040     ⋯   7.71 5.50e-03
# ⋮     ⋮          ⋮          ⋮          ⋮          ⋮          ⋱ ⋮      ⋮
# 25601  83.1      0.2700     0.4250     0.4050     0.466      ⋯ 16.50  4.91e-05
# 25602  49.0      0.2430     0.2500     0.2670     0.318      ⋯ 15.10  1.02e-04
# 25603  16.3      0.0691     0.1040     0.1330     0.166      ⋯ 17.10  3.62e-05
# 25604 366.0      0.7150     0.7920     0.7900     0.825      ⋯  8.19  4.22e-03
# 25605 277.0      0.8350     0.8770     0.9440     0.888      ⋯  9.07  2.59e-03
# 25606  14.6      0.0631     0.1080     0.1030     0.157      ⋯ 12.50  4.16e-04
# 25607  95.5      0.3510     0.4390     0.4460     0.516      ⋯ 13.50  2.43e-04
# 25608  41.5      0.1680     0.3160     0.3080     0.327      ⋯ 13.90  1.95e-04
# 25609  27.3      0.1200     0.2080     0.2100     0.233      ⋯ 14.00  1.79e-04
# 25610  53.6      0.2070     0.3300     0.3230     0.386      ⋯ 12.00  5.23e-04
# 25611  30.9      0.1080     0.1890     0.2460     0.265      ⋯ 22.40  2.27e-06
# 25612  44.4      0.1710     0.3250     0.2670     0.363      ⋯ 11.60  6.53e-04
# 25613 186.0      0.4440     0.5520     0.6260     0.691      ⋯ 12.10  5.13e-04
# 25614  24.5      0.0901     0.1600     0.1330     0.215      ⋯ 14.00  1.88e-04
# 25615  40.5      0.1890     0.2920     0.2970     0.336      ⋯ 10.30  1.34e-03
# 25616  47.2      0.1860     0.2920     0.2970     0.363      ⋯ 16.30  5.48e-05
# 25617  24.8      0.0961     0.2080     0.2150     0.233      ⋯ 13.40  2.55e-04
# 25618  13.8      0.0571     0.0943     0.0872     0.139      ⋯  8.58  3.41e-03
# 25619  23.8      0.0991     0.1560     0.1790     0.211      ⋯ 15.40  8.53e-05
# 25620 218.0      0.5320     0.5990     0.5900     0.722      ⋯  8.81  3.01e-03
# 25621 239.0      0.5830     0.6080     0.6510     0.726      ⋯  8.20  4.20e-03
# 25622  19.9      0.0781     0.1700     0.1640     0.202      ⋯  9.50  2.06e-03
# 25623  59.6      0.2460     0.3770     0.3280     0.426      ⋯  9.68  1.87e-03
# 25624  56.1      0.2160     0.3540     0.3080     0.381      ⋯ 11.30  7.74e-04
# 25625  38.7      0.1740     0.2500     0.2720     0.309      ⋯ 13.80  2.07e-04
# 25626  20.9      0.0961     0.1700     0.1330     0.202      ⋯ 10.40  1.29e-03
# 25627  11.0      0.0360     0.0943     0.0923     0.117      ⋯ 13.00  3.12e-04
# 25628 325.0      0.5800     0.5940     0.7230     0.722      ⋯ 10.80  1.04e-03
# 25629   0.0      0.2100     0.0000     0.0000     0.000      ⋯ 39.80  2.82e-10
# 25630 267.0      0.5440     0.6040     0.6310     0.713      ⋯ 10.80  1.04e-03
#       p_adj.loc p_adj.glb contrast    Name         TF_Name
# 1     1.77e-02  1.00e+00  gtl1_df1-WT PDH-E1 ALPHA NA
# 2     7.77e-21  2.66e-17  gtl1_df1-WT LEA14        NA
# 3     2.70e-04  1.00e+00  gtl1_df1-WT AT1G01500    NA
# 4     1.44e-02  1.00e+00  gtl1_df1-WT AT1G01710    NA
# 5     8.64e-04  1.00e+00  gtl1_df1-WT PEX11C       NA
# 6     2.46e-25  6.40e-22  gtl1_df1-WT AT1G02360    NA
# 7     5.14e-05  1.00e+00  gtl1_df1-WT AT1G02610    NA
# 8     1.23e-03  1.00e+00  gtl1_df1-WT PME7         NA
# 9     5.89e-16  2.86e-12  gtl1_df1-WT BAH1         NA
# 10    1.10e-84  3.21e-82  gtl1_df1-WT GSTF7        NA
# 11    7.05e-53  5.81e-50  gtl1_df1-WT GSTF6        NA
# 12    3.24e-07  4.37e-03  gtl1_df1-WT AT1G03220    NA
# 13    1.99e-06  3.02e-02  gtl1_df1-WT AT1G03370    NA
# 14    1.51e-02  1.00e+00  gtl1_df1-WT CPX1         NA
# 15    7.20e-03  1.00e+00  gtl1_df1-WT AT1G03730    NA
# 16    3.62e-03  1.00e+00  gtl1_df1-WT AT1G03740    NA
# 17    1.01e-03  1.00e+00  gtl1_df1-WT FLA9         NA
# 18    1.08e-05  1.90e-01  gtl1_df1-WT AT1G04040    NA
# 19    1.48e-03  1.00e+00  gtl1_df1-WT AT1G04280    NA
# 20    1.83e-03  1.00e+00  gtl1_df1-WT MDH1         NA
# 21    6.69e-29  1.31e-25  gtl1_df1-WT AT1G05060    NA
# 22    6.15e-07  8.57e-03  gtl1_df1-WT PER3         NA
# 23    9.73e-05  1.00e+00  gtl1_df1-WT AT1G05280    NA
# 24    1.54e-03  1.00e+00  gtl1_df1-WT AT1G05340    NA
# 25    3.78e-15  2.00e-11  gtl1_df1-WT AT1G05575    NA
# 26    6.99e-08  8.39e-04  gtl1_df1-WT UGT74E2      NA
# 27    4.22e-02  1.00e+00  gtl1_df1-WT AT1G05870    NA
# 28    7.05e-09  7.42e-05  gtl1_df1-WT BBX24        STO
# 29    1.83e-71  7.78e-69  gtl1_df1-WT ADS1         NA
# 30    4.89e-02  1.00e+00  gtl1_df1-WT GLX2-4       NA
# ⋮     ⋮         ⋮         ⋮           ⋮            ⋮
# 25601 1.66e-03  1.000000  gtl1_df1-WT CCB382       NA
# 25602 3.00e-03  1.000000  gtl1_df1-WT ORF114       NA
# 25603 1.30e-03  1.000000  gtl1_df1-WT ATP6-2       NA
# 25604 4.97e-02  1.000000  gtl1_df1-WT COX1         NA
# 25605 3.51e-02  1.000000  gtl1_df1-WT RRN18        NA
# 25606 9.07e-03  1.000000  gtl1_df1-WT ATPA         NA
# 25607 5.99e-03  1.000000  gtl1_df1-WT ATPF         NA
# 25608 5.08e-03  1.000000  gtl1_df1-WT RPS2         NA
# 25609 4.75e-03  1.000000  gtl1_df1-WT RPOC1        NA
# 25610 1.08e-02  1.000000  gtl1_df1-WT YCF3         NA
# 25611 1.32e-04  1.000000  gtl1_df1-WT ATPB         NA
# 25612 1.28e-02  1.000000  gtl1_df1-WT RBCL         NA
# 25613 1.06e-02  1.000000  gtl1_df1-WT ACCD         NA
# 25614 4.94e-03  1.000000  gtl1_df1-WT YCF4         NA
# 25615 2.19e-02  1.000000  gtl1_df1-WT PETA         NA
# 25616 1.81e-03  1.000000  gtl1_df1-WT PSBF         NA
# 25617 6.20e-03  1.000000  gtl1_df1-WT RPL33        NA
# 25618 4.29e-02  1.000000  gtl1_df1-WT RPS18        NA
# 25619 2.58e-03  1.000000  gtl1_df1-WT RPL20        NA
# 25620 3.91e-02  1.000000  gtl1_df1-WT CLPP1        NA
# 25621 4.96e-02  1.000000  gtl1_df1-WT PETB         NA
# 25622 2.97e-02  1.000000  gtl1_df1-WT RPS8         NA
# 25623 2.75e-02  1.000000  gtl1_df1-WT RPL14        NA
# 25624 1.47e-02  1.000000  gtl1_df1-WT RPL22        NA
# 25625 5.33e-03  1.000000  gtl1_df1-WT NDHF         NA
# 25626 2.14e-02  1.000000  gtl1_df1-WT CCSA         NA
# 25627 7.28e-03  1.000000  gtl1_df1-WT NDHD         NA
# 25628 1.84e-02  1.000000  gtl1_df1-WT YCF1.2       NA
# 25629 5.32e-08  0.000149  gtl1_df1-WT AT3G43990    NA
# 25630 1.85e-02  1.000000  gtl1_df1-WT TRNK         NA
#       Description                      up_dn_label
# 1     NA                               Down
# 2     NA                               Down
# 3     NA                               Up
# 4     NA                               Down
# 5     NA                               Up
# 6     NA                               Up
# 7     NA                               Up
# 8     NA                               Up
# 9     NA                               Up
# 10    NA                               Up
# 11    NA                               Up
# 12    NA                               Up
# 13    NA                               Up
# 14    NA                               Up
# 15    NA                               Up
# 16    NA                               Up
# 17    NA                               Down
# 18    NA                               Up
# 19    NA                               Up
# 20    NA                               Down
# 21    NA                               Up
# 22    NA                               Down
# 23    NA                               Down
# 24    NA                               Down
# 25    NA                               Up
# 26    NA                               Down
# 27    NA                               Down
# 28    B-box zinc finger family protein Down
# 29    NA                               Up
# 30    NA                               Up
# ⋮     ⋮                                ⋮
# 25601 NA                               Up
# 25602 NA                               Up
# 25603 NA                               Up
# 25604 NA                               Up
# 25605 NA                               Up
# 25606 NA                               Up
# 25607 NA                               Up
# 25608 NA                               Up
# 25609 NA                               Up
# 25610 NA                               Up
# 25611 NA                               Up
# 25612 NA                               Up
# 25613 NA                               Up
# 25614 NA                               Up
# 25615 NA                               Up
# 25616 NA                               Up
# 25617 NA                               Up
# 25618 NA                               Up
# 25619 NA                               Up
# 25620 NA                               Up
# 25621 NA                               Up
# 25622 NA                               Up
# 25623 NA                               Up
# 25624 NA                               Up
# 25625 NA                               Up
# 25626 NA                               Up
# 25627 NA                               Up
# 25628 NA                               Up
# 25629 NA                               Down
# 25630 NA                               Up
#       clust_up_dn
# 1     Distal Columella_Down
# 2     Distal Columella_Down
# 3     Distal Columella_Up
# 4     Distal Columella_Down
# 5     Distal Columella_Up
# 6     Distal Columella_Up
# 7     Distal Columella_Up
# 8     Distal Columella_Up
# 9     Distal Columella_Up
# 10    Distal Columella_Up
# 11    Distal Columella_Up
# 12    Distal Columella_Up
# 13    Distal Columella_Up
# 14    Distal Columella_Up
# 15    Distal Columella_Up
# 16    Distal Columella_Up
# 17    Distal Columella_Down
# 18    Distal Columella_Up
# 19    Distal Columella_Up
# 20    Distal Columella_Down
# 21    Distal Columella_Up
# 22    Distal Columella_Down
# 23    Distal Columella_Down
# 24    Distal Columella_Down
# 25    Distal Columella_Up
# 26    Distal Columella_Down
# 27    Distal Columella_Down
# 28    Distal Columella_Down
# 29    Distal Columella_Up
# 30    Distal Columella_Up
# ⋮     ⋮
# 25601 Transition Domain_Trichoblast_Up
# 25602 Transition Domain_Trichoblast_Up
# 25603 Transition Domain_Trichoblast_Up
# 25604 Transition Domain_Trichoblast_Up
# 25605 Transition Domain_Trichoblast_Up
# 25606 Transition Domain_Trichoblast_Up
# 25607 Transition Domain_Trichoblast_Up
# 25608 Transition Domain_Trichoblast_Up
# 25609 Transition Domain_Trichoblast_Up
# 25610 Transition Domain_Trichoblast_Up
# 25611 Transition Domain_Trichoblast_Up
# 25612 Transition Domain_Trichoblast_Up
# 25613 Transition Domain_Trichoblast_Up
# 25614 Transition Domain_Trichoblast_Up
# 25615 Transition Domain_Trichoblast_Up
# 25616 Transition Domain_Trichoblast_Up
# 25617 Transition Domain_Trichoblast_Up
# 25618 Transition Domain_Trichoblast_Up
# 25619 Transition Domain_Trichoblast_Up
# 25620 Transition Domain_Trichoblast_Up
# 25621 Transition Domain_Trichoblast_Up
# 25622 Transition Domain_Trichoblast_Up
# 25623 Transition Domain_Trichoblast_Up
# 25624 Transition Domain_Trichoblast_Up
# 25625 Transition Domain_Trichoblast_Up
# 25626 Transition Domain_Trichoblast_Up
# 25627 Transition Domain_Trichoblast_Up
# 25628 Transition Domain_Trichoblast_Up
# 25629 Transition Domain_Trichoblast_Down
# 25630 Transition Domain_Trichoblast_Up

# %%
# add DE and up/dn to total list
sig_to_join <- sig_DE_fil %>%
mutate(clust_gene=paste(cluster_id, gene, sep="_")) %>%
select(clust_gene, up_dn_label, clust_up_dn)

# %%
# join all genes list to DE labels
all_bg <- mutate(all_bg, clust_gene=paste(cluster_id, gene, sep="_"))

all_bg <- left_join(all_bg, feature_names, by=c("gene"="AGI"))

all_bg$DE <- all_bg$clust_gene %in% sig_to_join$clust_gene


all_bg <- all_bg %>%
left_join(sig_to_join, by="clust_gene") %>%
arrange(all_bg, p_adj.loc)

write.csv(all_bg, file = "./output/v4_all_gtl1_df1_v_WT_cell_time_EdgeR_q0.05_FC1.5_r_v_4_20220121.csv")
